# %% [markdown]
# # Quaternion Valued CNN

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class QuatConv2D(layers.Layer):
    """
    Quaternion valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer(),
                 data_format=None,
                 kernel_regularizer=1e-4):
        super(QuatConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        self.kernel_regularizer = kernel_regularizer
        
    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('QuatConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        # Filter multiplied from the right!
        F_r = tf.concat([ self.f0,-self.f1,-self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3,-self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0, self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2,-self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
def diag_init(shape, dtype=None):
    return tf.ones(shape) / 2.

class Hypercomplex4DBNActivation(layers.Layer):
    """
    Batch Normalization for tessarines and quaternions.
    Based on matrix whitening. Decorrelates each component of tessarine/quaternion.
    Includes activation: can be placed before, after or in the middle of BN.
    References:
    [1] Ioffe, S. and Szegedy, C. (2015). Batch normalization: Accelerating deep network training by reducing internal covariate shift.
    [2] Kessy, A., Lewin, A., and Strimmer, K. (2018). Optimal whitening and decorrelation. The American Statistician, 72(4):309–314.
    [3] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Ros-tamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [4] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self,
                 center=True,
                 scale=True,
                 momentum=0.9,
                 beta_init='zeros',
                 gam_diag_init='diag_init',
                 gam_off_init='zeros',
                 mov_mean_init='zeros',
                 mov_var_init='diag_init',
                 mov_cov_init='zeros',
                 beta_reg=None,
                 gam_diag_reg=None,
                 gam_off_reg=None,
                 activation="elu",
                 activation_position="after",
                 epsilon=1e-6,
                 **kwargs):
        super(Hypercomplex4DBNActivation, self).__init__(**kwargs)
        self.center = center
        self.scale = scale
        self.momentum = momentum
        self.beta_init = initializers.get(beta_init)

        if gam_diag_init == 'diag_init':
            self.gam_diag_init = diag_init
        else:
            self.gam_diag_init = initializers.get(gam_diag_init)

        self.gam_off_init = initializers.get(gam_off_init)
        self.mov_mean_init = initializers.get(mov_mean_init)

        if mov_var_init == 'diag_init':
            self.mov_var_init = diag_init
        else:    
            self.mov_var_init = initializers.get(mov_var_init)
            
        self.mov_cov_init = initializers.get(mov_cov_init)
        self.beta_reg = regularizers.get(beta_reg)
        self.gam_diag_reg = regularizers.get(gam_diag_reg)
        self.gam_off_reg = regularizers.get(gam_off_reg)
        self.activation = activations.get(activation)
        self.activation_position = activation_position
        self.epsilon = epsilon

    def build(self, input_shape):
        input_dim = input_shape[-1] // 4
        vars_shape = [input_dim, 1]
        gamma_shape = (input_dim,)

        if self.scale:
            self.mov_Vrr = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vrr")
            self.mov_Vri = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vri")
            self.mov_Vrj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrj")
            self.mov_Vrk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrk")
            self.mov_Vii = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vii")
            self.mov_Vij = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vij")
            self.mov_Vik = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vik")
            self.mov_Vjj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vjj")
            self.mov_Vjk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vjk")
            self.mov_Vkk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vkk")

            self.gam_rr = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_rr")
            self.gam_ri = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ri")
            self.gam_rj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rj")
            self.gam_rk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rk")
            self.gam_ii = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_ii")
            self.gam_ij = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ij")
            self.gam_ik = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ik")
            self.gam_jj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_jj")
            self.gam_jk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_jk")
            self.gam_kk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_kk")
        else:
            self.mov_Vrr = None
            self.mov_Vri = None
            self.mov_Vrj = None
            self.mov_Vrk = None
            self.mov_Vii = None
            self.mov_Vij = None
            self.mov_Vik = None
            self.mov_Vjj = None
            self.mov_Vjk = None
            self.mov_Vkk = None
            self.gam_rr = None
            self.gam_ri = None
            self.gam_rj = None
            self.gam_rk = None
            self.gam_ii = None
            self.gam_ij = None
            self.gam_ik = None
            self.gam_jj = None
            self.gam_jk = None
            self.gam_kk = None

        if self.center:
            self.beta = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                        initializer=self.beta_init,
                                        regularizer=self.beta_reg,
                                        name="beta")
            self.mov_mean = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                            initializer=self.mov_mean_init,
                                            trainable=False,
                                            name="mov_mean")
        else:
            self.beta = None
            self.mov_mean = None

    def _compute_variances(self, centered_r, centered_i, centered_j, centered_k, input_dim):
        Vrr = kr.backend.mean(
            centered_r ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vri = kr.backend.mean(
            centered_r * centered_i,
            axis=[0, 1, 2]
        )

        Vrj = kr.backend.mean(
            centered_r * centered_j,
            axis=[0, 1, 2]
        )

        Vrk = kr.backend.mean(
            centered_r * centered_k,
            axis=[0, 1, 2]
        )

        Vii = kr.backend.mean(
            centered_i ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vij = kr.backend.mean(
            centered_i * centered_j,
            axis=[0, 1, 2]
        )

        Vik = kr.backend.mean(
            centered_i * centered_k,
            axis=[0, 1, 2]
        )

        Vjj = kr.backend.mean(
            centered_j ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vjk = kr.backend.mean(
            centered_j * centered_k,
            axis=[0, 1, 2]
        )

        Vkk = kr.backend.mean(
            centered_k ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        pars_shape = [input_dim, 1]
        Vrr = tf.reshape(Vrr, pars_shape)
        Vri = tf.reshape(Vri, pars_shape)
        Vrj = tf.reshape(Vrj, pars_shape)
        Vrk = tf.reshape(Vrk, pars_shape)
        Vii = tf.reshape(Vii, pars_shape)
        Vij = tf.reshape(Vij, pars_shape)
        Vik = tf.reshape(Vik, pars_shape)
        Vjj = tf.reshape(Vjj, pars_shape)
        Vjk = tf.reshape(Vjk, pars_shape)
        Vkk = tf.reshape(Vkk, pars_shape)

        return Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk
    
    def _moving_exponential_update(self, var, value):
        decay = 1 - self.momentum
        var.assign_sub(var * decay)
        var.assign_add(value * decay)

    def _update_moving_parameters(self, mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk):
        if self.center:
            self._moving_exponential_update(self.mov_mean, mean)

        if self.scale:
            self._moving_exponential_update(self.mov_Vrr, Vrr)
            self._moving_exponential_update(self.mov_Vri, Vri)
            self._moving_exponential_update(self.mov_Vrj, Vrj)
            self._moving_exponential_update(self.mov_Vrk, Vrk)
            self._moving_exponential_update(self.mov_Vii, Vii)
            self._moving_exponential_update(self.mov_Vij, Vij)
            self._moving_exponential_update(self.mov_Vik, Vik)
            self._moving_exponential_update(self.mov_Vjj, Vjj)
            self._moving_exponential_update(self.mov_Vjk, Vjk)
            self._moving_exponential_update(self.mov_Vkk, Vkk)

    def call(self, inputs, training=None):
        if (not self.center) or (not self.scale):
            raise ValueError("Batch Normalization should scale or center.")

        input_shape = kr.backend.int_shape(inputs)
        input_dim = input_shape[-1] // 4

        # Activation before
        if self.activation_position == "before":
            output = self.activation(inputs)
        else:
            output = inputs

        if training in {0, False}:
            mean = self.mov_mean
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr = self.mov_Vrr
                Vri = self.mov_Vri
                Vrj = self.mov_Vrj
                Vrk = self.mov_Vrk
                Vii = self.mov_Vii
                Vij = self.mov_Vij
                Vik = self.mov_Vik
                Vjj = self.mov_Vjj
                Vjk = self.mov_Vjk
                Vkk = self.mov_Vkk
        else:
            # mean and centering
            mean = kr.backend.mean(output, axis=[0, 1, 2])
            mean = kr.backend.reshape(mean, [1, 1, 1, input_dim * 4])
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = self._compute_variances(centered_r, centered_i, centered_j, centered_k, input_dim)
            else:
                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = [None for i in range(10)]  

            self._update_moving_parameters(mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk)

        if self.scale:
            var_reshape = [input_dim, 1, 4]
            # covariance matrix
            V = tf.concat([[tf.reshape(tf.concat([Vrr, Vri, Vrj, Vrk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vri, Vii, Vij, Vik], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrj, Vij, Vjj, Vjk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrk, Vik, Vjk, Vkk], axis=1), var_reshape)]], axis=2)

            # Whitening
            R = tf.reshape(tf.linalg.cholesky(V), [input_dim, 4, 4])
            W = tf.linalg.inv(tf.transpose(R, perm=[0,2,1]))

            Wrr = W[:,0,0]
            Wri = W[:,0,1]
            Wrj = W[:,0,2]
            Wrk = W[:,0,3]
            Wii = W[:,1,1]
            Wij = W[:,1,2]
            Wik = W[:,1,3]
            Wjj = W[:,2,2]
            Wjk = W[:,2,3]
            Wkk = W[:,3,3]

            output_r = centered_r * Wrr
            output_i = centered_r * Wri + centered_i * Wii
            output_j = centered_r * Wrj + centered_i * Wij + centered_j * Wjj
            output_k = centered_r * Wrk + centered_i * Wik + centered_j * Wjk + centered_k * Wkk

            if self.activation_position == "middle":
                output_r = self.activation(output_r)
                output_i = self.activation(output_i)
                output_j = self.activation(output_j)
                output_k = self.activation(output_k)

            out_r = output_r * self.gam_rr
            out_i = output_r * self.gam_ri + output_i * self.gam_ii
            out_j = output_r * self.gam_rj + output_i * self.gam_ij + output_j * self.gam_jj
            out_k = output_r * self.gam_rk + output_i * self.gam_ik + output_j * self.gam_jk + output_k * self.gam_kk
            output = tf.concat([out_r, out_i, out_j, out_k], axis=-1)
        else:
            output = centered
            if self.activation_position == "middle":
                output = self.activation(output)

        if self.center:
            output = output + self.beta

        if self.activation_position == "after":
            output = self.activation(output)

        return output

# %%
DefaultConvQuat = partial(QuatConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class QuatResidualUnit(layers.Layer):
    """ 
    Quaternion valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recognition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual networks.
    """
    def __init__(self, filters, strides=1, activation="elu", activation_position="after", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvQuat(filters, strides=strides),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position), 
            DefaultConvQuat(filters),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position),]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvQuat(filters, kernel_size=(1,1), strides=strides),
                Hypercomplex4DBNActivation(activation=None, activation_position='no_activation')]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"
activation_position = 'after'

quat_resnet = kr.models.Sequential()
quat_resnet.add(DefaultConvQuat(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    quat_resnet.add(QuatResidualUnit(filters, strides=strides, activation=activation, activation_position=activation_position))
    prev_filters = filters
quat_resnet.add(kr.layers.GlobalAvgPool2D())
quat_resnet.add(kr.layers.Flatten())
quat_resnet.add(kr.layers.Dense(10, activation="softmax"))
quat_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

quat_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 165s 292ms/step - loss: 2.3501 - accuracy: 0.3009 - val_loss: 2.5113 - val_accuracy: 0.2309
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 2.0989 - accuracy: 0.3923 - val_loss: 2.5609 - val_accuracy: 0.2233
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 1.9843 - accuracy: 0.4356 - val_loss: 2.4942 - val_accuracy: 0.2082
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 285ms/step - loss: 1.9088 - accuracy: 0.4622 - val_loss: 4.1060 - val_accuracy: 0.1517
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 1.8453 - accuracy: 0.4840 - val_loss: 2.8480 - val_accuracy: 0.1768
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 1.7939 - accuracy: 0.5021 - val_loss: 2.8279 - val_accuracy: 0.1987
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 1.7543 - accuracy: 0.5114 - val_loss: 2.3453 - val_accuracy: 0.3283
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 1.7172 - accuracy: 0.5269 - val_loss: 2.4460 - val_accuracy: 0.3324
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 288ms/step - loss: 1.6827 - accuracy: 0.5362 - val_loss: 2.7123 - val_accuracy: 0.2221
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 1.6546 - accuracy: 0.5440 - val_loss: 2.7740 - val_accuracy: 0.2393
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 1.8587 - accuracy: 0.4615 - val_loss: 2.4179 - val_accuracy: 0.3060
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 1.5757 - accuracy: 0.5503 - val_loss: 2.3337 - val_accuracy: 0.3461
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 1.4365 - accuracy: 0.5952 - val_loss: 1.9976 - val_accuracy: 0.4326
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 1.3326 - accuracy: 0.6202 - val_loss: 1.9611 - val_accuracy: 0.4558
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 1.2560 - accuracy: 0.6424 - val_loss: 3.3416 - val_accuracy: 0.3204
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 1.1902 - accuracy: 0.6581 - val_loss: 1.7564 - val_accuracy: 0.5019
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 1.1326 - accuracy: 0.6740 - val_loss: 1.7760 - val_accuracy: 0.5058
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 1.0856 - accuracy: 0.6891 - val_loss: 1.6508 - val_accuracy: 0.5191
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 1.0430 - accuracy: 0.6991 - val_loss: 1.4043 - val_accuracy: 0.5853
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 116s 295ms/step - loss: 0.9979 - accuracy: 0.7127 - val_loss: 1.4334 - val_accuracy: 0.5587
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.9701 - accuracy: 0.7197 - val_loss: 1.2486 - val_accuracy: 0.6318
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 290ms/step - loss: 0.9384 - accuracy: 0.7319 - val_loss: 1.4367 - val_accuracy: 0.5719
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 288ms/step - loss: 0.9165 - accuracy: 0.7377 - val_loss: 1.4009 - val_accuracy: 0.6000
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.8873 - accuracy: 0.7481 - val_loss: 1.0863 - val_accuracy: 0.6712
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.8659 - accuracy: 0.7550 - val_loss: 1.1460 - val_accuracy: 0.6608
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.8447 - accuracy: 0.7606 - val_loss: 1.5014 - val_accuracy: 0.5763
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.8283 - accuracy: 0.7658 - val_loss: 1.4916 - val_accuracy: 0.5399
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.8202 - accuracy: 0.7690 - val_loss: 1.3674 - val_accuracy: 0.6125
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7999 - accuracy: 0.7762 - val_loss: 1.3296 - val_accuracy: 0.6355
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7872 - accuracy: 0.7803 - val_loss: 1.6153 - val_accuracy: 0.5829
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.7717 - accuracy: 0.7870 - val_loss: 1.4022 - val_accuracy: 0.6107
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7571 - accuracy: 0.7907 - val_loss: 1.0327 - val_accuracy: 0.6986
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7503 - accuracy: 0.7917 - val_loss: 0.9474 - val_accuracy: 0.7242
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7436 - accuracy: 0.7963 - val_loss: 1.2391 - val_accuracy: 0.6598
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.7273 - accuracy: 0.8005 - val_loss: 0.9973 - val_accuracy: 0.7191
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.7242 - accuracy: 0.8010 - val_loss: 1.0979 - val_accuracy: 0.6924
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.7185 - accuracy: 0.8055 - val_loss: 1.3870 - val_accuracy: 0.6022
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 0.7070 - accuracy: 0.8076 - val_loss: 1.0761 - val_accuracy: 0.7037
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.6987 - accuracy: 0.8117 - val_loss: 1.0313 - val_accuracy: 0.7027
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.6962 - accuracy: 0.8108 - val_loss: 1.0202 - val_accuracy: 0.7150
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.6912 - accuracy: 0.8140 - val_loss: 1.0301 - val_accuracy: 0.7104
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6785 - accuracy: 0.8184 - val_loss: 1.1974 - val_accuracy: 0.6746
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.6781 - accuracy: 0.8193 - val_loss: 1.0138 - val_accuracy: 0.7148
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.6714 - accuracy: 0.8207 - val_loss: 0.9080 - val_accuracy: 0.7559
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.6686 - accuracy: 0.8226 - val_loss: 0.8863 - val_accuracy: 0.7478
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.6617 - accuracy: 0.8263 - val_loss: 1.0888 - val_accuracy: 0.6955
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.6595 - accuracy: 0.8240 - val_loss: 0.9537 - val_accuracy: 0.7326
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.6570 - accuracy: 0.8268 - val_loss: 0.8880 - val_accuracy: 0.7525
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.6485 - accuracy: 0.8291 - val_loss: 1.0612 - val_accuracy: 0.6946
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.6475 - accuracy: 0.8306 - val_loss: 0.9417 - val_accuracy: 0.7424
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.6417 - accuracy: 0.8325 - val_loss: 0.9415 - val_accuracy: 0.7297
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.6392 - accuracy: 0.8324 - val_loss: 1.1014 - val_accuracy: 0.6817
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.6359 - accuracy: 0.8347 - val_loss: 1.0265 - val_accuracy: 0.7221
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.6276 - accuracy: 0.8369 - val_loss: 1.0603 - val_accuracy: 0.7152
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 293ms/step - loss: 0.6277 - accuracy: 0.8357 - val_loss: 0.9771 - val_accuracy: 0.7238
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.6221 - accuracy: 0.8389 - val_loss: 1.4309 - val_accuracy: 0.6141
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.6220 - accuracy: 0.8382 - val_loss: 1.2756 - val_accuracy: 0.6791
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.6199 - accuracy: 0.8404 - val_loss: 1.1507 - val_accuracy: 0.6907
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.6175 - accuracy: 0.8417 - val_loss: 0.8590 - val_accuracy: 0.7586
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.6179 - accuracy: 0.8403 - val_loss: 1.0079 - val_accuracy: 0.7257
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.6136 - accuracy: 0.8411 - val_loss: 0.9671 - val_accuracy: 0.7268
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.6117 - accuracy: 0.8422 - val_loss: 1.0085 - val_accuracy: 0.7163
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.6084 - accuracy: 0.8433 - val_loss: 0.9132 - val_accuracy: 0.7525
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 295ms/step - loss: 0.6031 - accuracy: 0.8466 - val_loss: 0.9427 - val_accuracy: 0.7411
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.6043 - accuracy: 0.8460 - val_loss: 1.6018 - val_accuracy: 0.6127
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5964 - accuracy: 0.8492 - val_loss: 1.2540 - val_accuracy: 0.6524
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 295ms/step - loss: 0.5968 - accuracy: 0.8496 - val_loss: 1.2777 - val_accuracy: 0.6786
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.5947 - accuracy: 0.8510 - val_loss: 1.0109 - val_accuracy: 0.7227
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.5931 - accuracy: 0.8499 - val_loss: 1.0133 - val_accuracy: 0.7089
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 116s 296ms/step - loss: 0.5920 - accuracy: 0.8513 - val_loss: 1.0045 - val_accuracy: 0.7228
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.5891 - accuracy: 0.8512 - val_loss: 0.9255 - val_accuracy: 0.7463
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.5845 - accuracy: 0.8548 - val_loss: 1.0888 - val_accuracy: 0.7202
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.5859 - accuracy: 0.8541 - val_loss: 1.2288 - val_accuracy: 0.6751
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5849 - accuracy: 0.8530 - val_loss: 0.9591 - val_accuracy: 0.7500
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.5824 - accuracy: 0.8552 - val_loss: 0.9027 - val_accuracy: 0.7490
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.5810 - accuracy: 0.8542 - val_loss: 0.9584 - val_accuracy: 0.7442
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5792 - accuracy: 0.8552 - val_loss: 1.0462 - val_accuracy: 0.7158
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.5779 - accuracy: 0.8566 - val_loss: 1.0853 - val_accuracy: 0.7011
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.5755 - accuracy: 0.8560 - val_loss: 1.2031 - val_accuracy: 0.6904
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.5800 - accuracy: 0.8551 - val_loss: 0.9266 - val_accuracy: 0.7442
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5735 - accuracy: 0.8578 - val_loss: 0.9330 - val_accuracy: 0.7495
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5708 - accuracy: 0.8603 - val_loss: 0.9209 - val_accuracy: 0.7599
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5713 - accuracy: 0.8585 - val_loss: 0.8818 - val_accuracy: 0.7651
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.5657 - accuracy: 0.8597 - val_loss: 0.8489 - val_accuracy: 0.7686
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.5716 - accuracy: 0.8572 - val_loss: 1.0084 - val_accuracy: 0.7260
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5686 - accuracy: 0.8603 - val_loss: 1.1897 - val_accuracy: 0.6922
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5672 - accuracy: 0.8603 - val_loss: 1.1013 - val_accuracy: 0.6899
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.5651 - accuracy: 0.8602 - val_loss: 0.8519 - val_accuracy: 0.7661
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5660 - accuracy: 0.8611 - val_loss: 0.8167 - val_accuracy: 0.7782
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5611 - accuracy: 0.8634 - val_loss: 1.8089 - val_accuracy: 0.5874
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.5625 - accuracy: 0.8629 - val_loss: 0.8365 - val_accuracy: 0.7787
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 288ms/step - loss: 0.5621 - accuracy: 0.8609 - val_loss: 0.9678 - val_accuracy: 0.7402
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5571 - accuracy: 0.8630 - val_loss: 0.9734 - val_accuracy: 0.7402
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5621 - accuracy: 0.8617 - val_loss: 0.9632 - val_accuracy: 0.7417
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.5552 - accuracy: 0.8644 - val_loss: 1.0018 - val_accuracy: 0.7217
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5528 - accuracy: 0.8646 - val_loss: 1.0276 - val_accuracy: 0.7234
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5529 - accuracy: 0.8649 - val_loss: 0.9636 - val_accuracy: 0.7362
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5567 - accuracy: 0.8639 - val_loss: 1.6882 - val_accuracy: 0.5965
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.5518 - accuracy: 0.8675 - val_loss: 1.0134 - val_accuracy: 0.7394
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.5556 - accuracy: 0.8649 - val_loss: 0.8408 - val_accuracy: 0.7795
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5507 - accuracy: 0.8671 - val_loss: 0.8505 - val_accuracy: 0.7698
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5499 - accuracy: 0.8683 - val_loss: 0.9708 - val_accuracy: 0.7327
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5523 - accuracy: 0.8668 - val_loss: 0.9360 - val_accuracy: 0.7409
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 0.5454 - accuracy: 0.8661 - val_loss: 0.9600 - val_accuracy: 0.7454
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 0.5480 - accuracy: 0.8659 - val_loss: 0.9894 - val_accuracy: 0.7408
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5474 - accuracy: 0.8677 - val_loss: 0.9465 - val_accuracy: 0.7358
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5457 - accuracy: 0.8694 - val_loss: 1.0682 - val_accuracy: 0.7034
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5417 - accuracy: 0.8702 - val_loss: 0.8869 - val_accuracy: 0.7641
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5410 - accuracy: 0.8704 - val_loss: 0.8877 - val_accuracy: 0.7638
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.5403 - accuracy: 0.8700 - val_loss: 1.2175 - val_accuracy: 0.7050
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5409 - accuracy: 0.8681 - val_loss: 0.9271 - val_accuracy: 0.7565
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5397 - accuracy: 0.8703 - val_loss: 0.7660 - val_accuracy: 0.7983
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5435 - accuracy: 0.8700 - val_loss: 0.9260 - val_accuracy: 0.7591
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.5381 - accuracy: 0.8717 - val_loss: 1.3125 - val_accuracy: 0.6928
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5360 - accuracy: 0.8700 - val_loss: 0.9237 - val_accuracy: 0.7638
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5387 - accuracy: 0.8707 - val_loss: 1.1771 - val_accuracy: 0.6825
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5354 - accuracy: 0.8724 - val_loss: 1.1948 - val_accuracy: 0.6722
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5356 - accuracy: 0.8720 - val_loss: 0.9151 - val_accuracy: 0.7641
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5334 - accuracy: 0.8732 - val_loss: 1.1728 - val_accuracy: 0.6999
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.5370 - accuracy: 0.8715 - val_loss: 0.9027 - val_accuracy: 0.7633
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5357 - accuracy: 0.8722 - val_loss: 1.1822 - val_accuracy: 0.7141
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 290ms/step - loss: 0.5296 - accuracy: 0.8747 - val_loss: 0.8534 - val_accuracy: 0.7666
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 290ms/step - loss: 0.5304 - accuracy: 0.8750 - val_loss: 0.9641 - val_accuracy: 0.7423
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5317 - accuracy: 0.8728 - val_loss: 0.9046 - val_accuracy: 0.7607
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 293ms/step - loss: 0.5345 - accuracy: 0.8721 - val_loss: 0.7462 - val_accuracy: 0.8122
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.5324 - accuracy: 0.8723 - val_loss: 0.9763 - val_accuracy: 0.7442
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.5305 - accuracy: 0.8734 - val_loss: 0.9289 - val_accuracy: 0.7600
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.5314 - accuracy: 0.8741 - val_loss: 0.9614 - val_accuracy: 0.7449
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.5269 - accuracy: 0.8753 - val_loss: 0.9439 - val_accuracy: 0.7464
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 116s 295ms/step - loss: 0.5272 - accuracy: 0.8748 - val_loss: 0.9120 - val_accuracy: 0.7649
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 115s 294ms/step - loss: 0.5260 - accuracy: 0.8766 - val_loss: 1.0721 - val_accuracy: 0.7211
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5270 - accuracy: 0.8764 - val_loss: 0.8321 - val_accuracy: 0.7957
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 292ms/step - loss: 0.5309 - accuracy: 0.8741 - val_loss: 1.6117 - val_accuracy: 0.5888
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5268 - accuracy: 0.8761 - val_loss: 0.8402 - val_accuracy: 0.7760
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5253 - accuracy: 0.8760 - val_loss: 1.1806 - val_accuracy: 0.7180
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5280 - accuracy: 0.8751 - val_loss: 0.9396 - val_accuracy: 0.7704
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5207 - accuracy: 0.8777 - val_loss: 1.2352 - val_accuracy: 0.7093
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5222 - accuracy: 0.8772 - val_loss: 1.1757 - val_accuracy: 0.6937
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5271 - accuracy: 0.8747 - val_loss: 0.7464 - val_accuracy: 0.8036
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5207 - accuracy: 0.8782 - val_loss: 0.8729 - val_accuracy: 0.7768
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.5197 - accuracy: 0.8776 - val_loss: 0.9268 - val_accuracy: 0.7674
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5185 - accuracy: 0.8794 - val_loss: 0.9176 - val_accuracy: 0.7679
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5197 - accuracy: 0.8784 - val_loss: 1.1127 - val_accuracy: 0.7055
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.5228 - accuracy: 0.8772 - val_loss: 0.9042 - val_accuracy: 0.7590
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5189 - accuracy: 0.8792 - val_loss: 1.0540 - val_accuracy: 0.7194
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5214 - accuracy: 0.8784 - val_loss: 0.9641 - val_accuracy: 0.7368
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5179 - accuracy: 0.8784 - val_loss: 1.0066 - val_accuracy: 0.7300
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 277ms/step - loss: 0.5123 - accuracy: 0.8818 - val_loss: 0.7937 - val_accuracy: 0.7994
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5149 - accuracy: 0.8786 - val_loss: 1.0302 - val_accuracy: 0.7310
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5159 - accuracy: 0.8793 - val_loss: 1.1028 - val_accuracy: 0.7165
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5173 - accuracy: 0.8772 - val_loss: 0.7898 - val_accuracy: 0.7925
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 287ms/step - loss: 0.4192 - accuracy: 0.9146 - val_loss: 0.6284 - val_accuracy: 0.8406
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3934 - accuracy: 0.9225 - val_loss: 0.6571 - val_accuracy: 0.8305
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.3802 - accuracy: 0.9246 - val_loss: 0.6732 - val_accuracy: 0.8277
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 0.3718 - accuracy: 0.9279 - val_loss: 0.6688 - val_accuracy: 0.8304
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.3660 - accuracy: 0.9291 - val_loss: 0.6727 - val_accuracy: 0.8293
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 280ms/step - loss: 0.3595 - accuracy: 0.9303 - val_loss: 0.6496 - val_accuracy: 0.8359
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.3560 - accuracy: 0.9297 - val_loss: 0.6470 - val_accuracy: 0.8350
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3480 - accuracy: 0.9334 - val_loss: 0.6754 - val_accuracy: 0.8250
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.3443 - accuracy: 0.9337 - val_loss: 0.6724 - val_accuracy: 0.8267
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 280ms/step - loss: 0.3391 - accuracy: 0.9347 - val_loss: 0.6422 - val_accuracy: 0.8377
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 277ms/step - loss: 0.3367 - accuracy: 0.9335 - val_loss: 0.6609 - val_accuracy: 0.8314
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3320 - accuracy: 0.9362 - val_loss: 0.6422 - val_accuracy: 0.8372
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.3268 - accuracy: 0.9362 - val_loss: 0.6435 - val_accuracy: 0.8369
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3240 - accuracy: 0.9368 - val_loss: 0.6035 - val_accuracy: 0.8468
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3238 - accuracy: 0.9357 - val_loss: 0.6830 - val_accuracy: 0.8273
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3192 - accuracy: 0.9377 - val_loss: 0.6113 - val_accuracy: 0.8463
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3160 - accuracy: 0.9368 - val_loss: 0.6766 - val_accuracy: 0.8277
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3106 - accuracy: 0.9388 - val_loss: 0.6429 - val_accuracy: 0.8375
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 280ms/step - loss: 0.3080 - accuracy: 0.9385 - val_loss: 0.6198 - val_accuracy: 0.8407
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 277ms/step - loss: 0.3058 - accuracy: 0.9395 - val_loss: 0.6735 - val_accuracy: 0.8314
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3045 - accuracy: 0.9391 - val_loss: 0.6203 - val_accuracy: 0.8450
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 290ms/step - loss: 0.3004 - accuracy: 0.9397 - val_loss: 0.6335 - val_accuracy: 0.8394
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 114s 291ms/step - loss: 0.2981 - accuracy: 0.9403 - val_loss: 0.6773 - val_accuracy: 0.8248
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 114s 292ms/step - loss: 0.2937 - accuracy: 0.9406 - val_loss: 0.6456 - val_accuracy: 0.8324
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 114s 293ms/step - loss: 0.2927 - accuracy: 0.9413 - val_loss: 0.6660 - val_accuracy: 0.8323
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 115s 293ms/step - loss: 0.2918 - accuracy: 0.9410 - val_loss: 0.6235 - val_accuracy: 0.8433
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 116s 295ms/step - loss: 0.2897 - accuracy: 0.9409 - val_loss: 0.6639 - val_accuracy: 0.8289
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2845 - accuracy: 0.9415 - val_loss: 0.6388 - val_accuracy: 0.8341
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2836 - accuracy: 0.9423 - val_loss: 0.6785 - val_accuracy: 0.8265
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.2825 - accuracy: 0.9416 - val_loss: 0.6845 - val_accuracy: 0.8271
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.2794 - accuracy: 0.9414 - val_loss: 0.6160 - val_accuracy: 0.8405
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 287ms/step - loss: 0.2783 - accuracy: 0.9417 - val_loss: 0.5918 - val_accuracy: 0.8482
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.2766 - accuracy: 0.9427 - val_loss: 0.7060 - val_accuracy: 0.8232
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.2756 - accuracy: 0.9416 - val_loss: 0.6048 - val_accuracy: 0.8446
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.2730 - accuracy: 0.9424 - val_loss: 0.7347 - val_accuracy: 0.8105
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 287ms/step - loss: 0.2677 - accuracy: 0.9432 - val_loss: 0.6566 - val_accuracy: 0.8280
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 0.2706 - accuracy: 0.9421 - val_loss: 0.6515 - val_accuracy: 0.8363
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2693 - accuracy: 0.9418 - val_loss: 0.7281 - val_accuracy: 0.8112
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2690 - accuracy: 0.9431 - val_loss: 0.6465 - val_accuracy: 0.8298
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2680 - accuracy: 0.9427 - val_loss: 0.6564 - val_accuracy: 0.8290
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2664 - accuracy: 0.9414 - val_loss: 0.5814 - val_accuracy: 0.8469
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2635 - accuracy: 0.9422 - val_loss: 0.6561 - val_accuracy: 0.8284
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 0.2616 - accuracy: 0.9437 - val_loss: 0.7168 - val_accuracy: 0.8185
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2593 - accuracy: 0.9428 - val_loss: 0.7040 - val_accuracy: 0.8209
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2571 - accuracy: 0.9447 - val_loss: 0.6069 - val_accuracy: 0.8402
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2564 - accuracy: 0.9436 - val_loss: 0.7698 - val_accuracy: 0.8060
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2576 - accuracy: 0.9421 - val_loss: 0.7167 - val_accuracy: 0.8171
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2554 - accuracy: 0.9442 - val_loss: 0.7542 - val_accuracy: 0.8135
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2548 - accuracy: 0.9437 - val_loss: 0.6570 - val_accuracy: 0.8227
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2368 - accuracy: 0.9495 - val_loss: 0.6351 - val_accuracy: 0.8323
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 275ms/step - loss: 0.2279 - accuracy: 0.9537 - val_loss: 0.6270 - val_accuracy: 0.8341
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2236 - accuracy: 0.9551 - val_loss: 0.6226 - val_accuracy: 0.8360
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2220 - accuracy: 0.9559 - val_loss: 0.6271 - val_accuracy: 0.8364
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2239 - accuracy: 0.9556 - val_loss: 0.6364 - val_accuracy: 0.8330
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2200 - accuracy: 0.9579 - val_loss: 0.6102 - val_accuracy: 0.8394
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2192 - accuracy: 0.9573 - val_loss: 0.5978 - val_accuracy: 0.8431
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2183 - accuracy: 0.9579 - val_loss: 0.6080 - val_accuracy: 0.8414
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2188 - accuracy: 0.9562 - val_loss: 0.6136 - val_accuracy: 0.8395
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2165 - accuracy: 0.9580 - val_loss: 0.6296 - val_accuracy: 0.8372
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2154 - accuracy: 0.9592 - val_loss: 0.6227 - val_accuracy: 0.8393
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2174 - accuracy: 0.9575 - val_loss: 0.6329 - val_accuracy: 0.8369
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 275ms/step - loss: 0.2170 - accuracy: 0.9574 - val_loss: 0.6356 - val_accuracy: 0.8359
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2153 - accuracy: 0.9584 - val_loss: 0.6100 - val_accuracy: 0.8419
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2169 - accuracy: 0.9578 - val_loss: 0.6232 - val_accuracy: 0.8388
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2147 - accuracy: 0.9589 - val_loss: 0.6237 - val_accuracy: 0.8389
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2130 - accuracy: 0.9589 - val_loss: 0.6298 - val_accuracy: 0.8381
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2143 - accuracy: 0.9584 - val_loss: 0.6389 - val_accuracy: 0.8358
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 283ms/step - loss: 0.2099 - accuracy: 0.9603 - val_loss: 0.6230 - val_accuracy: 0.8384
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 280ms/step - loss: 0.2130 - accuracy: 0.9584 - val_loss: 0.6185 - val_accuracy: 0.8401
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2117 - accuracy: 0.9585 - val_loss: 0.6226 - val_accuracy: 0.8398
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2123 - accuracy: 0.9587 - val_loss: 0.6089 - val_accuracy: 0.8428
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2120 - accuracy: 0.9579 - val_loss: 0.6126 - val_accuracy: 0.8417
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2136 - accuracy: 0.9574 - val_loss: 0.6471 - val_accuracy: 0.8306
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2096 - accuracy: 0.9594 - val_loss: 0.6184 - val_accuracy: 0.8397
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2104 - accuracy: 0.9601 - val_loss: 0.6263 - val_accuracy: 0.8371
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2118 - accuracy: 0.9574 - val_loss: 0.6136 - val_accuracy: 0.8416
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2109 - accuracy: 0.9589 - val_loss: 0.6262 - val_accuracy: 0.8377
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2101 - accuracy: 0.9594 - val_loss: 0.6195 - val_accuracy: 0.8398
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2058 - accuracy: 0.9602 - val_loss: 0.6629 - val_accuracy: 0.8298
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2089 - accuracy: 0.9599 - val_loss: 0.6479 - val_accuracy: 0.8319
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2061 - accuracy: 0.9605 - val_loss: 0.6161 - val_accuracy: 0.8407
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2092 - accuracy: 0.9590 - val_loss: 0.6369 - val_accuracy: 0.8366
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2091 - accuracy: 0.9604 - val_loss: 0.6309 - val_accuracy: 0.8364
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2083 - accuracy: 0.9600 - val_loss: 0.6234 - val_accuracy: 0.8408
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2071 - accuracy: 0.9610 - val_loss: 0.6337 - val_accuracy: 0.8392
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2058 - accuracy: 0.9604 - val_loss: 0.6224 - val_accuracy: 0.8387
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2066 - accuracy: 0.9593 - val_loss: 0.6180 - val_accuracy: 0.8409
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2068 - accuracy: 0.9597 - val_loss: 0.6317 - val_accuracy: 0.8367
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 277ms/step - loss: 0.2055 - accuracy: 0.9605 - val_loss: 0.6444 - val_accuracy: 0.8342
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2050 - accuracy: 0.9605 - val_loss: 0.6340 - val_accuracy: 0.8358
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2063 - accuracy: 0.9603 - val_loss: 0.6270 - val_accuracy: 0.8394
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2038 - accuracy: 0.9600 - val_loss: 0.6366 - val_accuracy: 0.8379
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2055 - accuracy: 0.9597 - val_loss: 0.6200 - val_accuracy: 0.8435
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2038 - accuracy: 0.9612 - val_loss: 0.6114 - val_accuracy: 0.8423
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 277ms/step - loss: 0.2052 - accuracy: 0.9603 - val_loss: 0.6410 - val_accuracy: 0.8367
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2034 - accuracy: 0.9603 - val_loss: 0.6359 - val_accuracy: 0.8365
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2005 - accuracy: 0.9617 - val_loss: 0.6348 - val_accuracy: 0.8363
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2029 - accuracy: 0.9603 - val_loss: 0.6303 - val_accuracy: 0.8408
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2024 - accuracy: 0.9609 - val_loss: 0.6474 - val_accuracy: 0.8355

# %%
quat_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quat_conv2d (QuatConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# quat_residual_unit (QuatResi (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_1 (QuatRe (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_2 (QuatRe (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_3 (QuatRe (None, None, None, 48)    9072
# _________________________________________________________________
# quat_residual_unit_4 (QuatRe (None, None, None, 48)    11040
# _________________________________________________________________
# quat_residual_unit_5 (QuatRe (None, None, None, 96)    34272
# _________________________________________________________________
# quat_residual_unit_6 (QuatRe (None, None, None, 96)    42816
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 107,170
# Trainable params: 104,146
# Non-trainable params: 3,024
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(quat_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96464

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(quat_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8355
