# %% [markdown]
# # Quaternion Valued CNN

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class QuatConv2D(layers.Layer):
    """
    Quaternion valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer(),
                 data_format=None,
                 kernel_regularizer=1e-4):
        super(QuatConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        self.kernel_regularizer = kernel_regularizer
        
    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('QuatConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        # Filter multiplied from the right!
        F_r = tf.concat([ self.f0,-self.f1,-self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3,-self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0, self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2,-self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
def diag_init(shape, dtype=None):
    return tf.ones(shape) / 2.

class Hypercomplex4DBNActivation(layers.Layer):
    """
    Batch Normalization for tessarines and quaternions.
    Based on matrix whitening. Decorrelates each component of tessarine/quaternion.
    Includes activation: can be placed before, after or in the middle of BN.
    References:
    [1] Ioffe, S. and Szegedy, C. (2015). Batch normalization: Accelerating deep network training by reducing internal covariate shift.
    [2] Kessy, A., Lewin, A., and Strimmer, K. (2018). Optimal whitening and decorrelation. The American Statistician, 72(4):309–314.
    [3] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Ros-tamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [4] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self,
                 center=True,
                 scale=True,
                 momentum=0.9,
                 beta_init='zeros',
                 gam_diag_init='diag_init',
                 gam_off_init='zeros',
                 mov_mean_init='zeros',
                 mov_var_init='diag_init',
                 mov_cov_init='zeros',
                 beta_reg=None,
                 gam_diag_reg=None,
                 gam_off_reg=None,
                 activation="elu",
                 activation_position="after",
                 epsilon=1e-6,
                 **kwargs):
        super(Hypercomplex4DBNActivation, self).__init__(**kwargs)
        self.center = center
        self.scale = scale
        self.momentum = momentum
        self.beta_init = initializers.get(beta_init)

        if gam_diag_init == 'diag_init':
            self.gam_diag_init = diag_init
        else:
            self.gam_diag_init = initializers.get(gam_diag_init)

        self.gam_off_init = initializers.get(gam_off_init)
        self.mov_mean_init = initializers.get(mov_mean_init)

        if mov_var_init == 'diag_init':
            self.mov_var_init = diag_init
        else:    
            self.mov_var_init = initializers.get(mov_var_init)
            
        self.mov_cov_init = initializers.get(mov_cov_init)
        self.beta_reg = regularizers.get(beta_reg)
        self.gam_diag_reg = regularizers.get(gam_diag_reg)
        self.gam_off_reg = regularizers.get(gam_off_reg)
        self.activation = activations.get(activation)
        self.activation_position = activation_position
        self.epsilon = epsilon

    def build(self, input_shape):
        input_dim = input_shape[-1] // 4
        vars_shape = [input_dim, 1]
        gamma_shape = (input_dim,)

        if self.scale:
            self.mov_Vrr = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vrr")
            self.mov_Vri = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vri")
            self.mov_Vrj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrj")
            self.mov_Vrk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrk")
            self.mov_Vii = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vii")
            self.mov_Vij = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vij")
            self.mov_Vik = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vik")
            self.mov_Vjj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vjj")
            self.mov_Vjk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vjk")
            self.mov_Vkk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vkk")

            self.gam_rr = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_rr")
            self.gam_ri = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ri")
            self.gam_rj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rj")
            self.gam_rk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rk")
            self.gam_ii = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_ii")
            self.gam_ij = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ij")
            self.gam_ik = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ik")
            self.gam_jj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_jj")
            self.gam_jk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_jk")
            self.gam_kk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_kk")
        else:
            self.mov_Vrr = None
            self.mov_Vri = None
            self.mov_Vrj = None
            self.mov_Vrk = None
            self.mov_Vii = None
            self.mov_Vij = None
            self.mov_Vik = None
            self.mov_Vjj = None
            self.mov_Vjk = None
            self.mov_Vkk = None
            self.gam_rr = None
            self.gam_ri = None
            self.gam_rj = None
            self.gam_rk = None
            self.gam_ii = None
            self.gam_ij = None
            self.gam_ik = None
            self.gam_jj = None
            self.gam_jk = None
            self.gam_kk = None

        if self.center:
            self.beta = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                        initializer=self.beta_init,
                                        regularizer=self.beta_reg,
                                        name="beta")
            self.mov_mean = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                            initializer=self.mov_mean_init,
                                            trainable=False,
                                            name="mov_mean")
        else:
            self.beta = None
            self.mov_mean = None

    def _compute_variances(self, centered_r, centered_i, centered_j, centered_k, input_dim):
        Vrr = kr.backend.mean(
            centered_r ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vri = kr.backend.mean(
            centered_r * centered_i,
            axis=[0, 1, 2]
        )

        Vrj = kr.backend.mean(
            centered_r * centered_j,
            axis=[0, 1, 2]
        )

        Vrk = kr.backend.mean(
            centered_r * centered_k,
            axis=[0, 1, 2]
        )

        Vii = kr.backend.mean(
            centered_i ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vij = kr.backend.mean(
            centered_i * centered_j,
            axis=[0, 1, 2]
        )

        Vik = kr.backend.mean(
            centered_i * centered_k,
            axis=[0, 1, 2]
        )

        Vjj = kr.backend.mean(
            centered_j ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vjk = kr.backend.mean(
            centered_j * centered_k,
            axis=[0, 1, 2]
        )

        Vkk = kr.backend.mean(
            centered_k ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        pars_shape = [input_dim, 1]
        Vrr = tf.reshape(Vrr, pars_shape)
        Vri = tf.reshape(Vri, pars_shape)
        Vrj = tf.reshape(Vrj, pars_shape)
        Vrk = tf.reshape(Vrk, pars_shape)
        Vii = tf.reshape(Vii, pars_shape)
        Vij = tf.reshape(Vij, pars_shape)
        Vik = tf.reshape(Vik, pars_shape)
        Vjj = tf.reshape(Vjj, pars_shape)
        Vjk = tf.reshape(Vjk, pars_shape)
        Vkk = tf.reshape(Vkk, pars_shape)

        return Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk
    
    def _moving_exponential_update(self, var, value):
        decay = 1 - self.momentum
        var.assign_sub(var * decay)
        var.assign_add(value * decay)

    def _update_moving_parameters(self, mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk):
        if self.center:
            self._moving_exponential_update(self.mov_mean, mean)

        if self.scale:
            self._moving_exponential_update(self.mov_Vrr, Vrr)
            self._moving_exponential_update(self.mov_Vri, Vri)
            self._moving_exponential_update(self.mov_Vrj, Vrj)
            self._moving_exponential_update(self.mov_Vrk, Vrk)
            self._moving_exponential_update(self.mov_Vii, Vii)
            self._moving_exponential_update(self.mov_Vij, Vij)
            self._moving_exponential_update(self.mov_Vik, Vik)
            self._moving_exponential_update(self.mov_Vjj, Vjj)
            self._moving_exponential_update(self.mov_Vjk, Vjk)
            self._moving_exponential_update(self.mov_Vkk, Vkk)

    def call(self, inputs, training=None):
        if (not self.center) or (not self.scale):
            raise ValueError("Batch Normalization should scale or center.")

        input_shape = kr.backend.int_shape(inputs)
        input_dim = input_shape[-1] // 4

        # Activation before
        if self.activation_position == "before":
            output = self.activation(inputs)
        else:
            output = inputs

        if training in {0, False}:
            mean = self.mov_mean
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr = self.mov_Vrr
                Vri = self.mov_Vri
                Vrj = self.mov_Vrj
                Vrk = self.mov_Vrk
                Vii = self.mov_Vii
                Vij = self.mov_Vij
                Vik = self.mov_Vik
                Vjj = self.mov_Vjj
                Vjk = self.mov_Vjk
                Vkk = self.mov_Vkk
        else:
            # mean and centering
            mean = kr.backend.mean(output, axis=[0, 1, 2])
            mean = kr.backend.reshape(mean, [1, 1, 1, input_dim * 4])
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = self._compute_variances(centered_r, centered_i, centered_j, centered_k, input_dim)
            else:
                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = [None for i in range(10)]  

            self._update_moving_parameters(mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk)

        if self.scale:
            var_reshape = [input_dim, 1, 4]
            # covariance matrix
            V = tf.concat([[tf.reshape(tf.concat([Vrr, Vri, Vrj, Vrk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vri, Vii, Vij, Vik], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrj, Vij, Vjj, Vjk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrk, Vik, Vjk, Vkk], axis=1), var_reshape)]], axis=2)

            # Whitening
            R = tf.reshape(tf.linalg.cholesky(V), [input_dim, 4, 4])
            W = tf.linalg.inv(tf.transpose(R, perm=[0,2,1]))

            Wrr = W[:,0,0]
            Wri = W[:,0,1]
            Wrj = W[:,0,2]
            Wrk = W[:,0,3]
            Wii = W[:,1,1]
            Wij = W[:,1,2]
            Wik = W[:,1,3]
            Wjj = W[:,2,2]
            Wjk = W[:,2,3]
            Wkk = W[:,3,3]

            output_r = centered_r * Wrr
            output_i = centered_r * Wri + centered_i * Wii
            output_j = centered_r * Wrj + centered_i * Wij + centered_j * Wjj
            output_k = centered_r * Wrk + centered_i * Wik + centered_j * Wjk + centered_k * Wkk

            if self.activation_position == "middle":
                output_r = self.activation(output_r)
                output_i = self.activation(output_i)
                output_j = self.activation(output_j)
                output_k = self.activation(output_k)

            out_r = output_r * self.gam_rr
            out_i = output_r * self.gam_ri + output_i * self.gam_ii
            out_j = output_r * self.gam_rj + output_i * self.gam_ij + output_j * self.gam_jj
            out_k = output_r * self.gam_rk + output_i * self.gam_ik + output_j * self.gam_jk + output_k * self.gam_kk
            output = tf.concat([out_r, out_i, out_j, out_k], axis=-1)
        else:
            output = centered
            if self.activation_position == "middle":
                output = self.activation(output)

        if self.center:
            output = output + self.beta

        if self.activation_position == "after":
            output = self.activation(output)

        return output

# %%
DefaultConvQuat = partial(QuatConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class QuatResidualUnit(layers.Layer):
    """ 
    Quaternion valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recognition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual networks.
    """
    def __init__(self, filters, strides=1, activation="elu", activation_position="after", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvQuat(filters, strides=strides),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position), 
            DefaultConvQuat(filters),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position),]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvQuat(filters, kernel_size=(1,1), strides=strides),
                Hypercomplex4DBNActivation(activation=None, activation_position='no_activation')]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"
activation_position = 'after'

quat_resnet = kr.models.Sequential()
quat_resnet.add(DefaultConvQuat(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    quat_resnet.add(QuatResidualUnit(filters, strides=strides, activation=activation, activation_position=activation_position))
    prev_filters = filters
quat_resnet.add(kr.layers.GlobalAvgPool2D())
quat_resnet.add(kr.layers.Flatten())
quat_resnet.add(kr.layers.Dense(10, activation="softmax"))
quat_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

quat_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 133s 239ms/step - loss: 2.3652 - accuracy: 0.2932 - val_loss: 2.5703 - val_accuracy: 0.1987
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 2.1019 - accuracy: 0.3887 - val_loss: 2.4510 - val_accuracy: 0.2342
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 1.9956 - accuracy: 0.4261 - val_loss: 3.3656 - val_accuracy: 0.2196
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 1.9186 - accuracy: 0.4538 - val_loss: 2.4553 - val_accuracy: 0.2850
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 1.8558 - accuracy: 0.4795 - val_loss: 2.2993 - val_accuracy: 0.3106
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 1.8008 - accuracy: 0.4924 - val_loss: 3.2573 - val_accuracy: 0.1737
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 226ms/step - loss: 1.7570 - accuracy: 0.5105 - val_loss: 3.0753 - val_accuracy: 0.2736
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 226ms/step - loss: 1.7139 - accuracy: 0.5223 - val_loss: 2.7008 - val_accuracy: 0.2711
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 1.6774 - accuracy: 0.5365 - val_loss: 3.2903 - val_accuracy: 0.2531
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 226ms/step - loss: 1.6411 - accuracy: 0.5466 - val_loss: 2.2959 - val_accuracy: 0.3585
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 1.8002 - accuracy: 0.4845 - val_loss: 2.4128 - val_accuracy: 0.3103
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 1.5757 - accuracy: 0.5514 - val_loss: 2.5363 - val_accuracy: 0.3097
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 1.4511 - accuracy: 0.5884 - val_loss: 2.7500 - val_accuracy: 0.3092
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 1.3545 - accuracy: 0.6174 - val_loss: 1.8186 - val_accuracy: 0.4805
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.2671 - accuracy: 0.6409 - val_loss: 2.2879 - val_accuracy: 0.3916
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 1.2032 - accuracy: 0.6556 - val_loss: 1.8467 - val_accuracy: 0.4724
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 1.1421 - accuracy: 0.6730 - val_loss: 2.6739 - val_accuracy: 0.3335
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.0919 - accuracy: 0.6875 - val_loss: 2.0110 - val_accuracy: 0.4426
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.0492 - accuracy: 0.7002 - val_loss: 2.0539 - val_accuracy: 0.4253
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.0083 - accuracy: 0.7105 - val_loss: 1.4119 - val_accuracy: 0.5751
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.9678 - accuracy: 0.7257 - val_loss: 1.2930 - val_accuracy: 0.6036
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 226ms/step - loss: 0.9369 - accuracy: 0.7322 - val_loss: 1.1531 - val_accuracy: 0.6574
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.9091 - accuracy: 0.7424 - val_loss: 1.2912 - val_accuracy: 0.6185
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.8823 - accuracy: 0.7514 - val_loss: 0.9797 - val_accuracy: 0.7188
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 233ms/step - loss: 0.8598 - accuracy: 0.7590 - val_loss: 2.5194 - val_accuracy: 0.4265
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 226ms/step - loss: 0.8342 - accuracy: 0.7671 - val_loss: 1.1049 - val_accuracy: 0.6897
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.8219 - accuracy: 0.7690 - val_loss: 1.1152 - val_accuracy: 0.6845
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.8093 - accuracy: 0.7726 - val_loss: 1.0465 - val_accuracy: 0.6974
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.7953 - accuracy: 0.7800 - val_loss: 1.2205 - val_accuracy: 0.6498
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.7822 - accuracy: 0.7838 - val_loss: 1.4359 - val_accuracy: 0.5882
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.7738 - accuracy: 0.7863 - val_loss: 1.0492 - val_accuracy: 0.7014
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 226ms/step - loss: 0.7599 - accuracy: 0.7910 - val_loss: 1.0334 - val_accuracy: 0.7025
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.7501 - accuracy: 0.7946 - val_loss: 1.2098 - val_accuracy: 0.6552
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.7432 - accuracy: 0.7958 - val_loss: 1.0054 - val_accuracy: 0.7162
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 234ms/step - loss: 0.7331 - accuracy: 0.7990 - val_loss: 1.1466 - val_accuracy: 0.6811
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.7242 - accuracy: 0.8041 - val_loss: 1.1788 - val_accuracy: 0.6597
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.7167 - accuracy: 0.8061 - val_loss: 1.3484 - val_accuracy: 0.6151
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.7116 - accuracy: 0.8086 - val_loss: 0.9232 - val_accuracy: 0.7353
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.7029 - accuracy: 0.8104 - val_loss: 0.9960 - val_accuracy: 0.7196
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.6973 - accuracy: 0.8140 - val_loss: 0.8830 - val_accuracy: 0.7487
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6921 - accuracy: 0.8141 - val_loss: 0.9166 - val_accuracy: 0.7508
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6870 - accuracy: 0.8153 - val_loss: 1.0366 - val_accuracy: 0.7025
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6821 - accuracy: 0.8170 - val_loss: 0.8838 - val_accuracy: 0.7552
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 0.6728 - accuracy: 0.8216 - val_loss: 0.8938 - val_accuracy: 0.7494
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.6730 - accuracy: 0.8215 - val_loss: 1.0554 - val_accuracy: 0.7063
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 224ms/step - loss: 0.6692 - accuracy: 0.8237 - val_loss: 0.9216 - val_accuracy: 0.7444
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6615 - accuracy: 0.8262 - val_loss: 1.1648 - val_accuracy: 0.6764
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6579 - accuracy: 0.8255 - val_loss: 0.9776 - val_accuracy: 0.7198
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6567 - accuracy: 0.8268 - val_loss: 0.9804 - val_accuracy: 0.7304
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6545 - accuracy: 0.8284 - val_loss: 0.9840 - val_accuracy: 0.7145
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6493 - accuracy: 0.8280 - val_loss: 0.9343 - val_accuracy: 0.7333
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6411 - accuracy: 0.8334 - val_loss: 0.9266 - val_accuracy: 0.7388
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.6451 - accuracy: 0.8308 - val_loss: 0.9347 - val_accuracy: 0.7357
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6389 - accuracy: 0.8336 - val_loss: 1.3671 - val_accuracy: 0.6127
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6378 - accuracy: 0.8351 - val_loss: 1.8279 - val_accuracy: 0.5406
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6346 - accuracy: 0.8370 - val_loss: 1.0270 - val_accuracy: 0.6999
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6263 - accuracy: 0.8388 - val_loss: 0.9005 - val_accuracy: 0.7517
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.6275 - accuracy: 0.8395 - val_loss: 0.8931 - val_accuracy: 0.7551
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.6255 - accuracy: 0.8387 - val_loss: 0.8877 - val_accuracy: 0.7503
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6210 - accuracy: 0.8411 - val_loss: 0.9315 - val_accuracy: 0.7413
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 0.6227 - accuracy: 0.8416 - val_loss: 0.9969 - val_accuracy: 0.7186
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6190 - accuracy: 0.8429 - val_loss: 0.9634 - val_accuracy: 0.7527
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 0.6146 - accuracy: 0.8428 - val_loss: 0.9355 - val_accuracy: 0.7364
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6057 - accuracy: 0.8451 - val_loss: 1.0719 - val_accuracy: 0.7121
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.6104 - accuracy: 0.8464 - val_loss: 0.8773 - val_accuracy: 0.7648
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6017 - accuracy: 0.8479 - val_loss: 0.9758 - val_accuracy: 0.7226
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6075 - accuracy: 0.8473 - val_loss: 0.9300 - val_accuracy: 0.7406
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6031 - accuracy: 0.8490 - val_loss: 0.9746 - val_accuracy: 0.7356
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5981 - accuracy: 0.8497 - val_loss: 0.9273 - val_accuracy: 0.7449
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5990 - accuracy: 0.8492 - val_loss: 0.8257 - val_accuracy: 0.7832
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5923 - accuracy: 0.8507 - val_loss: 1.1657 - val_accuracy: 0.6984
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5938 - accuracy: 0.8510 - val_loss: 0.9250 - val_accuracy: 0.7500
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5955 - accuracy: 0.8508 - val_loss: 1.1341 - val_accuracy: 0.6866
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5939 - accuracy: 0.8516 - val_loss: 0.8027 - val_accuracy: 0.7837
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5905 - accuracy: 0.8538 - val_loss: 1.0232 - val_accuracy: 0.7199
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 232ms/step - loss: 0.5889 - accuracy: 0.8524 - val_loss: 0.8776 - val_accuracy: 0.7646
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5864 - accuracy: 0.8544 - val_loss: 0.8193 - val_accuracy: 0.7816
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5849 - accuracy: 0.8527 - val_loss: 1.1636 - val_accuracy: 0.6926
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5817 - accuracy: 0.8559 - val_loss: 0.8005 - val_accuracy: 0.7813
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5851 - accuracy: 0.8540 - val_loss: 1.0038 - val_accuracy: 0.7335
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5829 - accuracy: 0.8569 - val_loss: 1.0058 - val_accuracy: 0.7246
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 232ms/step - loss: 0.5776 - accuracy: 0.8577 - val_loss: 0.7885 - val_accuracy: 0.7910
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5814 - accuracy: 0.8547 - val_loss: 1.0633 - val_accuracy: 0.7239
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5786 - accuracy: 0.8569 - val_loss: 0.7936 - val_accuracy: 0.7902
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5753 - accuracy: 0.8569 - val_loss: 1.0065 - val_accuracy: 0.7262
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5751 - accuracy: 0.8584 - val_loss: 0.9368 - val_accuracy: 0.7406
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5761 - accuracy: 0.8579 - val_loss: 0.8416 - val_accuracy: 0.7780
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 232ms/step - loss: 0.5724 - accuracy: 0.8587 - val_loss: 1.1024 - val_accuracy: 0.7003
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5717 - accuracy: 0.8597 - val_loss: 0.8573 - val_accuracy: 0.7686
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5665 - accuracy: 0.8616 - val_loss: 1.1991 - val_accuracy: 0.6641
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5686 - accuracy: 0.8601 - val_loss: 1.0605 - val_accuracy: 0.7062
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5646 - accuracy: 0.8615 - val_loss: 0.7519 - val_accuracy: 0.8024
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5637 - accuracy: 0.8643 - val_loss: 0.8708 - val_accuracy: 0.7661
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5683 - accuracy: 0.8610 - val_loss: 0.8334 - val_accuracy: 0.7744
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5667 - accuracy: 0.8621 - val_loss: 0.8484 - val_accuracy: 0.7716
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5650 - accuracy: 0.8625 - val_loss: 0.7573 - val_accuracy: 0.7933
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5634 - accuracy: 0.8643 - val_loss: 0.9545 - val_accuracy: 0.7428
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5622 - accuracy: 0.8634 - val_loss: 0.8097 - val_accuracy: 0.7911
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5552 - accuracy: 0.8655 - val_loss: 1.0436 - val_accuracy: 0.7242
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5609 - accuracy: 0.8643 - val_loss: 1.1912 - val_accuracy: 0.6613
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.5562 - accuracy: 0.8661 - val_loss: 1.2900 - val_accuracy: 0.6559
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5555 - accuracy: 0.8649 - val_loss: 0.8722 - val_accuracy: 0.7615
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5595 - accuracy: 0.8650 - val_loss: 0.8677 - val_accuracy: 0.7777
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5531 - accuracy: 0.8660 - val_loss: 0.8131 - val_accuracy: 0.7875
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.5577 - accuracy: 0.8648 - val_loss: 0.8436 - val_accuracy: 0.7787
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5505 - accuracy: 0.8676 - val_loss: 1.1364 - val_accuracy: 0.6820
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5524 - accuracy: 0.8676 - val_loss: 1.1730 - val_accuracy: 0.7179
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5519 - accuracy: 0.8670 - val_loss: 0.7772 - val_accuracy: 0.7948
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5521 - accuracy: 0.8668 - val_loss: 0.9538 - val_accuracy: 0.7477
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.5482 - accuracy: 0.8675 - val_loss: 0.9632 - val_accuracy: 0.7370
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5483 - accuracy: 0.8681 - val_loss: 0.9309 - val_accuracy: 0.7510
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5467 - accuracy: 0.8701 - val_loss: 0.7324 - val_accuracy: 0.8147
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5450 - accuracy: 0.8717 - val_loss: 0.7519 - val_accuracy: 0.8018
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5442 - accuracy: 0.8703 - val_loss: 1.1024 - val_accuracy: 0.7148
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5413 - accuracy: 0.8716 - val_loss: 0.9556 - val_accuracy: 0.7305
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5435 - accuracy: 0.8691 - val_loss: 0.8980 - val_accuracy: 0.7562
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5423 - accuracy: 0.8709 - val_loss: 0.7964 - val_accuracy: 0.7898
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 0.5469 - accuracy: 0.8690 - val_loss: 1.1754 - val_accuracy: 0.7004
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5416 - accuracy: 0.8713 - val_loss: 1.0777 - val_accuracy: 0.7119
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5393 - accuracy: 0.8735 - val_loss: 1.9048 - val_accuracy: 0.5342
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5443 - accuracy: 0.8681 - val_loss: 0.9227 - val_accuracy: 0.7563
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5390 - accuracy: 0.8721 - val_loss: 0.9680 - val_accuracy: 0.7448
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5393 - accuracy: 0.8727 - val_loss: 0.8519 - val_accuracy: 0.7826
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.5361 - accuracy: 0.8740 - val_loss: 1.1918 - val_accuracy: 0.7116
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5366 - accuracy: 0.8729 - val_loss: 0.7352 - val_accuracy: 0.8120
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5376 - accuracy: 0.8724 - val_loss: 0.9198 - val_accuracy: 0.7565
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 226ms/step - loss: 0.5341 - accuracy: 0.8742 - val_loss: 0.8015 - val_accuracy: 0.8002
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5355 - accuracy: 0.8742 - val_loss: 0.7664 - val_accuracy: 0.8026
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5337 - accuracy: 0.8744 - val_loss: 0.9680 - val_accuracy: 0.7402
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5328 - accuracy: 0.8746 - val_loss: 0.8428 - val_accuracy: 0.7769
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5347 - accuracy: 0.8730 - val_loss: 0.8655 - val_accuracy: 0.7622
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5328 - accuracy: 0.8731 - val_loss: 0.9591 - val_accuracy: 0.7419
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5348 - accuracy: 0.8740 - val_loss: 0.9645 - val_accuracy: 0.7416
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5312 - accuracy: 0.8752 - val_loss: 0.8889 - val_accuracy: 0.7593
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5316 - accuracy: 0.8740 - val_loss: 0.8975 - val_accuracy: 0.7781
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5342 - accuracy: 0.8742 - val_loss: 0.9302 - val_accuracy: 0.7492
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5320 - accuracy: 0.8750 - val_loss: 0.7918 - val_accuracy: 0.7947
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.5253 - accuracy: 0.8776 - val_loss: 0.8324 - val_accuracy: 0.7726
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5301 - accuracy: 0.8738 - val_loss: 1.0891 - val_accuracy: 0.7017
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5279 - accuracy: 0.8755 - val_loss: 1.0606 - val_accuracy: 0.7218
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 232ms/step - loss: 0.5295 - accuracy: 0.8747 - val_loss: 0.8310 - val_accuracy: 0.7873
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5311 - accuracy: 0.8749 - val_loss: 0.8296 - val_accuracy: 0.7906
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5231 - accuracy: 0.8776 - val_loss: 0.9051 - val_accuracy: 0.7689
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5275 - accuracy: 0.8764 - val_loss: 0.7963 - val_accuracy: 0.7945
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5277 - accuracy: 0.8761 - val_loss: 1.1354 - val_accuracy: 0.7080
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5270 - accuracy: 0.8773 - val_loss: 1.2511 - val_accuracy: 0.6942
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.5221 - accuracy: 0.8784 - val_loss: 1.8510 - val_accuracy: 0.5854
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.5239 - accuracy: 0.8776 - val_loss: 0.9316 - val_accuracy: 0.7599
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5221 - accuracy: 0.8782 - val_loss: 1.2818 - val_accuracy: 0.7043
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 0.5230 - accuracy: 0.8780 - val_loss: 0.8884 - val_accuracy: 0.7681
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 87s 223ms/step - loss: 0.5233 - accuracy: 0.8779 - val_loss: 1.0237 - val_accuracy: 0.7403
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.4260 - accuracy: 0.9120 - val_loss: 0.6538 - val_accuracy: 0.8350
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.3899 - accuracy: 0.9249 - val_loss: 0.6672 - val_accuracy: 0.8318
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.3855 - accuracy: 0.9247 - val_loss: 0.6161 - val_accuracy: 0.8483
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 0.3750 - accuracy: 0.9277 - val_loss: 0.6029 - val_accuracy: 0.8477
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 226ms/step - loss: 0.3686 - accuracy: 0.9293 - val_loss: 0.6173 - val_accuracy: 0.8459
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 226ms/step - loss: 0.3592 - accuracy: 0.9316 - val_loss: 0.6334 - val_accuracy: 0.8423
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.3570 - accuracy: 0.9320 - val_loss: 0.6276 - val_accuracy: 0.8415
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.3531 - accuracy: 0.9320 - val_loss: 0.6246 - val_accuracy: 0.8436
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 229ms/step - loss: 0.3449 - accuracy: 0.9351 - val_loss: 0.6145 - val_accuracy: 0.8433
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 0.3403 - accuracy: 0.9356 - val_loss: 0.6257 - val_accuracy: 0.8388
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.3361 - accuracy: 0.9352 - val_loss: 0.6522 - val_accuracy: 0.8321
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3347 - accuracy: 0.9362 - val_loss: 0.6323 - val_accuracy: 0.8388
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.3312 - accuracy: 0.9350 - val_loss: 0.6376 - val_accuracy: 0.8350
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.3272 - accuracy: 0.9363 - val_loss: 0.6402 - val_accuracy: 0.8363
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 229ms/step - loss: 0.3215 - accuracy: 0.9366 - val_loss: 0.6121 - val_accuracy: 0.8422
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3214 - accuracy: 0.9363 - val_loss: 0.6015 - val_accuracy: 0.8467
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 92s 234ms/step - loss: 0.3124 - accuracy: 0.9387 - val_loss: 0.5939 - val_accuracy: 0.8462
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 0.3140 - accuracy: 0.9368 - val_loss: 0.6086 - val_accuracy: 0.8459
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.3103 - accuracy: 0.9391 - val_loss: 0.6025 - val_accuracy: 0.8446
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 0.3090 - accuracy: 0.9391 - val_loss: 0.6436 - val_accuracy: 0.8340
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 231ms/step - loss: 0.3058 - accuracy: 0.9387 - val_loss: 0.6158 - val_accuracy: 0.8409
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.3036 - accuracy: 0.9381 - val_loss: 0.5833 - val_accuracy: 0.8503
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3009 - accuracy: 0.9387 - val_loss: 0.6342 - val_accuracy: 0.8382
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2945 - accuracy: 0.9414 - val_loss: 0.5928 - val_accuracy: 0.8497
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 233ms/step - loss: 0.2964 - accuracy: 0.9396 - val_loss: 0.6189 - val_accuracy: 0.8405
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 233ms/step - loss: 0.2913 - accuracy: 0.9412 - val_loss: 0.6384 - val_accuracy: 0.8304
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2896 - accuracy: 0.9415 - val_loss: 0.6367 - val_accuracy: 0.8365
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 231ms/step - loss: 0.2897 - accuracy: 0.9404 - val_loss: 0.5889 - val_accuracy: 0.8482
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2838 - accuracy: 0.9418 - val_loss: 0.6719 - val_accuracy: 0.8216
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2832 - accuracy: 0.9418 - val_loss: 0.6207 - val_accuracy: 0.8343
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2821 - accuracy: 0.9408 - val_loss: 0.6369 - val_accuracy: 0.8354
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2801 - accuracy: 0.9408 - val_loss: 0.6111 - val_accuracy: 0.8409
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2780 - accuracy: 0.9420 - val_loss: 0.6492 - val_accuracy: 0.8278
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2770 - accuracy: 0.9433 - val_loss: 0.6369 - val_accuracy: 0.8305
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2735 - accuracy: 0.9421 - val_loss: 0.6221 - val_accuracy: 0.8399
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2741 - accuracy: 0.9417 - val_loss: 0.6185 - val_accuracy: 0.8351
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2721 - accuracy: 0.9417 - val_loss: 0.7025 - val_accuracy: 0.8168
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2691 - accuracy: 0.9421 - val_loss: 0.5814 - val_accuracy: 0.8490
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 234ms/step - loss: 0.2689 - accuracy: 0.9432 - val_loss: 0.6518 - val_accuracy: 0.8266
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 226ms/step - loss: 0.2676 - accuracy: 0.9430 - val_loss: 0.6239 - val_accuracy: 0.8346
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2645 - accuracy: 0.9437 - val_loss: 0.5971 - val_accuracy: 0.8410
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2648 - accuracy: 0.9427 - val_loss: 0.7143 - val_accuracy: 0.8148
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2635 - accuracy: 0.9426 - val_loss: 0.6288 - val_accuracy: 0.8314
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2615 - accuracy: 0.9426 - val_loss: 0.5977 - val_accuracy: 0.8407
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2597 - accuracy: 0.9433 - val_loss: 0.6366 - val_accuracy: 0.8322
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 227ms/step - loss: 0.2615 - accuracy: 0.9425 - val_loss: 0.7317 - val_accuracy: 0.8079
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2605 - accuracy: 0.9436 - val_loss: 0.6453 - val_accuracy: 0.8283
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2569 - accuracy: 0.9439 - val_loss: 0.7389 - val_accuracy: 0.8074
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2533 - accuracy: 0.9451 - val_loss: 0.6556 - val_accuracy: 0.8241
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 227ms/step - loss: 0.2394 - accuracy: 0.9500 - val_loss: 0.6193 - val_accuracy: 0.8367
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2309 - accuracy: 0.9525 - val_loss: 0.5946 - val_accuracy: 0.8431
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2265 - accuracy: 0.9544 - val_loss: 0.6182 - val_accuracy: 0.8370
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2220 - accuracy: 0.9564 - val_loss: 0.6109 - val_accuracy: 0.8371
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2226 - accuracy: 0.9563 - val_loss: 0.6134 - val_accuracy: 0.8357
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2210 - accuracy: 0.9574 - val_loss: 0.6069 - val_accuracy: 0.8377
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2206 - accuracy: 0.9574 - val_loss: 0.6005 - val_accuracy: 0.8395
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2227 - accuracy: 0.9565 - val_loss: 0.5924 - val_accuracy: 0.8418
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2195 - accuracy: 0.9578 - val_loss: 0.6023 - val_accuracy: 0.8379
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2182 - accuracy: 0.9576 - val_loss: 0.6061 - val_accuracy: 0.8382
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2180 - accuracy: 0.9574 - val_loss: 0.6066 - val_accuracy: 0.8391
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2198 - accuracy: 0.9566 - val_loss: 0.5994 - val_accuracy: 0.8406
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2177 - accuracy: 0.9586 - val_loss: 0.6017 - val_accuracy: 0.8407
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2153 - accuracy: 0.9580 - val_loss: 0.6054 - val_accuracy: 0.8390
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2185 - accuracy: 0.9569 - val_loss: 0.6168 - val_accuracy: 0.8359
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2157 - accuracy: 0.9591 - val_loss: 0.6047 - val_accuracy: 0.8392
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2147 - accuracy: 0.9581 - val_loss: 0.6023 - val_accuracy: 0.8392
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2129 - accuracy: 0.9588 - val_loss: 0.6141 - val_accuracy: 0.8360
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 227ms/step - loss: 0.2163 - accuracy: 0.9589 - val_loss: 0.6227 - val_accuracy: 0.8347
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2161 - accuracy: 0.9592 - val_loss: 0.6075 - val_accuracy: 0.8387
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 231ms/step - loss: 0.2123 - accuracy: 0.9598 - val_loss: 0.6238 - val_accuracy: 0.8341
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2126 - accuracy: 0.9593 - val_loss: 0.6242 - val_accuracy: 0.8329
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2158 - accuracy: 0.9565 - val_loss: 0.6141 - val_accuracy: 0.8378
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2140 - accuracy: 0.9594 - val_loss: 0.6268 - val_accuracy: 0.8327
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2111 - accuracy: 0.9594 - val_loss: 0.6277 - val_accuracy: 0.8324
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2140 - accuracy: 0.9583 - val_loss: 0.6126 - val_accuracy: 0.8363
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2100 - accuracy: 0.9605 - val_loss: 0.6406 - val_accuracy: 0.8289
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2118 - accuracy: 0.9590 - val_loss: 0.6126 - val_accuracy: 0.8364
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2099 - accuracy: 0.9601 - val_loss: 0.5969 - val_accuracy: 0.8414
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2092 - accuracy: 0.9595 - val_loss: 0.6171 - val_accuracy: 0.8358
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2096 - accuracy: 0.9593 - val_loss: 0.6137 - val_accuracy: 0.8378
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2099 - accuracy: 0.9589 - val_loss: 0.6215 - val_accuracy: 0.8335
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2095 - accuracy: 0.9582 - val_loss: 0.6028 - val_accuracy: 0.8404
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2102 - accuracy: 0.9592 - val_loss: 0.6153 - val_accuracy: 0.8371
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2107 - accuracy: 0.9581 - val_loss: 0.6060 - val_accuracy: 0.8402
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2069 - accuracy: 0.9614 - val_loss: 0.6170 - val_accuracy: 0.8366
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2103 - accuracy: 0.9591 - val_loss: 0.6234 - val_accuracy: 0.8335
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2106 - accuracy: 0.9581 - val_loss: 0.6203 - val_accuracy: 0.8369
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2065 - accuracy: 0.9608 - val_loss: 0.6133 - val_accuracy: 0.8373
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2082 - accuracy: 0.9591 - val_loss: 0.6249 - val_accuracy: 0.8342
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 92s 234ms/step - loss: 0.2063 - accuracy: 0.9593 - val_loss: 0.6382 - val_accuracy: 0.8324
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2073 - accuracy: 0.9593 - val_loss: 0.6311 - val_accuracy: 0.8331
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 88s 225ms/step - loss: 0.2048 - accuracy: 0.9607 - val_loss: 0.6096 - val_accuracy: 0.8397
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2065 - accuracy: 0.9598 - val_loss: 0.6393 - val_accuracy: 0.8329
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2039 - accuracy: 0.9611 - val_loss: 0.6207 - val_accuracy: 0.8370
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2048 - accuracy: 0.9605 - val_loss: 0.6026 - val_accuracy: 0.8421
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2044 - accuracy: 0.9609 - val_loss: 0.6191 - val_accuracy: 0.8365
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2061 - accuracy: 0.9598 - val_loss: 0.6248 - val_accuracy: 0.8339
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2032 - accuracy: 0.9614 - val_loss: 0.6367 - val_accuracy: 0.8301
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2034 - accuracy: 0.9607 - val_loss: 0.6136 - val_accuracy: 0.8399

# %%
quat_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quat_conv2d (QuatConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# quat_residual_unit (QuatResi (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_1 (QuatRe (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_2 (QuatRe (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_3 (QuatRe (None, None, None, 48)    9072
# _________________________________________________________________
# quat_residual_unit_4 (QuatRe (None, None, None, 48)    11040
# _________________________________________________________________
# quat_residual_unit_5 (QuatRe (None, None, None, 96)    34272
# _________________________________________________________________
# quat_residual_unit_6 (QuatRe (None, None, None, 96)    42816
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 107,170
# Trainable params: 104,146
# Non-trainable params: 3,024
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(quat_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96522

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(quat_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8399
