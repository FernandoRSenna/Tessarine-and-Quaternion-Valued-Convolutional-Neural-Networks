# %% [markdown]
# # Quaternion Valued CNN with Hypercomplex Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class QuatConv2D(layers.Layer):
    """
    Quaternion valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer(),
                 data_format=None,
                 kernel_regularizer=1e-4):
        super(QuatConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        self.kernel_regularizer = kernel_regularizer
        
    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('QuatConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        # Filter multiplied from the right!
        F_r = tf.concat([ self.f0,-self.f1,-self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3,-self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0, self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2,-self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
def diag_init(shape, dtype=None):
    return tf.ones(shape) / 2.

class Hypercomplex4DBNActivation(layers.Layer):
    """
    Batch Normalization for tessarines and quaternions.
    Based on matrix whitening. Decorrelates each component of tessarine/quaternion.
    Includes activation: can be placed before, after or in the middle of BN.
    References:
    [1] Ioffe, S. and Szegedy, C. (2015). Batch normalization: Accelerating deep network training by reducing internal covariate shift.
    [2] Kessy, A., Lewin, A., and Strimmer, K. (2018). Optimal whitening and decorrelation. The American Statistician, 72(4):309–314.
    [3] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Ros-tamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [4] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self,
                 center=True,
                 scale=True,
                 momentum=0.9,
                 beta_init='zeros',
                 gam_diag_init='diag_init',
                 gam_off_init='zeros',
                 mov_mean_init='zeros',
                 mov_var_init='diag_init',
                 mov_cov_init='zeros',
                 beta_reg=None,
                 gam_diag_reg=None,
                 gam_off_reg=None,
                 activation="elu",
                 activation_position="after",
                 epsilon=1e-6,
                 **kwargs):
        super(Hypercomplex4DBNActivation, self).__init__(**kwargs)
        self.center = center
        self.scale = scale
        self.momentum = momentum
        self.beta_init = initializers.get(beta_init)

        if gam_diag_init == 'diag_init':
            self.gam_diag_init = diag_init
        else:
            self.gam_diag_init = initializers.get(gam_diag_init)

        self.gam_off_init = initializers.get(gam_off_init)
        self.mov_mean_init = initializers.get(mov_mean_init)

        if mov_var_init == 'diag_init':
            self.mov_var_init = diag_init
        else:    
            self.mov_var_init = initializers.get(mov_var_init)
            
        self.mov_cov_init = initializers.get(mov_cov_init)
        self.beta_reg = regularizers.get(beta_reg)
        self.gam_diag_reg = regularizers.get(gam_diag_reg)
        self.gam_off_reg = regularizers.get(gam_off_reg)
        self.activation = activations.get(activation)
        self.activation_position = activation_position
        self.epsilon = epsilon

    def build(self, input_shape):
        input_dim = input_shape[-1] // 4
        vars_shape = [input_dim, 1]
        gamma_shape = (input_dim,)

        if self.scale:
            self.mov_Vrr = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vrr")
            self.mov_Vri = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vri")
            self.mov_Vrj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrj")
            self.mov_Vrk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrk")
            self.mov_Vii = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vii")
            self.mov_Vij = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vij")
            self.mov_Vik = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vik")
            self.mov_Vjj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vjj")
            self.mov_Vjk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vjk")
            self.mov_Vkk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vkk")

            self.gam_rr = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_rr")
            self.gam_ri = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ri")
            self.gam_rj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rj")
            self.gam_rk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rk")
            self.gam_ii = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_ii")
            self.gam_ij = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ij")
            self.gam_ik = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ik")
            self.gam_jj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_jj")
            self.gam_jk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_jk")
            self.gam_kk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_kk")
        else:
            self.mov_Vrr = None
            self.mov_Vri = None
            self.mov_Vrj = None
            self.mov_Vrk = None
            self.mov_Vii = None
            self.mov_Vij = None
            self.mov_Vik = None
            self.mov_Vjj = None
            self.mov_Vjk = None
            self.mov_Vkk = None
            self.gam_rr = None
            self.gam_ri = None
            self.gam_rj = None
            self.gam_rk = None
            self.gam_ii = None
            self.gam_ij = None
            self.gam_ik = None
            self.gam_jj = None
            self.gam_jk = None
            self.gam_kk = None

        if self.center:
            self.beta = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                        initializer=self.beta_init,
                                        regularizer=self.beta_reg,
                                        name="beta")
            self.mov_mean = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                            initializer=self.mov_mean_init,
                                            trainable=False,
                                            name="mov_mean")
        else:
            self.beta = None
            self.mov_mean = None

    def _compute_variances(self, centered_r, centered_i, centered_j, centered_k, input_dim):
        Vrr = kr.backend.mean(
            centered_r ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vri = kr.backend.mean(
            centered_r * centered_i,
            axis=[0, 1, 2]
        )

        Vrj = kr.backend.mean(
            centered_r * centered_j,
            axis=[0, 1, 2]
        )

        Vrk = kr.backend.mean(
            centered_r * centered_k,
            axis=[0, 1, 2]
        )

        Vii = kr.backend.mean(
            centered_i ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vij = kr.backend.mean(
            centered_i * centered_j,
            axis=[0, 1, 2]
        )

        Vik = kr.backend.mean(
            centered_i * centered_k,
            axis=[0, 1, 2]
        )

        Vjj = kr.backend.mean(
            centered_j ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vjk = kr.backend.mean(
            centered_j * centered_k,
            axis=[0, 1, 2]
        )

        Vkk = kr.backend.mean(
            centered_k ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        pars_shape = [input_dim, 1]
        Vrr = tf.reshape(Vrr, pars_shape)
        Vri = tf.reshape(Vri, pars_shape)
        Vrj = tf.reshape(Vrj, pars_shape)
        Vrk = tf.reshape(Vrk, pars_shape)
        Vii = tf.reshape(Vii, pars_shape)
        Vij = tf.reshape(Vij, pars_shape)
        Vik = tf.reshape(Vik, pars_shape)
        Vjj = tf.reshape(Vjj, pars_shape)
        Vjk = tf.reshape(Vjk, pars_shape)
        Vkk = tf.reshape(Vkk, pars_shape)

        return Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk
    
    def _moving_exponential_update(self, var, value):
        decay = 1 - self.momentum
        var.assign_sub(var * decay)
        var.assign_add(value * decay)

    def _update_moving_parameters(self, mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk):
        if self.center:
            self._moving_exponential_update(self.mov_mean, mean)

        if self.scale:
            self._moving_exponential_update(self.mov_Vrr, Vrr)
            self._moving_exponential_update(self.mov_Vri, Vri)
            self._moving_exponential_update(self.mov_Vrj, Vrj)
            self._moving_exponential_update(self.mov_Vrk, Vrk)
            self._moving_exponential_update(self.mov_Vii, Vii)
            self._moving_exponential_update(self.mov_Vij, Vij)
            self._moving_exponential_update(self.mov_Vik, Vik)
            self._moving_exponential_update(self.mov_Vjj, Vjj)
            self._moving_exponential_update(self.mov_Vjk, Vjk)
            self._moving_exponential_update(self.mov_Vkk, Vkk)

    def call(self, inputs, training=None):
        if (not self.center) or (not self.scale):
            raise ValueError("Batch Normalization should scale or center.")

        input_shape = kr.backend.int_shape(inputs)
        input_dim = input_shape[-1] // 4

        # Activation before
        if self.activation_position == "before":
            output = self.activation(inputs)
        else:
            output = inputs

        if training in {0, False}:
            mean = self.mov_mean
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr = self.mov_Vrr
                Vri = self.mov_Vri
                Vrj = self.mov_Vrj
                Vrk = self.mov_Vrk
                Vii = self.mov_Vii
                Vij = self.mov_Vij
                Vik = self.mov_Vik
                Vjj = self.mov_Vjj
                Vjk = self.mov_Vjk
                Vkk = self.mov_Vkk
        else:
            # mean and centering
            mean = kr.backend.mean(output, axis=[0, 1, 2])
            mean = kr.backend.reshape(mean, [1, 1, 1, input_dim * 4])
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = self._compute_variances(centered_r, centered_i, centered_j, centered_k, input_dim)
            else:
                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = [None for i in range(10)]  

            self._update_moving_parameters(mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk)

        if self.scale:
            var_reshape = [input_dim, 1, 4]
            # covariance matrix
            V = tf.concat([[tf.reshape(tf.concat([Vrr, Vri, Vrj, Vrk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vri, Vii, Vij, Vik], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrj, Vij, Vjj, Vjk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrk, Vik, Vjk, Vkk], axis=1), var_reshape)]], axis=2)

            # Whitening
            R = tf.reshape(tf.linalg.cholesky(V), [input_dim, 4, 4])
            W = tf.linalg.inv(tf.transpose(R, perm=[0,2,1]))

            Wrr = W[:,0,0]
            Wri = W[:,0,1]
            Wrj = W[:,0,2]
            Wrk = W[:,0,3]
            Wii = W[:,1,1]
            Wij = W[:,1,2]
            Wik = W[:,1,3]
            Wjj = W[:,2,2]
            Wjk = W[:,2,3]
            Wkk = W[:,3,3]

            output_r = centered_r * Wrr
            output_i = centered_r * Wri + centered_i * Wii
            output_j = centered_r * Wrj + centered_i * Wij + centered_j * Wjj
            output_k = centered_r * Wrk + centered_i * Wik + centered_j * Wjk + centered_k * Wkk

            if self.activation_position == "middle":
                output_r = self.activation(output_r)
                output_i = self.activation(output_i)
                output_j = self.activation(output_j)
                output_k = self.activation(output_k)

            out_r = output_r * self.gam_rr
            out_i = output_r * self.gam_ri + output_i * self.gam_ii
            out_j = output_r * self.gam_rj + output_i * self.gam_ij + output_j * self.gam_jj
            out_k = output_r * self.gam_rk + output_i * self.gam_ik + output_j * self.gam_jk + output_k * self.gam_kk
            output = tf.concat([out_r, out_i, out_j, out_k], axis=-1)
        else:
            output = centered
            if self.activation_position == "middle":
                output = self.activation(output)

        if self.center:
            output = output + self.beta

        if self.activation_position == "after":
            output = self.activation(output)

        return output

# %%
DefaultConvQuat = partial(QuatConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class QuatResidualUnit(layers.Layer):
    """ 
    Quaternion valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recognition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual networks.
    """
    def __init__(self, filters, strides=1, activation="elu", activation_position="after", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvQuat(filters, strides=strides),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position), 
            DefaultConvQuat(filters),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position),]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvQuat(filters, kernel_size=(1,1), strides=strides),
                Hypercomplex4DBNActivation(activation=None, activation_position='no_activation')]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"
activation_position = 'after'

quat_resnet = kr.models.Sequential()
quat_resnet.add(DefaultConvQuat(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    quat_resnet.add(QuatResidualUnit(filters, strides=strides, activation=activation, activation_position=activation_position))
    prev_filters = filters
quat_resnet.add(kr.layers.GlobalAvgPool2D())
quat_resnet.add(kr.layers.Flatten())
quat_resnet.add(kr.layers.Dense(10, activation="softmax"))
quat_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

quat_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 130s 234ms/step - loss: 2.3685 - accuracy: 0.3005 - val_loss: 2.5054 - val_accuracy: 0.2155
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 225ms/step - loss: 2.1053 - accuracy: 0.3899 - val_loss: 2.5396 - val_accuracy: 0.2240
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 224ms/step - loss: 1.9977 - accuracy: 0.4293 - val_loss: 2.5462 - val_accuracy: 0.2408
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 225ms/step - loss: 1.9133 - accuracy: 0.4593 - val_loss: 2.8805 - val_accuracy: 0.2269
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 226ms/step - loss: 1.8545 - accuracy: 0.4781 - val_loss: 2.6365 - val_accuracy: 0.2181
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 225ms/step - loss: 1.8047 - accuracy: 0.4947 - val_loss: 3.9151 - val_accuracy: 0.1657
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 1.7576 - accuracy: 0.5077 - val_loss: 2.1509 - val_accuracy: 0.3531
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 225ms/step - loss: 1.7147 - accuracy: 0.5223 - val_loss: 3.3060 - val_accuracy: 0.1988
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 88s 226ms/step - loss: 1.6866 - accuracy: 0.5337 - val_loss: 2.8318 - val_accuracy: 0.2556
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 1.6479 - accuracy: 0.5442 - val_loss: 2.6396 - val_accuracy: 0.2585
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.8943 - accuracy: 0.4465 - val_loss: 3.2341 - val_accuracy: 0.2027
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 1.5944 - accuracy: 0.5431 - val_loss: 2.3141 - val_accuracy: 0.3630
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 1.4732 - accuracy: 0.5766 - val_loss: 2.2878 - val_accuracy: 0.3434
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 1.3711 - accuracy: 0.6076 - val_loss: 2.4711 - val_accuracy: 0.3688
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.2970 - accuracy: 0.6253 - val_loss: 1.8382 - val_accuracy: 0.4810
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 1.2283 - accuracy: 0.6447 - val_loss: 1.8322 - val_accuracy: 0.4862
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.1768 - accuracy: 0.6572 - val_loss: 2.4008 - val_accuracy: 0.3247
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 1.1246 - accuracy: 0.6739 - val_loss: 1.8858 - val_accuracy: 0.4941
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 1.0761 - accuracy: 0.6876 - val_loss: 1.3741 - val_accuracy: 0.6037
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 1.0363 - accuracy: 0.7010 - val_loss: 1.3516 - val_accuracy: 0.6037
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 226ms/step - loss: 0.9970 - accuracy: 0.7117 - val_loss: 1.4976 - val_accuracy: 0.5484
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.9695 - accuracy: 0.7187 - val_loss: 1.4531 - val_accuracy: 0.5768
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.9439 - accuracy: 0.7279 - val_loss: 1.1320 - val_accuracy: 0.6757
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.9108 - accuracy: 0.7379 - val_loss: 1.2781 - val_accuracy: 0.6402
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.8889 - accuracy: 0.7465 - val_loss: 1.7584 - val_accuracy: 0.5246
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.8688 - accuracy: 0.7527 - val_loss: 0.9415 - val_accuracy: 0.7308
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.8453 - accuracy: 0.7612 - val_loss: 1.0032 - val_accuracy: 0.7043
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.8281 - accuracy: 0.7669 - val_loss: 0.9957 - val_accuracy: 0.7231
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.8157 - accuracy: 0.7722 - val_loss: 0.8936 - val_accuracy: 0.7440
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.8008 - accuracy: 0.7738 - val_loss: 1.2860 - val_accuracy: 0.6143
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.7903 - accuracy: 0.7785 - val_loss: 0.8890 - val_accuracy: 0.7474
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.7739 - accuracy: 0.7849 - val_loss: 1.1754 - val_accuracy: 0.6702
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.7621 - accuracy: 0.7885 - val_loss: 0.8832 - val_accuracy: 0.7418
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.7527 - accuracy: 0.7922 - val_loss: 1.0380 - val_accuracy: 0.6991
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.7472 - accuracy: 0.7929 - val_loss: 0.9491 - val_accuracy: 0.7352
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.7403 - accuracy: 0.7972 - val_loss: 1.0254 - val_accuracy: 0.7039
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.7296 - accuracy: 0.7978 - val_loss: 0.9215 - val_accuracy: 0.7336
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 0.7204 - accuracy: 0.8051 - val_loss: 1.0476 - val_accuracy: 0.6915
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.7099 - accuracy: 0.8077 - val_loss: 1.1814 - val_accuracy: 0.6619
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.7055 - accuracy: 0.8095 - val_loss: 1.0461 - val_accuracy: 0.6998
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6948 - accuracy: 0.8135 - val_loss: 1.0120 - val_accuracy: 0.7072
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6951 - accuracy: 0.8125 - val_loss: 0.9807 - val_accuracy: 0.7200
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6857 - accuracy: 0.8148 - val_loss: 1.1230 - val_accuracy: 0.6889
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6834 - accuracy: 0.8170 - val_loss: 0.8194 - val_accuracy: 0.7737
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6720 - accuracy: 0.8211 - val_loss: 1.3084 - val_accuracy: 0.6286
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6711 - accuracy: 0.8215 - val_loss: 0.8449 - val_accuracy: 0.7596
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6631 - accuracy: 0.8235 - val_loss: 0.9324 - val_accuracy: 0.7331
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6660 - accuracy: 0.8220 - val_loss: 0.7992 - val_accuracy: 0.7833
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6544 - accuracy: 0.8281 - val_loss: 1.0602 - val_accuracy: 0.7205
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6520 - accuracy: 0.8287 - val_loss: 0.9831 - val_accuracy: 0.7271
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6471 - accuracy: 0.8308 - val_loss: 1.0239 - val_accuracy: 0.7103
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6451 - accuracy: 0.8310 - val_loss: 0.9065 - val_accuracy: 0.7522
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6423 - accuracy: 0.8329 - val_loss: 0.8098 - val_accuracy: 0.7782
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6413 - accuracy: 0.8324 - val_loss: 0.9985 - val_accuracy: 0.7203
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6377 - accuracy: 0.8347 - val_loss: 0.9582 - val_accuracy: 0.7408
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 226ms/step - loss: 0.6365 - accuracy: 0.8345 - val_loss: 1.0013 - val_accuracy: 0.7302
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6330 - accuracy: 0.8364 - val_loss: 0.9302 - val_accuracy: 0.7421
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6283 - accuracy: 0.8397 - val_loss: 0.7914 - val_accuracy: 0.7812
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.6210 - accuracy: 0.8411 - val_loss: 1.7091 - val_accuracy: 0.5903
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6215 - accuracy: 0.8397 - val_loss: 0.8649 - val_accuracy: 0.7621
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6225 - accuracy: 0.8379 - val_loss: 0.8501 - val_accuracy: 0.7674
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6157 - accuracy: 0.8425 - val_loss: 0.9627 - val_accuracy: 0.7386
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.6115 - accuracy: 0.8422 - val_loss: 0.9465 - val_accuracy: 0.7383
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6091 - accuracy: 0.8446 - val_loss: 0.8291 - val_accuracy: 0.7752
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.6102 - accuracy: 0.8443 - val_loss: 0.7776 - val_accuracy: 0.7938
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6051 - accuracy: 0.8451 - val_loss: 0.9818 - val_accuracy: 0.7409
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.6020 - accuracy: 0.8481 - val_loss: 0.8546 - val_accuracy: 0.7660
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.6044 - accuracy: 0.8471 - val_loss: 0.9241 - val_accuracy: 0.7537
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5982 - accuracy: 0.8483 - val_loss: 0.7671 - val_accuracy: 0.7954
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5975 - accuracy: 0.8481 - val_loss: 0.9799 - val_accuracy: 0.7338
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5984 - accuracy: 0.8502 - val_loss: 0.9893 - val_accuracy: 0.7343
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5909 - accuracy: 0.8508 - val_loss: 0.8467 - val_accuracy: 0.7761
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5908 - accuracy: 0.8512 - val_loss: 0.8123 - val_accuracy: 0.7810
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5874 - accuracy: 0.8551 - val_loss: 0.9391 - val_accuracy: 0.7452
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5909 - accuracy: 0.8513 - val_loss: 0.8792 - val_accuracy: 0.7524
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5879 - accuracy: 0.8522 - val_loss: 0.9715 - val_accuracy: 0.7265
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5821 - accuracy: 0.8553 - val_loss: 0.8720 - val_accuracy: 0.7664
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5797 - accuracy: 0.8556 - val_loss: 1.1861 - val_accuracy: 0.7033
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 226ms/step - loss: 0.5785 - accuracy: 0.8575 - val_loss: 1.0424 - val_accuracy: 0.7294
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5792 - accuracy: 0.8568 - val_loss: 1.1561 - val_accuracy: 0.7017
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5773 - accuracy: 0.8561 - val_loss: 0.8483 - val_accuracy: 0.7760
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5759 - accuracy: 0.8594 - val_loss: 0.9829 - val_accuracy: 0.7471
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 88s 225ms/step - loss: 0.5782 - accuracy: 0.8549 - val_loss: 0.7935 - val_accuracy: 0.7916
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5688 - accuracy: 0.8601 - val_loss: 0.9162 - val_accuracy: 0.7633
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5766 - accuracy: 0.8577 - val_loss: 0.9889 - val_accuracy: 0.7386
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5703 - accuracy: 0.8590 - val_loss: 0.9852 - val_accuracy: 0.7297
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5670 - accuracy: 0.8613 - val_loss: 0.8563 - val_accuracy: 0.7777
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5661 - accuracy: 0.8597 - val_loss: 0.9190 - val_accuracy: 0.7627
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5676 - accuracy: 0.8603 - val_loss: 0.9564 - val_accuracy: 0.7347
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5659 - accuracy: 0.8606 - val_loss: 0.8075 - val_accuracy: 0.7964
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5694 - accuracy: 0.8599 - val_loss: 1.1875 - val_accuracy: 0.6985
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5600 - accuracy: 0.8647 - val_loss: 0.7876 - val_accuracy: 0.7904
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5599 - accuracy: 0.8630 - val_loss: 0.8050 - val_accuracy: 0.7854
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5629 - accuracy: 0.8617 - val_loss: 0.7370 - val_accuracy: 0.8048
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5595 - accuracy: 0.8621 - val_loss: 0.8749 - val_accuracy: 0.7630
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5601 - accuracy: 0.8629 - val_loss: 0.7900 - val_accuracy: 0.7929
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5573 - accuracy: 0.8640 - val_loss: 0.8853 - val_accuracy: 0.7723
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5547 - accuracy: 0.8653 - val_loss: 0.8536 - val_accuracy: 0.7796
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5555 - accuracy: 0.8637 - val_loss: 0.9436 - val_accuracy: 0.7592
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5538 - accuracy: 0.8653 - val_loss: 0.8486 - val_accuracy: 0.7673
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5534 - accuracy: 0.8670 - val_loss: 1.0569 - val_accuracy: 0.7238
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5493 - accuracy: 0.8673 - val_loss: 0.8589 - val_accuracy: 0.7732
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5539 - accuracy: 0.8663 - val_loss: 0.8956 - val_accuracy: 0.7516
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5491 - accuracy: 0.8689 - val_loss: 0.9639 - val_accuracy: 0.7520
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 227ms/step - loss: 0.5473 - accuracy: 0.8691 - val_loss: 0.7413 - val_accuracy: 0.8130
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 94s 242ms/step - loss: 0.5500 - accuracy: 0.8670 - val_loss: 0.7878 - val_accuracy: 0.7965
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5450 - accuracy: 0.8690 - val_loss: 1.5474 - val_accuracy: 0.6306
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5496 - accuracy: 0.8696 - val_loss: 0.8273 - val_accuracy: 0.7848
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5431 - accuracy: 0.8687 - val_loss: 0.8266 - val_accuracy: 0.7888
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5452 - accuracy: 0.8690 - val_loss: 1.0865 - val_accuracy: 0.7137
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5413 - accuracy: 0.8710 - val_loss: 0.8150 - val_accuracy: 0.7869
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5427 - accuracy: 0.8703 - val_loss: 0.7559 - val_accuracy: 0.7998
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5387 - accuracy: 0.8713 - val_loss: 0.9348 - val_accuracy: 0.7474
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5405 - accuracy: 0.8707 - val_loss: 0.7984 - val_accuracy: 0.7920
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5417 - accuracy: 0.8716 - val_loss: 0.7694 - val_accuracy: 0.7916
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5375 - accuracy: 0.8727 - val_loss: 0.9036 - val_accuracy: 0.7672
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5397 - accuracy: 0.8725 - val_loss: 0.7662 - val_accuracy: 0.8062
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5404 - accuracy: 0.8723 - val_loss: 0.9920 - val_accuracy: 0.7236
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 228ms/step - loss: 0.5357 - accuracy: 0.8726 - val_loss: 0.8070 - val_accuracy: 0.7961
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5380 - accuracy: 0.8711 - val_loss: 0.7240 - val_accuracy: 0.8180
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5336 - accuracy: 0.8741 - val_loss: 0.8969 - val_accuracy: 0.7715
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5344 - accuracy: 0.8720 - val_loss: 1.2619 - val_accuracy: 0.6975
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5363 - accuracy: 0.8711 - val_loss: 0.7608 - val_accuracy: 0.8074
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5348 - accuracy: 0.8730 - val_loss: 0.9758 - val_accuracy: 0.7374
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5306 - accuracy: 0.8738 - val_loss: 0.8025 - val_accuracy: 0.7943
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5349 - accuracy: 0.8737 - val_loss: 0.8597 - val_accuracy: 0.7739
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5371 - accuracy: 0.8724 - val_loss: 0.7963 - val_accuracy: 0.7927
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5263 - accuracy: 0.8771 - val_loss: 1.0056 - val_accuracy: 0.7354
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5292 - accuracy: 0.8743 - val_loss: 1.2509 - val_accuracy: 0.6783
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5273 - accuracy: 0.8755 - val_loss: 0.8611 - val_accuracy: 0.7843
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5310 - accuracy: 0.8738 - val_loss: 0.7553 - val_accuracy: 0.8046
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5258 - accuracy: 0.8755 - val_loss: 0.7582 - val_accuracy: 0.8018
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5260 - accuracy: 0.8755 - val_loss: 1.0355 - val_accuracy: 0.7166
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5293 - accuracy: 0.8757 - val_loss: 0.9145 - val_accuracy: 0.7595
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5252 - accuracy: 0.8766 - val_loss: 0.9457 - val_accuracy: 0.7601
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 231ms/step - loss: 0.5238 - accuracy: 0.8767 - val_loss: 0.8005 - val_accuracy: 0.7927
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5247 - accuracy: 0.8775 - val_loss: 0.8887 - val_accuracy: 0.7682
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5227 - accuracy: 0.8795 - val_loss: 0.8437 - val_accuracy: 0.7810
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5223 - accuracy: 0.8779 - val_loss: 0.7869 - val_accuracy: 0.7969
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5190 - accuracy: 0.8797 - val_loss: 1.0384 - val_accuracy: 0.7393
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5230 - accuracy: 0.8780 - val_loss: 0.8196 - val_accuracy: 0.7813
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5233 - accuracy: 0.8775 - val_loss: 0.7813 - val_accuracy: 0.8002
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 89s 229ms/step - loss: 0.5200 - accuracy: 0.8796 - val_loss: 0.8931 - val_accuracy: 0.7598
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5179 - accuracy: 0.8795 - val_loss: 1.0216 - val_accuracy: 0.7334
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 231ms/step - loss: 0.5187 - accuracy: 0.8793 - val_loss: 0.8648 - val_accuracy: 0.7703
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 232ms/step - loss: 0.5217 - accuracy: 0.8785 - val_loss: 0.9007 - val_accuracy: 0.7630
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5200 - accuracy: 0.8803 - val_loss: 0.9323 - val_accuracy: 0.7483
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 229ms/step - loss: 0.5172 - accuracy: 0.8805 - val_loss: 1.0163 - val_accuracy: 0.7373
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5208 - accuracy: 0.8780 - val_loss: 1.1682 - val_accuracy: 0.7122
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 91s 232ms/step - loss: 0.5182 - accuracy: 0.8803 - val_loss: 0.9663 - val_accuracy: 0.7442
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 90s 230ms/step - loss: 0.5171 - accuracy: 0.8794 - val_loss: 1.0304 - val_accuracy: 0.7219
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.4208 - accuracy: 0.9132 - val_loss: 0.6289 - val_accuracy: 0.8443
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.3895 - accuracy: 0.9243 - val_loss: 0.5962 - val_accuracy: 0.8538
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3793 - accuracy: 0.9283 - val_loss: 0.6097 - val_accuracy: 0.8533
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.3685 - accuracy: 0.9295 - val_loss: 0.6077 - val_accuracy: 0.8533
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 229ms/step - loss: 0.3613 - accuracy: 0.9317 - val_loss: 0.6253 - val_accuracy: 0.8460
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 233ms/step - loss: 0.3578 - accuracy: 0.9330 - val_loss: 0.5974 - val_accuracy: 0.8548
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.3527 - accuracy: 0.9323 - val_loss: 0.6266 - val_accuracy: 0.8481
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3462 - accuracy: 0.9339 - val_loss: 0.6157 - val_accuracy: 0.8479
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.3424 - accuracy: 0.9349 - val_loss: 0.6014 - val_accuracy: 0.8523
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.3395 - accuracy: 0.9353 - val_loss: 0.6387 - val_accuracy: 0.8431
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.3315 - accuracy: 0.9370 - val_loss: 0.6280 - val_accuracy: 0.8471
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3280 - accuracy: 0.9377 - val_loss: 0.6184 - val_accuracy: 0.8475
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.3266 - accuracy: 0.9361 - val_loss: 0.6143 - val_accuracy: 0.8481
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3206 - accuracy: 0.9390 - val_loss: 0.6253 - val_accuracy: 0.8445
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.3174 - accuracy: 0.9387 - val_loss: 0.6243 - val_accuracy: 0.8475
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.3165 - accuracy: 0.9386 - val_loss: 0.6219 - val_accuracy: 0.8460
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.3098 - accuracy: 0.9406 - val_loss: 0.6036 - val_accuracy: 0.8508
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.3088 - accuracy: 0.9396 - val_loss: 0.6014 - val_accuracy: 0.8489
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.3054 - accuracy: 0.9395 - val_loss: 0.6360 - val_accuracy: 0.8417
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 233ms/step - loss: 0.3023 - accuracy: 0.9402 - val_loss: 0.5984 - val_accuracy: 0.8508
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2992 - accuracy: 0.9415 - val_loss: 0.6258 - val_accuracy: 0.8445
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2978 - accuracy: 0.9407 - val_loss: 0.5745 - val_accuracy: 0.8575
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2946 - accuracy: 0.9414 - val_loss: 0.6467 - val_accuracy: 0.8379
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2915 - accuracy: 0.9420 - val_loss: 0.5819 - val_accuracy: 0.8540
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2889 - accuracy: 0.9413 - val_loss: 0.6052 - val_accuracy: 0.8500
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2892 - accuracy: 0.9420 - val_loss: 0.5826 - val_accuracy: 0.8522
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2858 - accuracy: 0.9424 - val_loss: 0.6504 - val_accuracy: 0.8384
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2818 - accuracy: 0.9423 - val_loss: 0.5707 - val_accuracy: 0.8584
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2814 - accuracy: 0.9426 - val_loss: 0.6279 - val_accuracy: 0.8412
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 233ms/step - loss: 0.2785 - accuracy: 0.9441 - val_loss: 0.6323 - val_accuracy: 0.8368
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2777 - accuracy: 0.9431 - val_loss: 0.6044 - val_accuracy: 0.8465
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2745 - accuracy: 0.9436 - val_loss: 0.6042 - val_accuracy: 0.8472
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2740 - accuracy: 0.9436 - val_loss: 0.6035 - val_accuracy: 0.8461
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2714 - accuracy: 0.9434 - val_loss: 0.6067 - val_accuracy: 0.8422
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2699 - accuracy: 0.9430 - val_loss: 0.5751 - val_accuracy: 0.8528
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 231ms/step - loss: 0.2701 - accuracy: 0.9434 - val_loss: 0.6416 - val_accuracy: 0.8364
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2699 - accuracy: 0.9432 - val_loss: 0.6291 - val_accuracy: 0.8369
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2649 - accuracy: 0.9442 - val_loss: 0.5921 - val_accuracy: 0.8456
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2660 - accuracy: 0.9436 - val_loss: 0.6438 - val_accuracy: 0.8355
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2608 - accuracy: 0.9456 - val_loss: 0.5817 - val_accuracy: 0.8514
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2621 - accuracy: 0.9453 - val_loss: 0.6172 - val_accuracy: 0.8395
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2589 - accuracy: 0.9452 - val_loss: 0.6654 - val_accuracy: 0.8312
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2595 - accuracy: 0.9432 - val_loss: 0.6113 - val_accuracy: 0.8476
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2587 - accuracy: 0.9439 - val_loss: 0.6055 - val_accuracy: 0.8455
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2554 - accuracy: 0.9448 - val_loss: 0.6182 - val_accuracy: 0.8432
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2548 - accuracy: 0.9456 - val_loss: 0.5875 - val_accuracy: 0.8507
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2521 - accuracy: 0.9449 - val_loss: 0.5879 - val_accuracy: 0.8495
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2541 - accuracy: 0.9444 - val_loss: 0.6379 - val_accuracy: 0.8372
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2529 - accuracy: 0.9449 - val_loss: 0.5937 - val_accuracy: 0.8483
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2317 - accuracy: 0.9529 - val_loss: 0.5655 - val_accuracy: 0.8535
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2244 - accuracy: 0.9564 - val_loss: 0.5602 - val_accuracy: 0.8552
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2188 - accuracy: 0.9573 - val_loss: 0.5643 - val_accuracy: 0.8545
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2197 - accuracy: 0.9575 - val_loss: 0.5630 - val_accuracy: 0.8556
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2206 - accuracy: 0.9579 - val_loss: 0.5519 - val_accuracy: 0.8569
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2174 - accuracy: 0.9577 - val_loss: 0.5850 - val_accuracy: 0.8500
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 227ms/step - loss: 0.2175 - accuracy: 0.9575 - val_loss: 0.5681 - val_accuracy: 0.8523
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2151 - accuracy: 0.9597 - val_loss: 0.5732 - val_accuracy: 0.8519
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2142 - accuracy: 0.9585 - val_loss: 0.5692 - val_accuracy: 0.8547
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2144 - accuracy: 0.9598 - val_loss: 0.5680 - val_accuracy: 0.8546
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2156 - accuracy: 0.9583 - val_loss: 0.5649 - val_accuracy: 0.8565
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2123 - accuracy: 0.9595 - val_loss: 0.5628 - val_accuracy: 0.8553
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 92s 234ms/step - loss: 0.2138 - accuracy: 0.9594 - val_loss: 0.5723 - val_accuracy: 0.8509
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2127 - accuracy: 0.9596 - val_loss: 0.5716 - val_accuracy: 0.8533
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2122 - accuracy: 0.9585 - val_loss: 0.5678 - val_accuracy: 0.8559
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2105 - accuracy: 0.9611 - val_loss: 0.5709 - val_accuracy: 0.8552
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2106 - accuracy: 0.9613 - val_loss: 0.5746 - val_accuracy: 0.8542
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2101 - accuracy: 0.9608 - val_loss: 0.5827 - val_accuracy: 0.8507
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2088 - accuracy: 0.9613 - val_loss: 0.5752 - val_accuracy: 0.8520
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2101 - accuracy: 0.9603 - val_loss: 0.5723 - val_accuracy: 0.8548
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 229ms/step - loss: 0.2084 - accuracy: 0.9608 - val_loss: 0.5808 - val_accuracy: 0.8540
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.2101 - accuracy: 0.9607 - val_loss: 0.5621 - val_accuracy: 0.8564
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 233ms/step - loss: 0.2101 - accuracy: 0.9600 - val_loss: 0.5756 - val_accuracy: 0.8523
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2052 - accuracy: 0.9620 - val_loss: 0.5769 - val_accuracy: 0.8523
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2103 - accuracy: 0.9596 - val_loss: 0.5841 - val_accuracy: 0.8506
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2073 - accuracy: 0.9605 - val_loss: 0.5869 - val_accuracy: 0.8494
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2054 - accuracy: 0.9614 - val_loss: 0.5855 - val_accuracy: 0.8512
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2064 - accuracy: 0.9612 - val_loss: 0.5886 - val_accuracy: 0.8489
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2054 - accuracy: 0.9612 - val_loss: 0.5794 - val_accuracy: 0.8517
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2038 - accuracy: 0.9622 - val_loss: 0.5892 - val_accuracy: 0.8513
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 234ms/step - loss: 0.2045 - accuracy: 0.9609 - val_loss: 0.5795 - val_accuracy: 0.8525
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 231ms/step - loss: 0.2055 - accuracy: 0.9609 - val_loss: 0.5871 - val_accuracy: 0.8530
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 89s 228ms/step - loss: 0.2049 - accuracy: 0.9620 - val_loss: 0.5923 - val_accuracy: 0.8504
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2014 - accuracy: 0.9623 - val_loss: 0.5916 - val_accuracy: 0.8484
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 233ms/step - loss: 0.2037 - accuracy: 0.9618 - val_loss: 0.5847 - val_accuracy: 0.8522
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2031 - accuracy: 0.9621 - val_loss: 0.6063 - val_accuracy: 0.8492
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2026 - accuracy: 0.9619 - val_loss: 0.5860 - val_accuracy: 0.8512
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2028 - accuracy: 0.9613 - val_loss: 0.5900 - val_accuracy: 0.8488
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2027 - accuracy: 0.9624 - val_loss: 0.5813 - val_accuracy: 0.8544
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.2005 - accuracy: 0.9624 - val_loss: 0.5735 - val_accuracy: 0.8533
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.1997 - accuracy: 0.9630 - val_loss: 0.5778 - val_accuracy: 0.8528
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2015 - accuracy: 0.9617 - val_loss: 0.5882 - val_accuracy: 0.8507
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2011 - accuracy: 0.9614 - val_loss: 0.5984 - val_accuracy: 0.8492
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.1998 - accuracy: 0.9630 - val_loss: 0.6123 - val_accuracy: 0.8447
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.1996 - accuracy: 0.9628 - val_loss: 0.5931 - val_accuracy: 0.8493
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 231ms/step - loss: 0.2022 - accuracy: 0.9614 - val_loss: 0.5926 - val_accuracy: 0.8481
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2003 - accuracy: 0.9621 - val_loss: 0.6054 - val_accuracy: 0.8467
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 229ms/step - loss: 0.1976 - accuracy: 0.9622 - val_loss: 0.5988 - val_accuracy: 0.8491
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 90s 230ms/step - loss: 0.2005 - accuracy: 0.9613 - val_loss: 0.5907 - val_accuracy: 0.8511
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 91s 232ms/step - loss: 0.1994 - accuracy: 0.9627 - val_loss: 0.5895 - val_accuracy: 0.8499

# %%
quat_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quat_conv2d (QuatConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# quat_residual_unit (QuatResi (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_1 (QuatRe (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_2 (QuatRe (None, None, None, 24)    2928
# _________________________________________________________________
# quat_residual_unit_3 (QuatRe (None, None, None, 48)    9072
# _________________________________________________________________
# quat_residual_unit_4 (QuatRe (None, None, None, 48)    11040
# _________________________________________________________________
# quat_residual_unit_5 (QuatRe (None, None, None, 96)    34272
# _________________________________________________________________
# quat_residual_unit_6 (QuatRe (None, None, None, 96)    42816
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 107,170
# Trainable params: 104,146
# Non-trainable params: 3,024
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(quat_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96704

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(quat_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8499
