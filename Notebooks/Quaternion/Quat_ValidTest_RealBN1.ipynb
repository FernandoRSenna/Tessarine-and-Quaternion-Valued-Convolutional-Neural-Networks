# %% [markdown]
# # Quaternion Valued CNN with Real Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class QuatConv2D(layers.Layer):
    """
    Quaternion valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer(),
                 data_format=None,
                 kernel_regularizer=1e-4):
        super(QuatConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        self.kernel_regularizer = kernel_regularizer
        
    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('QuatConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        # Filter multiplied from the right!
        F_r = tf.concat([ self.f0,-self.f1,-self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3,-self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0, self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2,-self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvQuat = partial(QuatConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class QuatResidualUnit(layers.Layer):
    """ 
    Quaternion valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recognition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual networks.
    """
    def __init__(self, filters, strides=1, activation="elu", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvQuat(filters, strides=strides),
            kr.layers.BatchNormalization(),
            self.activation, 
            DefaultConvQuat(filters),
            kr.layers.BatchNormalization(),
            self.activation]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvQuat(filters, kernel_size=(1,1), strides=strides),
                kr.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

quat_resnet = kr.models.Sequential()
quat_resnet.add(DefaultConvQuat(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    quat_resnet.add(QuatResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
quat_resnet.add(kr.layers.GlobalAvgPool2D())
quat_resnet.add(kr.layers.Flatten())
quat_resnet.add(kr.layers.Dense(10, activation="softmax"))
quat_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

quat_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 56s 125ms/step - loss: 2.2431 - accuracy: 0.3450 - val_loss: 2.7490 - val_accuracy: 0.1717
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 119ms/step - loss: 2.0271 - accuracy: 0.4194 - val_loss: 2.7649 - val_accuracy: 0.1873
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 1.9334 - accuracy: 0.4536 - val_loss: 2.7749 - val_accuracy: 0.2068
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 1.8600 - accuracy: 0.4786 - val_loss: 2.3988 - val_accuracy: 0.2666
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 1.7944 - accuracy: 0.5041 - val_loss: 2.5526 - val_accuracy: 0.2640
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 115ms/step - loss: 1.7399 - accuracy: 0.5233 - val_loss: 2.2762 - val_accuracy: 0.3159
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 1.6883 - accuracy: 0.5411 - val_loss: 2.4267 - val_accuracy: 0.2919
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 1.6493 - accuracy: 0.5530 - val_loss: 2.3685 - val_accuracy: 0.2961
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 114ms/step - loss: 1.6057 - accuracy: 0.5663 - val_loss: 2.2665 - val_accuracy: 0.3705
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 119ms/step - loss: 1.5710 - accuracy: 0.5792 - val_loss: 2.2029 - val_accuracy: 0.3818
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 115ms/step - loss: 1.7699 - accuracy: 0.4979 - val_loss: 1.9955 - val_accuracy: 0.4051
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 1.5013 - accuracy: 0.5866 - val_loss: 1.9759 - val_accuracy: 0.4109
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 1.3810 - accuracy: 0.6179 - val_loss: 1.7751 - val_accuracy: 0.4888
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 1.2985 - accuracy: 0.6394 - val_loss: 1.6043 - val_accuracy: 0.5512
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 48s 122ms/step - loss: 1.2138 - accuracy: 0.6617 - val_loss: 1.8878 - val_accuracy: 0.4766
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 121ms/step - loss: 1.1496 - accuracy: 0.6815 - val_loss: 1.5311 - val_accuracy: 0.5409
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 48s 123ms/step - loss: 1.0936 - accuracy: 0.6941 - val_loss: 1.3757 - val_accuracy: 0.5985
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 1.0506 - accuracy: 0.7065 - val_loss: 1.5485 - val_accuracy: 0.5581
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 115ms/step - loss: 1.0144 - accuracy: 0.7157 - val_loss: 1.3798 - val_accuracy: 0.5971
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 48s 122ms/step - loss: 0.9799 - accuracy: 0.7276 - val_loss: 1.3975 - val_accuracy: 0.6003
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.9510 - accuracy: 0.7352 - val_loss: 1.5802 - val_accuracy: 0.5535
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.9213 - accuracy: 0.7431 - val_loss: 1.1329 - val_accuracy: 0.6797
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.9044 - accuracy: 0.7481 - val_loss: 1.2638 - val_accuracy: 0.6296
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8788 - accuracy: 0.7564 - val_loss: 1.7161 - val_accuracy: 0.5417
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8598 - accuracy: 0.7631 - val_loss: 1.3438 - val_accuracy: 0.6118
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8416 - accuracy: 0.7664 - val_loss: 1.4851 - val_accuracy: 0.5788
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 119ms/step - loss: 0.8318 - accuracy: 0.7708 - val_loss: 1.0161 - val_accuracy: 0.7072
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.8213 - accuracy: 0.7730 - val_loss: 1.1478 - val_accuracy: 0.6738
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8026 - accuracy: 0.7795 - val_loss: 1.2519 - val_accuracy: 0.6449
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.7942 - accuracy: 0.7791 - val_loss: 0.9858 - val_accuracy: 0.7147
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7840 - accuracy: 0.7845 - val_loss: 0.9190 - val_accuracy: 0.7443
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.7746 - accuracy: 0.7893 - val_loss: 1.0276 - val_accuracy: 0.7089
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7633 - accuracy: 0.7925 - val_loss: 1.2941 - val_accuracy: 0.6363
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7575 - accuracy: 0.7955 - val_loss: 0.9565 - val_accuracy: 0.7296
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.7498 - accuracy: 0.7977 - val_loss: 0.8896 - val_accuracy: 0.7541
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 48s 122ms/step - loss: 0.7385 - accuracy: 0.8018 - val_loss: 1.1327 - val_accuracy: 0.6843
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.7389 - accuracy: 0.8026 - val_loss: 1.1032 - val_accuracy: 0.6989
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.7263 - accuracy: 0.8049 - val_loss: 1.0995 - val_accuracy: 0.6974
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7216 - accuracy: 0.8056 - val_loss: 1.1784 - val_accuracy: 0.6613
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.7149 - accuracy: 0.8078 - val_loss: 0.9256 - val_accuracy: 0.7490
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7127 - accuracy: 0.8117 - val_loss: 1.1715 - val_accuracy: 0.6807
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7039 - accuracy: 0.8129 - val_loss: 0.9329 - val_accuracy: 0.7360
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.7026 - accuracy: 0.8125 - val_loss: 0.9914 - val_accuracy: 0.7243
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.6943 - accuracy: 0.8166 - val_loss: 0.9261 - val_accuracy: 0.7500
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.6913 - accuracy: 0.8177 - val_loss: 0.8725 - val_accuracy: 0.7580
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.
250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3328 - accuracy: 0.9333 - val_loss: 0.6403 - val_accuracy: 0.8349
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3246 - accuracy: 0.9351 - val_loss: 0.6181 - val_accuracy: 0.8444
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 119ms/step - loss: 0.3268 - accuracy: 0.9336 - val_loss: 0.5976 - val_accuracy: 0.8509
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 116ms/step - loss: 0.3206 - accuracy: 0.9369 - val_loss: 0.6018 - val_accuracy: 0.8452
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 49s 125ms/step - loss: 0.3163 - accuracy: 0.9374 - val_loss: 0.6110 - val_accuracy: 0.8458
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3138 - accuracy: 0.9361 - val_loss: 0.6291 - val_accuracy: 0.8326
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.3132 - accuracy: 0.9365 - val_loss: 0.5991 - val_accuracy: 0.8487
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.3107 - accuracy: 0.9369 - val_loss: 0.6166 - val_accuracy: 0.8420
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.3066 - accuracy: 0.9370 - val_loss: 0.6031 - val_accuracy: 0.8466
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.3069 - accuracy: 0.9360 - val_loss: 0.6077 - val_accuracy: 0.8447
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 116ms/step - loss: 0.3034 - accuracy: 0.9366 - val_loss: 0.6257 - val_accuracy: 0.8437
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 120ms/step - loss: 0.3044 - accuracy: 0.9364 - val_loss: 0.6045 - val_accuracy: 0.8467
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2989 - accuracy: 0.9378 - val_loss: 0.6072 - val_accuracy: 0.8421
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.3002 - accuracy: 0.9377 - val_loss: 0.6441 - val_accuracy: 0.8373
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2951 - accuracy: 0.9377 - val_loss: 0.5948 - val_accuracy: 0.8491
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 116ms/step - loss: 0.2929 - accuracy: 0.9389 - val_loss: 0.6086 - val_accuracy: 0.8479
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2896 - accuracy: 0.9396 - val_loss: 0.6447 - val_accuracy: 0.8310
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2888 - accuracy: 0.9392 - val_loss: 0.5905 - val_accuracy: 0.8497
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2897 - accuracy: 0.9382 - val_loss: 0.6877 - val_accuracy: 0.8185
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2901 - accuracy: 0.9376 - val_loss: 0.6019 - val_accuracy: 0.8416
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 116ms/step - loss: 0.2848 - accuracy: 0.9391 - val_loss: 0.6213 - val_accuracy: 0.8437
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2847 - accuracy: 0.9384 - val_loss: 0.6141 - val_accuracy: 0.8430
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2770 - accuracy: 0.9405 - val_loss: 0.6547 - val_accuracy: 0.8294
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2813 - accuracy: 0.9383 - val_loss: 0.6720 - val_accuracy: 0.8245
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 116ms/step - loss: 0.2788 - accuracy: 0.9403 - val_loss: 0.5866 - val_accuracy: 0.8474
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2756 - accuracy: 0.9399 - val_loss: 0.5791 - val_accuracy: 0.8500
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2756 - accuracy: 0.9388 - val_loss: 0.6257 - val_accuracy: 0.8399
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2780 - accuracy: 0.9386 - val_loss: 0.5962 - val_accuracy: 0.8432
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2750 - accuracy: 0.9395 - val_loss: 0.6499 - val_accuracy: 0.8310
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2722 - accuracy: 0.9393 - val_loss: 0.6615 - val_accuracy: 0.8242
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2747 - accuracy: 0.9387 - val_loss: 0.6037 - val_accuracy: 0.8451
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2712 - accuracy: 0.9394 - val_loss: 0.6525 - val_accuracy: 0.8326
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2487 - accuracy: 0.9478 - val_loss: 0.5646 - val_accuracy: 0.8518
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2423 - accuracy: 0.9501 - val_loss: 0.5737 - val_accuracy: 0.8499
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2407 - accuracy: 0.9507 - val_loss: 0.5642 - val_accuracy: 0.8536
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2370 - accuracy: 0.9527 - val_loss: 0.5751 - val_accuracy: 0.8489
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2367 - accuracy: 0.9533 - val_loss: 0.5781 - val_accuracy: 0.8480
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 121ms/step - loss: 0.2370 - accuracy: 0.9525 - val_loss: 0.5726 - val_accuracy: 0.8514
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2348 - accuracy: 0.9541 - val_loss: 0.5719 - val_accuracy: 0.8521
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 123ms/step - loss: 0.2348 - accuracy: 0.9526 - val_loss: 0.5742 - val_accuracy: 0.8506
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2325 - accuracy: 0.9545 - val_loss: 0.5809 - val_accuracy: 0.8484
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2317 - accuracy: 0.9547 - val_loss: 0.5763 - val_accuracy: 0.8494
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2311 - accuracy: 0.9548 - val_loss: 0.5668 - val_accuracy: 0.8530
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2302 - accuracy: 0.9547 - val_loss: 0.5698 - val_accuracy: 0.8521
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2295 - accuracy: 0.9541 - val_loss: 0.5766 - val_accuracy: 0.8499
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2296 - accuracy: 0.9554 - val_loss: 0.5716 - val_accuracy: 0.8500
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2296 - accuracy: 0.9553 - val_loss: 0.5782 - val_accuracy: 0.8485
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 121ms/step - loss: 0.2269 - accuracy: 0.9560 - val_loss: 0.5669 - val_accuracy: 0.8529
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2270 - accuracy: 0.9547 - val_loss: 0.5600 - val_accuracy: 0.8543
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2300 - accuracy: 0.9556 - val_loss: 0.5481 - val_accuracy: 0.8571
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2286 - accuracy: 0.9547 - val_loss: 0.5697 - val_accuracy: 0.8513
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2283 - accuracy: 0.9547 - val_loss: 0.5717 - val_accuracy: 0.8516
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2262 - accuracy: 0.9558 - val_loss: 0.5711 - val_accuracy: 0.8517
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2246 - accuracy: 0.9571 - val_loss: 0.5794 - val_accuracy: 0.8488
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2259 - accuracy: 0.9562 - val_loss: 0.5835 - val_accuracy: 0.8476
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2233 - accuracy: 0.9568 - val_loss: 0.5698 - val_accuracy: 0.8496
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 123ms/step - loss: 0.2246 - accuracy: 0.9554 - val_loss: 0.5778 - val_accuracy: 0.8494
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2257 - accuracy: 0.9550 - val_loss: 0.5753 - val_accuracy: 0.8492
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2257 - accuracy: 0.9551 - val_loss: 0.5724 - val_accuracy: 0.8516
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2242 - accuracy: 0.9551 - val_loss: 0.5588 - val_accuracy: 0.8533
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 121ms/step - loss: 0.2229 - accuracy: 0.9570 - val_loss: 0.5652 - val_accuracy: 0.8517
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2227 - accuracy: 0.9558 - val_loss: 0.5739 - val_accuracy: 0.8533
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2254 - accuracy: 0.9545 - val_loss: 0.5793 - val_accuracy: 0.8490
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 49s 125ms/step - loss: 0.2235 - accuracy: 0.9572 - val_loss: 0.5712 - val_accuracy: 0.8511
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2227 - accuracy: 0.9549 - val_loss: 0.5816 - val_accuracy: 0.8498
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2216 - accuracy: 0.9573 - val_loss: 0.5751 - val_accuracy: 0.8517
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 49s 125ms/step - loss: 0.2202 - accuracy: 0.9574 - val_loss: 0.5739 - val_accuracy: 0.8510
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2224 - accuracy: 0.9561 - val_loss: 0.5755 - val_accuracy: 0.8511
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2203 - accuracy: 0.9573 - val_loss: 0.5706 - val_accuracy: 0.8524
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2183 - accuracy: 0.9574 - val_loss: 0.5730 - val_accuracy: 0.8524
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2222 - accuracy: 0.9562 - val_loss: 0.5715 - val_accuracy: 0.8529
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2194 - accuracy: 0.9575 - val_loss: 0.5715 - val_accuracy: 0.8520
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2207 - accuracy: 0.9560 - val_loss: 0.5706 - val_accuracy: 0.8526
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2193 - accuracy: 0.9561 - val_loss: 0.5747 - val_accuracy: 0.8508
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 50s 127ms/step - loss: 0.2196 - accuracy: 0.9559 - val_loss: 0.5773 - val_accuracy: 0.8505
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2183 - accuracy: 0.9572 - val_loss: 0.5863 - val_accuracy: 0.8459
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2189 - accuracy: 0.9575 - val_loss: 0.5853 - val_accuracy: 0.8488
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2185 - accuracy: 0.9571 - val_loss: 0.5868 - val_accuracy: 0.8474
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2177 - accuracy: 0.9570 - val_loss: 0.5851 - val_accuracy: 0.8479
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2167 - accuracy: 0.9579 - val_loss: 0.5802 - val_accuracy: 0.8478
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2172 - accuracy: 0.9576 - val_loss: 0.5794 - val_accuracy: 0.8506
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2196 - accuracy: 0.9571 - val_loss: 0.5810 - val_accuracy: 0.8493

# %%
quat_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quat_conv2d (QuatConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# quat_residual_unit (QuatResi (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_1 (QuatRe (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_2 (QuatRe (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_3 (QuatRe (None, None, None, 48)    8640
# _________________________________________________________________
# quat_residual_unit_4 (QuatRe (None, None, None, 48)    10752
# _________________________________________________________________
# quat_residual_unit_5 (QuatRe (None, None, None, 96)    33408
# _________________________________________________________________
# quat_residual_unit_6 (QuatRe (None, None, None, 96)    42240
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 104,578
# Trainable params: 102,850
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(quat_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96086

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(quat_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8493
