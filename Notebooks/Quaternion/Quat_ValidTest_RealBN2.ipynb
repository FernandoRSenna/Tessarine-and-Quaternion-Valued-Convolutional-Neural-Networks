# %% [markdown]
# # Quaternion Valued CNN with Real Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class QuatConv2D(layers.Layer):
    """
    Quaternion valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer(),
                 data_format=None,
                 kernel_regularizer=1e-4):
        super(QuatConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        self.kernel_regularizer = kernel_regularizer
        
    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('QuatConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        # Filter multiplied from the right!
        F_r = tf.concat([ self.f0,-self.f1,-self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3,-self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0, self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2,-self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvQuat = partial(QuatConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class QuatResidualUnit(layers.Layer):
    """ 
    Quaternion valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recognition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual networks.
    """
    def __init__(self, filters, strides=1, activation="elu", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvQuat(filters, strides=strides),
            kr.layers.BatchNormalization(),
            self.activation, 
            DefaultConvQuat(filters),
            kr.layers.BatchNormalization(),
            self.activation]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvQuat(filters, kernel_size=(1,1), strides=strides),
                kr.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

quat_resnet = kr.models.Sequential()
quat_resnet.add(DefaultConvQuat(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    quat_resnet.add(QuatResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
quat_resnet.add(kr.layers.GlobalAvgPool2D())
quat_resnet.add(kr.layers.Flatten())
quat_resnet.add(kr.layers.Dense(10, activation="softmax"))
quat_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

quat_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 48s 105ms/step - loss: 2.2330 - accuracy: 0.3465 - val_loss: 2.7413 - val_accuracy: 0.1601
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 2.0164 - accuracy: 0.4223 - val_loss: 2.4355 - val_accuracy: 0.2502
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 1.9220 - accuracy: 0.4587 - val_loss: 2.5925 - val_accuracy: 0.2243
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 1.8505 - accuracy: 0.4831 - val_loss: 2.3059 - val_accuracy: 0.2978
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 1.7929 - accuracy: 0.5019 - val_loss: 2.3731 - val_accuracy: 0.3005
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 104ms/step - loss: 1.7365 - accuracy: 0.5219 - val_loss: 2.0934 - val_accuracy: 0.3705
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 1.6918 - accuracy: 0.5378 - val_loss: 2.0363 - val_accuracy: 0.3954
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 1.6493 - accuracy: 0.5506 - val_loss: 2.1335 - val_accuracy: 0.3790
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 1.6095 - accuracy: 0.5661 - val_loss: 2.2610 - val_accuracy: 0.3468
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 1.5713 - accuracy: 0.5775 - val_loss: 1.9894 - val_accuracy: 0.4048
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 1.8843 - accuracy: 0.4534 - val_loss: 2.5795 - val_accuracy: 0.3111
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 1.5327 - accuracy: 0.5728 - val_loss: 1.8522 - val_accuracy: 0.4348
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.3879 - accuracy: 0.6137 - val_loss: 2.2627 - val_accuracy: 0.3819
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 1.2852 - accuracy: 0.6406 - val_loss: 1.6471 - val_accuracy: 0.5070
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 1.2011 - accuracy: 0.6653 - val_loss: 1.5348 - val_accuracy: 0.5322
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 1.1372 - accuracy: 0.6826 - val_loss: 1.6309 - val_accuracy: 0.5263
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 1.0818 - accuracy: 0.6983 - val_loss: 1.2337 - val_accuracy: 0.6425
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.0413 - accuracy: 0.7101 - val_loss: 1.3183 - val_accuracy: 0.6310
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.9959 - accuracy: 0.7225 - val_loss: 1.1137 - val_accuracy: 0.6830
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.9657 - accuracy: 0.7296 - val_loss: 1.5140 - val_accuracy: 0.5509
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.9337 - accuracy: 0.7394 - val_loss: 1.4140 - val_accuracy: 0.6029
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.9126 - accuracy: 0.7457 - val_loss: 1.5213 - val_accuracy: 0.5793
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.8945 - accuracy: 0.7505 - val_loss: 1.1972 - val_accuracy: 0.6535
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.8708 - accuracy: 0.7576 - val_loss: 1.2166 - val_accuracy: 0.6474
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.8551 - accuracy: 0.7613 - val_loss: 1.0295 - val_accuracy: 0.7009
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.8386 - accuracy: 0.7676 - val_loss: 1.3381 - val_accuracy: 0.6299
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.8240 - accuracy: 0.7715 - val_loss: 1.3100 - val_accuracy: 0.6192
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.8099 - accuracy: 0.7762 - val_loss: 0.9292 - val_accuracy: 0.7350
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.7988 - accuracy: 0.7793 - val_loss: 1.0544 - val_accuracy: 0.6933
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.7869 - accuracy: 0.7848 - val_loss: 1.3301 - val_accuracy: 0.6541
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.7813 - accuracy: 0.7859 - val_loss: 0.9625 - val_accuracy: 0.7318
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.7640 - accuracy: 0.7920 - val_loss: 1.3678 - val_accuracy: 0.5979
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.7630 - accuracy: 0.7927 - val_loss: 1.0244 - val_accuracy: 0.6991
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7538 - accuracy: 0.7966 - val_loss: 0.9770 - val_accuracy: 0.7241
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.7456 - accuracy: 0.7968 - val_loss: 0.9629 - val_accuracy: 0.7327
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.7387 - accuracy: 0.7999 - val_loss: 1.0618 - val_accuracy: 0.6966
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7315 - accuracy: 0.8027 - val_loss: 0.9718 - val_accuracy: 0.7236
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.7239 - accuracy: 0.8063 - val_loss: 0.9363 - val_accuracy: 0.7309
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.7233 - accuracy: 0.8064 - val_loss: 1.1090 - val_accuracy: 0.7015
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.7150 - accuracy: 0.8103 - val_loss: 1.2788 - val_accuracy: 0.6514
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.7039 - accuracy: 0.8124 - val_loss: 0.8921 - val_accuracy: 0.7497
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7063 - accuracy: 0.8118 - val_loss: 1.0149 - val_accuracy: 0.7271
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6995 - accuracy: 0.8157 - val_loss: 0.9165 - val_accuracy: 0.7426
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.6937 - accuracy: 0.8181 - val_loss: 0.9499 - val_accuracy: 0.7357
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6853 - accuracy: 0.8198 - val_loss: 1.0449 - val_accuracy: 0.7034
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6881 - accuracy: 0.8183 - val_loss: 0.9011 - val_accuracy: 0.7607
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6804 - accuracy: 0.8204 - val_loss: 1.4515 - val_accuracy: 0.6191
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6795 - accuracy: 0.8234 - val_loss: 0.9662 - val_accuracy: 0.7313
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6754 - accuracy: 0.8257 - val_loss: 0.8889 - val_accuracy: 0.7583
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6697 - accuracy: 0.8278 - val_loss: 1.0345 - val_accuracy: 0.7025
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6681 - accuracy: 0.8276 - val_loss: 0.9633 - val_accuracy: 0.7322
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6635 - accuracy: 0.8279 - val_loss: 0.9909 - val_accuracy: 0.7136
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.6599 - accuracy: 0.8286 - val_loss: 0.8980 - val_accuracy: 0.7420
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6590 - accuracy: 0.8278 - val_loss: 1.0552 - val_accuracy: 0.7048
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6538 - accuracy: 0.8311 - val_loss: 1.0160 - val_accuracy: 0.7224
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6531 - accuracy: 0.8340 - val_loss: 0.9593 - val_accuracy: 0.7368
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6492 - accuracy: 0.8330 - val_loss: 1.0015 - val_accuracy: 0.7177
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6495 - accuracy: 0.8343 - val_loss: 0.9522 - val_accuracy: 0.7415
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6440 - accuracy: 0.8355 - val_loss: 0.8124 - val_accuracy: 0.7780
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6423 - accuracy: 0.8354 - val_loss: 1.3235 - val_accuracy: 0.6316
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6385 - accuracy: 0.8389 - val_loss: 0.8810 - val_accuracy: 0.7584
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6387 - accuracy: 0.8367 - val_loss: 0.8633 - val_accuracy: 0.7629
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.6329 - accuracy: 0.8408 - val_loss: 0.9806 - val_accuracy: 0.7305
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.6339 - accuracy: 0.8399 - val_loss: 1.0036 - val_accuracy: 0.7312
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6330 - accuracy: 0.8393 - val_loss: 0.9209 - val_accuracy: 0.7479
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6306 - accuracy: 0.8423 - val_loss: 0.8665 - val_accuracy: 0.7631
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6257 - accuracy: 0.8435 - val_loss: 0.8770 - val_accuracy: 0.7503
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6249 - accuracy: 0.8432 - val_loss: 0.9214 - val_accuracy: 0.7475
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.6266 - accuracy: 0.8432 - val_loss: 1.0329 - val_accuracy: 0.7110
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6188 - accuracy: 0.8452 - val_loss: 1.0755 - val_accuracy: 0.6902
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6202 - accuracy: 0.8447 - val_loss: 0.8906 - val_accuracy: 0.7577
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6176 - accuracy: 0.8449 - val_loss: 0.7782 - val_accuracy: 0.7919
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.6188 - accuracy: 0.8445 - val_loss: 0.8186 - val_accuracy: 0.7883
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6132 - accuracy: 0.8467 - val_loss: 1.1235 - val_accuracy: 0.6861
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6127 - accuracy: 0.8458 - val_loss: 0.8128 - val_accuracy: 0.7854
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 104ms/step - loss: 0.6110 - accuracy: 0.8485 - val_loss: 1.1614 - val_accuracy: 0.6855
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6149 - accuracy: 0.8473 - val_loss: 0.9283 - val_accuracy: 0.7491
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6086 - accuracy: 0.8506 - val_loss: 0.8981 - val_accuracy: 0.7478
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6078 - accuracy: 0.8501 - val_loss: 1.1553 - val_accuracy: 0.6961
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6044 - accuracy: 0.8518 - val_loss: 1.0531 - val_accuracy: 0.7252
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6041 - accuracy: 0.8495 - val_loss: 0.9582 - val_accuracy: 0.7360
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6039 - accuracy: 0.8506 - val_loss: 0.9470 - val_accuracy: 0.7383
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6032 - accuracy: 0.8496 - val_loss: 0.9809 - val_accuracy: 0.7390
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5966 - accuracy: 0.8533 - val_loss: 0.8223 - val_accuracy: 0.7775
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6017 - accuracy: 0.8517 - val_loss: 0.8552 - val_accuracy: 0.7676
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5980 - accuracy: 0.8526 - val_loss: 0.8872 - val_accuracy: 0.7560
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5968 - accuracy: 0.8531 - val_loss: 0.8735 - val_accuracy: 0.7699
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5930 - accuracy: 0.8539 - val_loss: 1.0635 - val_accuracy: 0.7171
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5912 - accuracy: 0.8558 - val_loss: 0.8190 - val_accuracy: 0.7803
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5911 - accuracy: 0.8548 - val_loss: 1.0935 - val_accuracy: 0.6867
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5903 - accuracy: 0.8559 - val_loss: 0.9967 - val_accuracy: 0.7175
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5889 - accuracy: 0.8557 - val_loss: 0.8148 - val_accuracy: 0.7885
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5889 - accuracy: 0.8565 - val_loss: 0.9273 - val_accuracy: 0.7459
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5849 - accuracy: 0.8568 - val_loss: 0.9947 - val_accuracy: 0.7393
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5837 - accuracy: 0.8579 - val_loss: 1.2549 - val_accuracy: 0.6583
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5835 - accuracy: 0.8577 - val_loss: 0.7850 - val_accuracy: 0.7999
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5843 - accuracy: 0.8578 - val_loss: 0.9719 - val_accuracy: 0.7463
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5788 - accuracy: 0.8585 - val_loss: 1.0439 - val_accuracy: 0.7085
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5831 - accuracy: 0.8574 - val_loss: 0.9593 - val_accuracy: 0.7402
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5788 - accuracy: 0.8605 - val_loss: 0.9714 - val_accuracy: 0.7506
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5772 - accuracy: 0.8606 - val_loss: 0.8296 - val_accuracy: 0.7798
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5771 - accuracy: 0.8619 - val_loss: 0.9386 - val_accuracy: 0.7446
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 109ms/step - loss: 0.5753 - accuracy: 0.8609 - val_loss: 1.1406 - val_accuracy: 0.6810
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5730 - accuracy: 0.8632 - val_loss: 1.2205 - val_accuracy: 0.6796
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5770 - accuracy: 0.8611 - val_loss: 1.1565 - val_accuracy: 0.7068
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5728 - accuracy: 0.8616 - val_loss: 0.8301 - val_accuracy: 0.7808
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5698 - accuracy: 0.8632 - val_loss: 1.0130 - val_accuracy: 0.7423
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5738 - accuracy: 0.8621 - val_loss: 0.9570 - val_accuracy: 0.7414
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5747 - accuracy: 0.8612 - val_loss: 1.0721 - val_accuracy: 0.6984
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5730 - accuracy: 0.8619 - val_loss: 1.0613 - val_accuracy: 0.7199
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5712 - accuracy: 0.8646 - val_loss: 0.9691 - val_accuracy: 0.7486
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5684 - accuracy: 0.8634 - val_loss: 0.9966 - val_accuracy: 0.7380
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5663 - accuracy: 0.8636 - val_loss: 0.9693 - val_accuracy: 0.7404
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5685 - accuracy: 0.8636 - val_loss: 1.1153 - val_accuracy: 0.7281
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5649 - accuracy: 0.8655 - val_loss: 1.1133 - val_accuracy: 0.6859
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5642 - accuracy: 0.8641 - val_loss: 1.0065 - val_accuracy: 0.7434
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5658 - accuracy: 0.8645 - val_loss: 1.5060 - val_accuracy: 0.6075
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5572 - accuracy: 0.8670 - val_loss: 1.3401 - val_accuracy: 0.6666
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 109ms/step - loss: 0.5675 - accuracy: 0.8641 - val_loss: 0.7520 - val_accuracy: 0.8032
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5622 - accuracy: 0.8668 - val_loss: 1.0510 - val_accuracy: 0.7224
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5576 - accuracy: 0.8686 - val_loss: 0.9930 - val_accuracy: 0.7308
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5637 - accuracy: 0.8642 - val_loss: 1.0066 - val_accuracy: 0.7355
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5621 - accuracy: 0.8667 - val_loss: 0.9013 - val_accuracy: 0.7698
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5602 - accuracy: 0.8668 - val_loss: 1.0136 - val_accuracy: 0.7312
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5595 - accuracy: 0.8693 - val_loss: 1.0117 - val_accuracy: 0.7286
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5519 - accuracy: 0.8697 - val_loss: 0.8955 - val_accuracy: 0.7743
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5575 - accuracy: 0.8666 - val_loss: 1.0213 - val_accuracy: 0.7250
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5563 - accuracy: 0.8679 - val_loss: 0.9138 - val_accuracy: 0.7562
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5580 - accuracy: 0.8664 - val_loss: 0.9329 - val_accuracy: 0.7489
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5525 - accuracy: 0.8698 - val_loss: 0.9623 - val_accuracy: 0.7501
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.5533 - accuracy: 0.8686 - val_loss: 0.9276 - val_accuracy: 0.7597
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5530 - accuracy: 0.8671 - val_loss: 1.1283 - val_accuracy: 0.7140
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5547 - accuracy: 0.8685 - val_loss: 1.1836 - val_accuracy: 0.7055
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5562 - accuracy: 0.8683 - val_loss: 0.8122 - val_accuracy: 0.7988
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5535 - accuracy: 0.8701 - val_loss: 1.0871 - val_accuracy: 0.7057
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5545 - accuracy: 0.8694 - val_loss: 0.9466 - val_accuracy: 0.7410
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5479 - accuracy: 0.8702 - val_loss: 0.9047 - val_accuracy: 0.7652
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5477 - accuracy: 0.8688 - val_loss: 0.8975 - val_accuracy: 0.7675
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5494 - accuracy: 0.8701 - val_loss: 1.2057 - val_accuracy: 0.6709
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5499 - accuracy: 0.8697 - val_loss: 0.7813 - val_accuracy: 0.7939
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 44s 111ms/step - loss: 0.5473 - accuracy: 0.8706 - val_loss: 0.8537 - val_accuracy: 0.7760
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5418 - accuracy: 0.8728 - val_loss: 1.0110 - val_accuracy: 0.7271
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5460 - accuracy: 0.8724 - val_loss: 1.0434 - val_accuracy: 0.7380
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5494 - accuracy: 0.8704 - val_loss: 1.0723 - val_accuracy: 0.7213
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5473 - accuracy: 0.8713 - val_loss: 1.2048 - val_accuracy: 0.7013
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5467 - accuracy: 0.8714 - val_loss: 1.1455 - val_accuracy: 0.7047
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5482 - accuracy: 0.8704 - val_loss: 1.3069 - val_accuracy: 0.6665
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5498 - accuracy: 0.8694 - val_loss: 0.9094 - val_accuracy: 0.7716
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.5485 - accuracy: 0.8700 - val_loss: 0.8083 - val_accuracy: 0.7921
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5424 - accuracy: 0.8725 - val_loss: 1.1233 - val_accuracy: 0.7118
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5428 - accuracy: 0.8728 - val_loss: 1.0050 - val_accuracy: 0.7294
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.4501 - accuracy: 0.9062 - val_loss: 0.7225 - val_accuracy: 0.8147
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.4145 - accuracy: 0.9175 - val_loss: 0.6620 - val_accuracy: 0.8318
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.4044 - accuracy: 0.9203 - val_loss: 0.6553 - val_accuracy: 0.8333
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3937 - accuracy: 0.9232 - val_loss: 0.6541 - val_accuracy: 0.8379
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3851 - accuracy: 0.9259 - val_loss: 0.6833 - val_accuracy: 0.8265
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3811 - accuracy: 0.9268 - val_loss: 0.6946 - val_accuracy: 0.8231
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.3763 - accuracy: 0.9267 - val_loss: 0.6830 - val_accuracy: 0.8240
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3705 - accuracy: 0.9275 - val_loss: 0.6419 - val_accuracy: 0.8393
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 112ms/step - loss: 0.3668 - accuracy: 0.9281 - val_loss: 0.6496 - val_accuracy: 0.8346
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3589 - accuracy: 0.9298 - val_loss: 0.6465 - val_accuracy: 0.8395
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 0.3582 - accuracy: 0.9290 - val_loss: 0.6956 - val_accuracy: 0.8219
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3508 - accuracy: 0.9310 - val_loss: 0.7072 - val_accuracy: 0.8147
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 101ms/step - loss: 0.3505 - accuracy: 0.9322 - val_loss: 0.6908 - val_accuracy: 0.8221
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3446 - accuracy: 0.9312 - val_loss: 0.7956 - val_accuracy: 0.7974
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 0.3397 - accuracy: 0.9325 - val_loss: 0.7188 - val_accuracy: 0.8126
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 111ms/step - loss: 0.3383 - accuracy: 0.9312 - val_loss: 0.6703 - val_accuracy: 0.8251
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3342 - accuracy: 0.9336 - val_loss: 0.6987 - val_accuracy: 0.8198
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3315 - accuracy: 0.9351 - val_loss: 0.6778 - val_accuracy: 0.8213
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3287 - accuracy: 0.9345 - val_loss: 0.6784 - val_accuracy: 0.8193
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.3239 - accuracy: 0.9348 - val_loss: 0.7101 - val_accuracy: 0.8166
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3269 - accuracy: 0.9331 - val_loss: 0.6704 - val_accuracy: 0.8219
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3184 - accuracy: 0.9353 - val_loss: 0.6905 - val_accuracy: 0.8202
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3182 - accuracy: 0.9358 - val_loss: 0.6761 - val_accuracy: 0.8218
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 106ms/step - loss: 0.3137 - accuracy: 0.9357 - val_loss: 0.7278 - val_accuracy: 0.8076
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3111 - accuracy: 0.9358 - val_loss: 0.6774 - val_accuracy: 0.8236
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.3070 - accuracy: 0.9371 - val_loss: 0.6977 - val_accuracy: 0.8176
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3063 - accuracy: 0.9372 - val_loss: 0.7481 - val_accuracy: 0.8010
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3078 - accuracy: 0.9357 - val_loss: 0.7429 - val_accuracy: 0.8038
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 101ms/step - loss: 0.3039 - accuracy: 0.9357 - val_loss: 0.6821 - val_accuracy: 0.8215
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 111ms/step - loss: 0.3021 - accuracy: 0.9366 - val_loss: 0.6073 - val_accuracy: 0.8459
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2961 - accuracy: 0.9372 - val_loss: 0.7249 - val_accuracy: 0.8115
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2985 - accuracy: 0.9369 - val_loss: 0.6362 - val_accuracy: 0.8310
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2951 - accuracy: 0.9366 - val_loss: 0.6335 - val_accuracy: 0.8313
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2945 - accuracy: 0.9376 - val_loss: 0.7276 - val_accuracy: 0.8119
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2916 - accuracy: 0.9373 - val_loss: 0.6597 - val_accuracy: 0.8236
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2923 - accuracy: 0.9365 - val_loss: 0.7186 - val_accuracy: 0.8158
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2902 - accuracy: 0.9370 - val_loss: 0.7598 - val_accuracy: 0.8073
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2846 - accuracy: 0.9386 - val_loss: 0.6493 - val_accuracy: 0.8271
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2861 - accuracy: 0.9377 - val_loss: 0.7448 - val_accuracy: 0.8037
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2853 - accuracy: 0.9382 - val_loss: 0.7843 - val_accuracy: 0.7928
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2837 - accuracy: 0.9383 - val_loss: 0.7391 - val_accuracy: 0.8056
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2806 - accuracy: 0.9385 - val_loss: 0.6462 - val_accuracy: 0.8255
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2795 - accuracy: 0.9392 - val_loss: 0.7011 - val_accuracy: 0.8154
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 106ms/step - loss: 0.2785 - accuracy: 0.9383 - val_loss: 0.7802 - val_accuracy: 0.7963
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2811 - accuracy: 0.9365 - val_loss: 0.7036 - val_accuracy: 0.8125
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2792 - accuracy: 0.9376 - val_loss: 0.6841 - val_accuracy: 0.8219
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2761 - accuracy: 0.9384 - val_loss: 0.7644 - val_accuracy: 0.8046
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2758 - accuracy: 0.9380 - val_loss: 0.7864 - val_accuracy: 0.7945
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2744 - accuracy: 0.9378 - val_loss: 0.8102 - val_accuracy: 0.7835
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2527 - accuracy: 0.9470 - val_loss: 0.6383 - val_accuracy: 0.8295
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2437 - accuracy: 0.9495 - val_loss: 0.6489 - val_accuracy: 0.8279
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2431 - accuracy: 0.9508 - val_loss: 0.6584 - val_accuracy: 0.8263
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 109ms/step - loss: 0.2380 - accuracy: 0.9528 - val_loss: 0.6720 - val_accuracy: 0.8225
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2403 - accuracy: 0.9520 - val_loss: 0.6699 - val_accuracy: 0.8230
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2360 - accuracy: 0.9546 - val_loss: 0.6525 - val_accuracy: 0.8252
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 111ms/step - loss: 0.2370 - accuracy: 0.9530 - val_loss: 0.6734 - val_accuracy: 0.8215
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2372 - accuracy: 0.9530 - val_loss: 0.6566 - val_accuracy: 0.8277
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 109ms/step - loss: 0.2346 - accuracy: 0.9537 - val_loss: 0.6750 - val_accuracy: 0.8214
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2345 - accuracy: 0.9538 - val_loss: 0.6402 - val_accuracy: 0.8297
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2328 - accuracy: 0.9543 - val_loss: 0.6739 - val_accuracy: 0.8225
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2336 - accuracy: 0.9529 - val_loss: 0.6488 - val_accuracy: 0.8293
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2326 - accuracy: 0.9547 - val_loss: 0.6565 - val_accuracy: 0.8264
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.2353 - accuracy: 0.9509 - val_loss: 0.6528 - val_accuracy: 0.8293
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.2314 - accuracy: 0.9542 - val_loss: 0.6637 - val_accuracy: 0.8236
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2318 - accuracy: 0.9536 - val_loss: 0.6686 - val_accuracy: 0.8219
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2307 - accuracy: 0.9552 - val_loss: 0.6751 - val_accuracy: 0.8229
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2293 - accuracy: 0.9546 - val_loss: 0.6697 - val_accuracy: 0.8237
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2290 - accuracy: 0.9553 - val_loss: 0.6971 - val_accuracy: 0.8178
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2286 - accuracy: 0.9548 - val_loss: 0.7150 - val_accuracy: 0.8143
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2293 - accuracy: 0.9548 - val_loss: 0.6977 - val_accuracy: 0.8178
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2287 - accuracy: 0.9539 - val_loss: 0.6728 - val_accuracy: 0.8218
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.2274 - accuracy: 0.9549 - val_loss: 0.6939 - val_accuracy: 0.8156
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2285 - accuracy: 0.9536 - val_loss: 0.6811 - val_accuracy: 0.8203
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2263 - accuracy: 0.9550 - val_loss: 0.6740 - val_accuracy: 0.8206
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2235 - accuracy: 0.9569 - val_loss: 0.6662 - val_accuracy: 0.8245
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2257 - accuracy: 0.9563 - val_loss: 0.6910 - val_accuracy: 0.8188
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.2259 - accuracy: 0.9539 - val_loss: 0.6776 - val_accuracy: 0.8229
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2257 - accuracy: 0.9554 - val_loss: 0.6633 - val_accuracy: 0.8255
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2273 - accuracy: 0.9543 - val_loss: 0.7018 - val_accuracy: 0.8156
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2230 - accuracy: 0.9564 - val_loss: 0.6662 - val_accuracy: 0.8252
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 111ms/step - loss: 0.2238 - accuracy: 0.9559 - val_loss: 0.6445 - val_accuracy: 0.8294
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2241 - accuracy: 0.9554 - val_loss: 0.6586 - val_accuracy: 0.8245
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2237 - accuracy: 0.9566 - val_loss: 0.6848 - val_accuracy: 0.8192
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.2284 - accuracy: 0.9539 - val_loss: 0.6872 - val_accuracy: 0.8196
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2217 - accuracy: 0.9569 - val_loss: 0.6665 - val_accuracy: 0.8271
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2234 - accuracy: 0.9554 - val_loss: 0.6525 - val_accuracy: 0.8271
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2223 - accuracy: 0.9557 - val_loss: 0.6888 - val_accuracy: 0.8182
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2213 - accuracy: 0.9568 - val_loss: 0.6577 - val_accuracy: 0.8285
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2208 - accuracy: 0.9570 - val_loss: 0.6456 - val_accuracy: 0.8301
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2216 - accuracy: 0.9567 - val_loss: 0.6594 - val_accuracy: 0.8264
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2217 - accuracy: 0.9562 - val_loss: 0.6505 - val_accuracy: 0.8299
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2177 - accuracy: 0.9581 - val_loss: 0.6757 - val_accuracy: 0.8235
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2173 - accuracy: 0.9576 - val_loss: 0.6809 - val_accuracy: 0.8239
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 106ms/step - loss: 0.2206 - accuracy: 0.9554 - val_loss: 0.6842 - val_accuracy: 0.8194
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2191 - accuracy: 0.9574 - val_loss: 0.6407 - val_accuracy: 0.8313
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2214 - accuracy: 0.9556 - val_loss: 0.7045 - val_accuracy: 0.8157
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2199 - accuracy: 0.9559 - val_loss: 0.7138 - val_accuracy: 0.8126
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2189 - accuracy: 0.9574 - val_loss: 0.7115 - val_accuracy: 0.8157
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2182 - accuracy: 0.9565 - val_loss: 0.6608 - val_accuracy: 0.8270

# %%
quat_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quat_conv2d (QuatConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# quat_residual_unit (QuatResi (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_1 (QuatRe (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_2 (QuatRe (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_3 (QuatRe (None, None, None, 48)    8640
# _________________________________________________________________
# quat_residual_unit_4 (QuatRe (None, None, None, 48)    10752
# _________________________________________________________________
# quat_residual_unit_5 (QuatRe (None, None, None, 96)    33408
# _________________________________________________________________
# quat_residual_unit_6 (QuatRe (None, None, None, 96)    42240
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 104,578
# Trainable params: 102,850
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(quat_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.95818

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(quat_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.827
