# %% [markdown]
# # Quaternion Valued CNN with Real Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class QuatConv2D(layers.Layer):
    """
    Quaternion valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer(),
                 data_format=None,
                 kernel_regularizer=1e-4):
        super(QuatConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        self.kernel_regularizer = kernel_regularizer
        
    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('QuatConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=kr.regularizers.l2(self.kernel_regularizer)
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        # Filter multiplied from the right!
        F_r = tf.concat([ self.f0,-self.f1,-self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3,-self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0, self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2,-self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvQuat = partial(QuatConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class QuatResidualUnit(layers.Layer):
    """ 
    Quaternion valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recognition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual networks.
    """
    def __init__(self, filters, strides=1, activation="elu", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvQuat(filters, strides=strides),
            kr.layers.BatchNormalization(),
            self.activation, 
            DefaultConvQuat(filters),
            kr.layers.BatchNormalization(),
            self.activation]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvQuat(filters, kernel_size=(1,1), strides=strides),
                kr.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

quat_resnet = kr.models.Sequential()
quat_resnet.add(DefaultConvQuat(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    quat_resnet.add(QuatResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
quat_resnet.add(kr.layers.GlobalAvgPool2D())
quat_resnet.add(kr.layers.Flatten())
quat_resnet.add(kr.layers.Dense(10, activation="softmax"))
quat_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

quat_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 48s 105ms/step - loss: 2.2801 - accuracy: 0.3304 - val_loss: 3.1266 - val_accuracy: 0.1343
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 2.0312 - accuracy: 0.4165 - val_loss: 2.6876 - val_accuracy: 0.1741
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 1.9237 - accuracy: 0.4582 - val_loss: 2.4494 - val_accuracy: 0.2561
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 1.8421 - accuracy: 0.4858 - val_loss: 2.3129 - val_accuracy: 0.3196
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 1.7815 - accuracy: 0.5054 - val_loss: 2.5034 - val_accuracy: 0.2970
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 1.7254 - accuracy: 0.5279 - val_loss: 2.3433 - val_accuracy: 0.3312
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 1.6817 - accuracy: 0.5420 - val_loss: 2.9808 - val_accuracy: 0.2411
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 1.6411 - accuracy: 0.5541 - val_loss: 2.0984 - val_accuracy: 0.3818
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 1.6061 - accuracy: 0.5645 - val_loss: 2.1682 - val_accuracy: 0.3424
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 1.5657 - accuracy: 0.5801 - val_loss: 2.2675 - val_accuracy: 0.3388
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 109ms/step - loss: 1.7825 - accuracy: 0.4977 - val_loss: 2.5027 - val_accuracy: 0.3147
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.4970 - accuracy: 0.5855 - val_loss: 2.2360 - val_accuracy: 0.4006
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.3662 - accuracy: 0.6241 - val_loss: 2.2092 - val_accuracy: 0.3805
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 1.2740 - accuracy: 0.6475 - val_loss: 1.7214 - val_accuracy: 0.5242
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 44s 111ms/step - loss: 1.1884 - accuracy: 0.6710 - val_loss: 1.3187 - val_accuracy: 0.6265
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 111ms/step - loss: 1.1260 - accuracy: 0.6879 - val_loss: 1.5120 - val_accuracy: 0.5710
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.0720 - accuracy: 0.7038 - val_loss: 1.9924 - val_accuracy: 0.4355
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 1.0244 - accuracy: 0.7146 - val_loss: 1.1854 - val_accuracy: 0.6631
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.9886 - accuracy: 0.7263 - val_loss: 1.7350 - val_accuracy: 0.4955
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.9553 - accuracy: 0.7358 - val_loss: 1.1915 - val_accuracy: 0.6567
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.9265 - accuracy: 0.7429 - val_loss: 1.4484 - val_accuracy: 0.5798
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.8990 - accuracy: 0.7509 - val_loss: 1.2989 - val_accuracy: 0.6255
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.8810 - accuracy: 0.7564 - val_loss: 1.2531 - val_accuracy: 0.6446
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.8643 - accuracy: 0.7606 - val_loss: 1.2232 - val_accuracy: 0.6501
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.8429 - accuracy: 0.7669 - val_loss: 1.6181 - val_accuracy: 0.5505
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.8288 - accuracy: 0.7715 - val_loss: 1.0238 - val_accuracy: 0.7115
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.8189 - accuracy: 0.7729 - val_loss: 0.9371 - val_accuracy: 0.7411
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.8052 - accuracy: 0.7778 - val_loss: 1.0790 - val_accuracy: 0.6805
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.7941 - accuracy: 0.7830 - val_loss: 1.2193 - val_accuracy: 0.6716
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.7777 - accuracy: 0.7879 - val_loss: 1.0954 - val_accuracy: 0.6904
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.7719 - accuracy: 0.7892 - val_loss: 1.1349 - val_accuracy: 0.6751
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.7643 - accuracy: 0.7926 - val_loss: 1.1417 - val_accuracy: 0.6783
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.7567 - accuracy: 0.7955 - val_loss: 1.2677 - val_accuracy: 0.6469
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7444 - accuracy: 0.7974 - val_loss: 0.9283 - val_accuracy: 0.7466
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.7395 - accuracy: 0.8011 - val_loss: 0.9869 - val_accuracy: 0.7195
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.7310 - accuracy: 0.8039 - val_loss: 1.0366 - val_accuracy: 0.7149
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.7288 - accuracy: 0.8043 - val_loss: 1.0129 - val_accuracy: 0.7191
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7223 - accuracy: 0.8062 - val_loss: 1.0124 - val_accuracy: 0.7117
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.7159 - accuracy: 0.8082 - val_loss: 1.0435 - val_accuracy: 0.7169
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.7089 - accuracy: 0.8130 - val_loss: 1.0245 - val_accuracy: 0.7125
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.7011 - accuracy: 0.8155 - val_loss: 1.0246 - val_accuracy: 0.7157
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7000 - accuracy: 0.8157 - val_loss: 0.9983 - val_accuracy: 0.7208
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6976 - accuracy: 0.8160 - val_loss: 1.0581 - val_accuracy: 0.7104
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6931 - accuracy: 0.8154 - val_loss: 0.9083 - val_accuracy: 0.7582
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6891 - accuracy: 0.8194 - val_loss: 1.0205 - val_accuracy: 0.7188
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6797 - accuracy: 0.8215 - val_loss: 1.0535 - val_accuracy: 0.7071
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6840 - accuracy: 0.8214 - val_loss: 0.9262 - val_accuracy: 0.7461
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6790 - accuracy: 0.8217 - val_loss: 1.0765 - val_accuracy: 0.7019
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6742 - accuracy: 0.8247 - val_loss: 1.0121 - val_accuracy: 0.7191
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6724 - accuracy: 0.8257 - val_loss: 0.9598 - val_accuracy: 0.7267
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6688 - accuracy: 0.8266 - val_loss: 0.8518 - val_accuracy: 0.7628
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6630 - accuracy: 0.8280 - val_loss: 0.9952 - val_accuracy: 0.7210
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.6637 - accuracy: 0.8276 - val_loss: 0.8524 - val_accuracy: 0.7672
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6571 - accuracy: 0.8318 - val_loss: 1.1339 - val_accuracy: 0.6968
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6518 - accuracy: 0.8336 - val_loss: 0.9667 - val_accuracy: 0.7347
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6523 - accuracy: 0.8318 - val_loss: 0.9451 - val_accuracy: 0.7366
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6544 - accuracy: 0.8332 - val_loss: 1.0069 - val_accuracy: 0.7331
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6488 - accuracy: 0.8339 - val_loss: 0.9091 - val_accuracy: 0.7524
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6479 - accuracy: 0.8335 - val_loss: 0.8667 - val_accuracy: 0.7606
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6445 - accuracy: 0.8371 - val_loss: 1.1859 - val_accuracy: 0.6742
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6407 - accuracy: 0.8370 - val_loss: 0.8696 - val_accuracy: 0.7635
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.6390 - accuracy: 0.8358 - val_loss: 1.5579 - val_accuracy: 0.5997
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6381 - accuracy: 0.8384 - val_loss: 0.8253 - val_accuracy: 0.7801
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6314 - accuracy: 0.8390 - val_loss: 0.8658 - val_accuracy: 0.7684
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6329 - accuracy: 0.8390 - val_loss: 0.9616 - val_accuracy: 0.7369
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6306 - accuracy: 0.8406 - val_loss: 0.9398 - val_accuracy: 0.7448
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6292 - accuracy: 0.8417 - val_loss: 0.9484 - val_accuracy: 0.7478
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6283 - accuracy: 0.8414 - val_loss: 1.1480 - val_accuracy: 0.6805
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 0.6249 - accuracy: 0.8422 - val_loss: 0.8575 - val_accuracy: 0.7715
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6186 - accuracy: 0.8452 - val_loss: 1.4816 - val_accuracy: 0.6019
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.6269 - accuracy: 0.8428 - val_loss: 1.1725 - val_accuracy: 0.6829
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.6226 - accuracy: 0.8435 - val_loss: 1.0074 - val_accuracy: 0.7329
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.6161 - accuracy: 0.8468 - val_loss: 0.8824 - val_accuracy: 0.7700
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 0.6163 - accuracy: 0.8465 - val_loss: 1.2781 - val_accuracy: 0.6680
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6196 - accuracy: 0.8459 - val_loss: 0.8511 - val_accuracy: 0.7713
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6146 - accuracy: 0.8459 - val_loss: 0.8073 - val_accuracy: 0.7885
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.6115 - accuracy: 0.8477 - val_loss: 0.8590 - val_accuracy: 0.7673
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6110 - accuracy: 0.8488 - val_loss: 0.8625 - val_accuracy: 0.7611
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6057 - accuracy: 0.8498 - val_loss: 0.8905 - val_accuracy: 0.7571
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6070 - accuracy: 0.8501 - val_loss: 1.0897 - val_accuracy: 0.7009
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.6066 - accuracy: 0.8514 - val_loss: 0.9774 - val_accuracy: 0.7318
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6055 - accuracy: 0.8518 - val_loss: 0.9729 - val_accuracy: 0.7283
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.6071 - accuracy: 0.8492 - val_loss: 0.8108 - val_accuracy: 0.7880
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.6035 - accuracy: 0.8513 - val_loss: 1.0019 - val_accuracy: 0.7398
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6028 - accuracy: 0.8513 - val_loss: 1.1419 - val_accuracy: 0.7129
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6014 - accuracy: 0.8518 - val_loss: 0.8642 - val_accuracy: 0.7770
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 109ms/step - loss: 0.5980 - accuracy: 0.8514 - val_loss: 0.9012 - val_accuracy: 0.7561
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5977 - accuracy: 0.8534 - val_loss: 0.8486 - val_accuracy: 0.7749
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5938 - accuracy: 0.8545 - val_loss: 1.1881 - val_accuracy: 0.6810
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5982 - accuracy: 0.8525 - val_loss: 0.9254 - val_accuracy: 0.7522
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5940 - accuracy: 0.8539 - val_loss: 1.1745 - val_accuracy: 0.6830
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5956 - accuracy: 0.8544 - val_loss: 1.6915 - val_accuracy: 0.6031
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5956 - accuracy: 0.8540 - val_loss: 0.8031 - val_accuracy: 0.7908
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5852 - accuracy: 0.8589 - val_loss: 0.8529 - val_accuracy: 0.7674
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5940 - accuracy: 0.8545 - val_loss: 1.0578 - val_accuracy: 0.7181
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5885 - accuracy: 0.8570 - val_loss: 0.8106 - val_accuracy: 0.7846
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 111ms/step - loss: 0.5889 - accuracy: 0.8568 - val_loss: 1.3419 - val_accuracy: 0.6455
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5853 - accuracy: 0.8578 - val_loss: 1.0943 - val_accuracy: 0.7238
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 0.5900 - accuracy: 0.8576 - val_loss: 0.9661 - val_accuracy: 0.7400
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5843 - accuracy: 0.8599 - val_loss: 0.9401 - val_accuracy: 0.7592
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5821 - accuracy: 0.8593 - val_loss: 1.1128 - val_accuracy: 0.7258
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5839 - accuracy: 0.8595 - val_loss: 0.9343 - val_accuracy: 0.7547
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5827 - accuracy: 0.8594 - val_loss: 0.9693 - val_accuracy: 0.7424
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5803 - accuracy: 0.8601 - val_loss: 0.7659 - val_accuracy: 0.8023
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5806 - accuracy: 0.8601 - val_loss: 0.8835 - val_accuracy: 0.7697
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5762 - accuracy: 0.8606 - val_loss: 0.9829 - val_accuracy: 0.7389
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5756 - accuracy: 0.8615 - val_loss: 0.7929 - val_accuracy: 0.7934
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 104ms/step - loss: 0.5732 - accuracy: 0.8633 - val_loss: 0.9487 - val_accuracy: 0.7364
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5776 - accuracy: 0.8605 - val_loss: 1.1026 - val_accuracy: 0.7247
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5786 - accuracy: 0.8620 - val_loss: 0.8493 - val_accuracy: 0.7761
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5724 - accuracy: 0.8632 - val_loss: 1.1535 - val_accuracy: 0.7031
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5702 - accuracy: 0.8626 - val_loss: 1.0149 - val_accuracy: 0.7320
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5737 - accuracy: 0.8615 - val_loss: 0.8214 - val_accuracy: 0.7807
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 0.5713 - accuracy: 0.8615 - val_loss: 1.2000 - val_accuracy: 0.6920
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 109ms/step - loss: 0.5674 - accuracy: 0.8647 - val_loss: 1.0839 - val_accuracy: 0.6989
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5694 - accuracy: 0.8637 - val_loss: 1.0141 - val_accuracy: 0.7212
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5650 - accuracy: 0.8639 - val_loss: 0.8466 - val_accuracy: 0.7823
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5722 - accuracy: 0.8630 - val_loss: 0.8461 - val_accuracy: 0.7777
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5656 - accuracy: 0.8662 - val_loss: 1.0186 - val_accuracy: 0.7432
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5646 - accuracy: 0.8663 - val_loss: 1.1464 - val_accuracy: 0.7051
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.5657 - accuracy: 0.8655 - val_loss: 0.9762 - val_accuracy: 0.7548
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5675 - accuracy: 0.8641 - val_loss: 1.2009 - val_accuracy: 0.6972
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 44s 113ms/step - loss: 0.5658 - accuracy: 0.8656 - val_loss: 0.9152 - val_accuracy: 0.7547
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5600 - accuracy: 0.8676 - val_loss: 0.8225 - val_accuracy: 0.7857
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5677 - accuracy: 0.8649 - val_loss: 0.8422 - val_accuracy: 0.7931
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 111ms/step - loss: 0.5621 - accuracy: 0.8672 - val_loss: 0.8302 - val_accuracy: 0.7830
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5640 - accuracy: 0.8656 - val_loss: 0.8211 - val_accuracy: 0.7816
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5590 - accuracy: 0.8682 - val_loss: 0.9581 - val_accuracy: 0.7379
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.5617 - accuracy: 0.8650 - val_loss: 0.9134 - val_accuracy: 0.7539
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5644 - accuracy: 0.8665 - val_loss: 0.8782 - val_accuracy: 0.7654
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5606 - accuracy: 0.8682 - val_loss: 0.7949 - val_accuracy: 0.8003
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5575 - accuracy: 0.8690 - val_loss: 1.0234 - val_accuracy: 0.7433
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5640 - accuracy: 0.8655 - val_loss: 1.1823 - val_accuracy: 0.7041
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5522 - accuracy: 0.8696 - val_loss: 0.9740 - val_accuracy: 0.7438
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5570 - accuracy: 0.8697 - val_loss: 0.8677 - val_accuracy: 0.7785
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5525 - accuracy: 0.8701 - val_loss: 0.9577 - val_accuracy: 0.7622
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5554 - accuracy: 0.8685 - val_loss: 0.9471 - val_accuracy: 0.7615
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 0.5510 - accuracy: 0.8714 - val_loss: 0.9654 - val_accuracy: 0.7471
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5581 - accuracy: 0.8684 - val_loss: 0.9973 - val_accuracy: 0.7475
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 44s 112ms/step - loss: 0.5513 - accuracy: 0.8706 - val_loss: 1.1237 - val_accuracy: 0.7247
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5574 - accuracy: 0.8683 - val_loss: 0.8926 - val_accuracy: 0.7706
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 109ms/step - loss: 0.5504 - accuracy: 0.8711 - val_loss: 0.8630 - val_accuracy: 0.7846
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5537 - accuracy: 0.8681 - val_loss: 0.7739 - val_accuracy: 0.8051
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5506 - accuracy: 0.8722 - val_loss: 0.7727 - val_accuracy: 0.8021
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 111ms/step - loss: 0.5483 - accuracy: 0.8717 - val_loss: 0.9601 - val_accuracy: 0.7556
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5522 - accuracy: 0.8703 - val_loss: 0.8459 - val_accuracy: 0.7851
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 109ms/step - loss: 0.5514 - accuracy: 0.8706 - val_loss: 0.9864 - val_accuracy: 0.7427
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5480 - accuracy: 0.8719 - val_loss: 1.0176 - val_accuracy: 0.7465
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 110ms/step - loss: 0.5495 - accuracy: 0.8709 - val_loss: 0.7538 - val_accuracy: 0.8113
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 43s 109ms/step - loss: 0.5489 - accuracy: 0.8733 - val_loss: 1.0264 - val_accuracy: 0.7461
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5478 - accuracy: 0.8712 - val_loss: 0.9356 - val_accuracy: 0.7638
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4463 - accuracy: 0.9078 - val_loss: 0.6782 - val_accuracy: 0.8381
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.4167 - accuracy: 0.9179 - val_loss: 0.6834 - val_accuracy: 0.8305
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 109ms/step - loss: 0.4046 - accuracy: 0.9207 - val_loss: 0.6676 - val_accuracy: 0.8395
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3956 - accuracy: 0.9235 - val_loss: 0.6476 - val_accuracy: 0.8418
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3867 - accuracy: 0.9237 - val_loss: 0.6735 - val_accuracy: 0.8377
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 109ms/step - loss: 0.3823 - accuracy: 0.9259 - val_loss: 0.6529 - val_accuracy: 0.8401
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.3777 - accuracy: 0.9260 - val_loss: 0.7123 - val_accuracy: 0.8226
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 114ms/step - loss: 0.3699 - accuracy: 0.9278 - val_loss: 0.6333 - val_accuracy: 0.8468
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.3659 - accuracy: 0.9295 - val_loss: 0.6767 - val_accuracy: 0.8374
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3633 - accuracy: 0.9284 - val_loss: 0.6772 - val_accuracy: 0.8356
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3564 - accuracy: 0.9305 - val_loss: 0.6726 - val_accuracy: 0.8294
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.3524 - accuracy: 0.9309 - val_loss: 0.6363 - val_accuracy: 0.8410
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3491 - accuracy: 0.9306 - val_loss: 0.6769 - val_accuracy: 0.8367
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 110ms/step - loss: 0.3465 - accuracy: 0.9308 - val_loss: 0.6523 - val_accuracy: 0.8344
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.3411 - accuracy: 0.9324 - val_loss: 0.6837 - val_accuracy: 0.8308
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.3405 - accuracy: 0.9327 - val_loss: 0.7048 - val_accuracy: 0.8226
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3380 - accuracy: 0.9321 - val_loss: 0.6694 - val_accuracy: 0.8333
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 110ms/step - loss: 0.3309 - accuracy: 0.9336 - val_loss: 0.6516 - val_accuracy: 0.8373
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3302 - accuracy: 0.9335 - val_loss: 0.6664 - val_accuracy: 0.8321
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3288 - accuracy: 0.9331 - val_loss: 0.6855 - val_accuracy: 0.8305
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.3254 - accuracy: 0.9349 - val_loss: 0.6551 - val_accuracy: 0.8334
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 44s 113ms/step - loss: 0.3224 - accuracy: 0.9345 - val_loss: 0.6448 - val_accuracy: 0.8379
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 109ms/step - loss: 0.3192 - accuracy: 0.9347 - val_loss: 0.6574 - val_accuracy: 0.8367
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.3162 - accuracy: 0.9348 - val_loss: 0.6653 - val_accuracy: 0.8282
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 110ms/step - loss: 0.3148 - accuracy: 0.9346 - val_loss: 0.6780 - val_accuracy: 0.8258
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.3121 - accuracy: 0.9351 - val_loss: 0.6804 - val_accuracy: 0.8270
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3104 - accuracy: 0.9359 - val_loss: 0.5840 - val_accuracy: 0.8540
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3061 - accuracy: 0.9360 - val_loss: 0.6106 - val_accuracy: 0.8447
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3026 - accuracy: 0.9380 - val_loss: 0.6481 - val_accuracy: 0.8353
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.3013 - accuracy: 0.9378 - val_loss: 0.6684 - val_accuracy: 0.8273
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2973 - accuracy: 0.9379 - val_loss: 0.6630 - val_accuracy: 0.8238
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 111ms/step - loss: 0.2984 - accuracy: 0.9373 - val_loss: 0.6179 - val_accuracy: 0.8440
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3005 - accuracy: 0.9357 - val_loss: 0.6144 - val_accuracy: 0.8464
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2927 - accuracy: 0.9377 - val_loss: 0.7013 - val_accuracy: 0.8250
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 111ms/step - loss: 0.2952 - accuracy: 0.9368 - val_loss: 0.6845 - val_accuracy: 0.8257
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2910 - accuracy: 0.9384 - val_loss: 0.7089 - val_accuracy: 0.8212
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2914 - accuracy: 0.9383 - val_loss: 0.6145 - val_accuracy: 0.8409
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2909 - accuracy: 0.9364 - val_loss: 0.6726 - val_accuracy: 0.8279
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 115ms/step - loss: 0.2860 - accuracy: 0.9396 - val_loss: 0.7588 - val_accuracy: 0.8103
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2898 - accuracy: 0.9366 - val_loss: 0.6619 - val_accuracy: 0.8292
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 109ms/step - loss: 0.2860 - accuracy: 0.9375 - val_loss: 0.6722 - val_accuracy: 0.8289
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2807 - accuracy: 0.9393 - val_loss: 0.7115 - val_accuracy: 0.8155
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2824 - accuracy: 0.9380 - val_loss: 0.6192 - val_accuracy: 0.8433
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2833 - accuracy: 0.9375 - val_loss: 0.6409 - val_accuracy: 0.8360
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2789 - accuracy: 0.9388 - val_loss: 0.7459 - val_accuracy: 0.8160
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2790 - accuracy: 0.9387 - val_loss: 0.6510 - val_accuracy: 0.8294
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2756 - accuracy: 0.9393 - val_loss: 0.6803 - val_accuracy: 0.8251
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 114ms/step - loss: 0.2776 - accuracy: 0.9367 - val_loss: 0.6844 - val_accuracy: 0.8200
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2736 - accuracy: 0.9400 - val_loss: 0.7049 - val_accuracy: 0.8240
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2515 - accuracy: 0.9477 - val_loss: 0.6054 - val_accuracy: 0.8444
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2437 - accuracy: 0.9511 - val_loss: 0.6114 - val_accuracy: 0.8450
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2419 - accuracy: 0.9518 - val_loss: 0.6074 - val_accuracy: 0.8451
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2434 - accuracy: 0.9505 - val_loss: 0.6145 - val_accuracy: 0.8434
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2372 - accuracy: 0.9530 - val_loss: 0.6172 - val_accuracy: 0.8423
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2369 - accuracy: 0.9526 - val_loss: 0.6273 - val_accuracy: 0.8416
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2398 - accuracy: 0.9535 - val_loss: 0.6276 - val_accuracy: 0.8404
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2365 - accuracy: 0.9530 - val_loss: 0.6070 - val_accuracy: 0.8436
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2360 - accuracy: 0.9538 - val_loss: 0.6227 - val_accuracy: 0.8435
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 106ms/step - loss: 0.2332 - accuracy: 0.9547 - val_loss: 0.6256 - val_accuracy: 0.8422
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2385 - accuracy: 0.9519 - val_loss: 0.6226 - val_accuracy: 0.8424
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2330 - accuracy: 0.9537 - val_loss: 0.6144 - val_accuracy: 0.8444
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2307 - accuracy: 0.9545 - val_loss: 0.6268 - val_accuracy: 0.8404
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2322 - accuracy: 0.9548 - val_loss: 0.6256 - val_accuracy: 0.8425
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2343 - accuracy: 0.9529 - val_loss: 0.6267 - val_accuracy: 0.8426
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2329 - accuracy: 0.9537 - val_loss: 0.6222 - val_accuracy: 0.8432
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2317 - accuracy: 0.9550 - val_loss: 0.6165 - val_accuracy: 0.8440
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2315 - accuracy: 0.9546 - val_loss: 0.6051 - val_accuracy: 0.8458
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2306 - accuracy: 0.9543 - val_loss: 0.6203 - val_accuracy: 0.8448
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2291 - accuracy: 0.9553 - val_loss: 0.6166 - val_accuracy: 0.8449
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.2300 - accuracy: 0.9545 - val_loss: 0.6291 - val_accuracy: 0.8412
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 106ms/step - loss: 0.2296 - accuracy: 0.9534 - val_loss: 0.6356 - val_accuracy: 0.8404
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.2291 - accuracy: 0.9548 - val_loss: 0.6427 - val_accuracy: 0.8390
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2267 - accuracy: 0.9572 - val_loss: 0.6083 - val_accuracy: 0.8488
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.2270 - accuracy: 0.9547 - val_loss: 0.6279 - val_accuracy: 0.8425
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.2270 - accuracy: 0.9548 - val_loss: 0.6166 - val_accuracy: 0.8448
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2264 - accuracy: 0.9558 - val_loss: 0.6237 - val_accuracy: 0.8412
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2261 - accuracy: 0.9554 - val_loss: 0.6124 - val_accuracy: 0.8468
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2270 - accuracy: 0.9556 - val_loss: 0.6250 - val_accuracy: 0.8427
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2235 - accuracy: 0.9559 - val_loss: 0.6398 - val_accuracy: 0.8404
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2257 - accuracy: 0.9562 - val_loss: 0.6285 - val_accuracy: 0.8433
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2231 - accuracy: 0.9573 - val_loss: 0.6471 - val_accuracy: 0.8367
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2241 - accuracy: 0.9564 - val_loss: 0.6364 - val_accuracy: 0.8398
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2257 - accuracy: 0.9549 - val_loss: 0.6378 - val_accuracy: 0.8396
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2247 - accuracy: 0.9556 - val_loss: 0.6207 - val_accuracy: 0.8449
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2261 - accuracy: 0.9543 - val_loss: 0.6258 - val_accuracy: 0.8421
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2200 - accuracy: 0.9577 - val_loss: 0.6581 - val_accuracy: 0.8338
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2228 - accuracy: 0.9557 - val_loss: 0.6420 - val_accuracy: 0.8374
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2234 - accuracy: 0.9558 - val_loss: 0.6469 - val_accuracy: 0.8378
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2217 - accuracy: 0.9571 - val_loss: 0.6560 - val_accuracy: 0.8363
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2197 - accuracy: 0.9569 - val_loss: 0.6518 - val_accuracy: 0.8374
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2206 - accuracy: 0.9567 - val_loss: 0.6480 - val_accuracy: 0.8370
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2216 - accuracy: 0.9558 - val_loss: 0.6453 - val_accuracy: 0.8417
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2235 - accuracy: 0.9561 - val_loss: 0.6442 - val_accuracy: 0.8380
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2221 - accuracy: 0.9553 - val_loss: 0.6491 - val_accuracy: 0.8404
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2188 - accuracy: 0.9569 - val_loss: 0.6339 - val_accuracy: 0.8416
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2214 - accuracy: 0.9562 - val_loss: 0.6394 - val_accuracy: 0.8417
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 111ms/step - loss: 0.2181 - accuracy: 0.9564 - val_loss: 0.6468 - val_accuracy: 0.8391
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.2188 - accuracy: 0.9569 - val_loss: 0.6650 - val_accuracy: 0.8354
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2209 - accuracy: 0.9563 - val_loss: 0.6351 - val_accuracy: 0.8401

# %%
quat_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# quat_conv2d (QuatConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# quat_residual_unit (QuatResi (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_1 (QuatRe (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_2 (QuatRe (None, None, None, 24)    2784
# _________________________________________________________________
# quat_residual_unit_3 (QuatRe (None, None, None, 48)    8640
# _________________________________________________________________
# quat_residual_unit_4 (QuatRe (None, None, None, 48)    10752
# _________________________________________________________________
# quat_residual_unit_5 (QuatRe (None, None, None, 96)    33408
# _________________________________________________________________
# quat_residual_unit_6 (QuatRe (None, None, None, 96)    42240
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 104,578
# Trainable params: 102,850
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(quat_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96052

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(quat_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8401
