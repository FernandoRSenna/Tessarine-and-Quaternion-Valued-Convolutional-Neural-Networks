# %% [markdown]
# # Tessarine Valued CNN with Hypercomplex Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class TessConv2D(layers.Layer):
    """
    Tessarine valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """

    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer,
                 data_format=None,
                 kernel_regularizer=1e-3):
        super(TessConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        if kernel_regularizer is not None:
            self.kernel_regularizer = kr.regularizers.l2(kernel_regularizer)
        else:
            self.kernel_regularizer = kernel_regularizer

    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('TessConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        F_r = tf.concat([ self.f0,-self.f1, self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3, self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0,-self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2, self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvTess = partial(TessConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
def diag_init(shape, dtype=None):
    return tf.ones(shape) / 2.

class Hypercomplex4DBNActivation(layers.Layer):
    """
    Batch Normalization for tessarines and quaternions.
    Based on matrix whitening. Decorrelates each component of tessarine/quaternion.
    Includes activation: can be placed before, after or in the middle of BN.
    References:
    [1] Ioffe, S. and Szegedy, C. (2015). Batch normalization: Accelerating deep network training by reducing internal covariate shift.
    [2] Kessy, A., Lewin, A., and Strimmer, K. (2018). Optimal whitening and decorrelation. The American Statistician, 72(4):309–314.
    [3] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Ros-tamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [4] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self,
                 center=True,
                 scale=True,
                 momentum=0.9,
                 beta_init='zeros',
                 gam_diag_init='diag_init',
                 gam_off_init='zeros',
                 mov_mean_init='zeros',
                 mov_var_init='diag_init',
                 mov_cov_init='zeros',
                 beta_reg=None,
                 gam_diag_reg=None,
                 gam_off_reg=None,
                 activation="elu",
                 activation_position="after",
                 epsilon=1e-6,
                 **kwargs):
        super(Hypercomplex4DBNActivation, self).__init__(**kwargs)
        self.center = center
        self.scale = scale
        self.momentum = momentum
        self.beta_init = initializers.get(beta_init)

        if gam_diag_init == 'diag_init':
            self.gam_diag_init = diag_init
        else:
            self.gam_diag_init = initializers.get(gam_diag_init)

        self.gam_off_init = initializers.get(gam_off_init)
        self.mov_mean_init = initializers.get(mov_mean_init)

        if mov_var_init == 'diag_init':
            self.mov_var_init = diag_init
        else:    
            self.mov_var_init = initializers.get(mov_var_init)
            
        self.mov_cov_init = initializers.get(mov_cov_init)
        self.beta_reg = regularizers.get(beta_reg)
        self.gam_diag_reg = regularizers.get(gam_diag_reg)
        self.gam_off_reg = regularizers.get(gam_off_reg)
        self.activation = activations.get(activation)
        self.activation_position = activation_position
        self.epsilon = epsilon

    def build(self, input_shape):
        input_dim = input_shape[-1] // 4
        vars_shape = [input_dim, 1]
        gamma_shape = (input_dim,)

        if self.scale:
            self.mov_Vrr = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vrr")
            self.mov_Vri = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vri")
            self.mov_Vrj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrj")
            self.mov_Vrk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrk")
            self.mov_Vii = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vii")
            self.mov_Vij = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vij")
            self.mov_Vik = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vik")
            self.mov_Vjj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vjj")
            self.mov_Vjk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vjk")
            self.mov_Vkk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vkk")

            self.gam_rr = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_rr")
            self.gam_ri = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ri")
            self.gam_rj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rj")
            self.gam_rk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rk")
            self.gam_ii = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_ii")
            self.gam_ij = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ij")
            self.gam_ik = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ik")
            self.gam_jj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_jj")
            self.gam_jk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_jk")
            self.gam_kk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_kk")
        else:
            self.mov_Vrr = None
            self.mov_Vri = None
            self.mov_Vrj = None
            self.mov_Vrk = None
            self.mov_Vii = None
            self.mov_Vij = None
            self.mov_Vik = None
            self.mov_Vjj = None
            self.mov_Vjk = None
            self.mov_Vkk = None
            self.gam_rr = None
            self.gam_ri = None
            self.gam_rj = None
            self.gam_rk = None
            self.gam_ii = None
            self.gam_ij = None
            self.gam_ik = None
            self.gam_jj = None
            self.gam_jk = None
            self.gam_kk = None

        if self.center:
            self.beta = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                        initializer=self.beta_init,
                                        regularizer=self.beta_reg,
                                        name="beta")
            self.mov_mean = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                            initializer=self.mov_mean_init,
                                            trainable=False,
                                            name="mov_mean")
        else:
            self.beta = None
            self.mov_mean = None

    def _compute_variances(self, centered_r, centered_i, centered_j, centered_k, input_dim):
        Vrr = kr.backend.mean(
            centered_r ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vri = kr.backend.mean(
            centered_r * centered_i,
            axis=[0, 1, 2]
        )

        Vrj = kr.backend.mean(
            centered_r * centered_j,
            axis=[0, 1, 2]
        )

        Vrk = kr.backend.mean(
            centered_r * centered_k,
            axis=[0, 1, 2]
        )

        Vii = kr.backend.mean(
            centered_i ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vij = kr.backend.mean(
            centered_i * centered_j,
            axis=[0, 1, 2]
        )

        Vik = kr.backend.mean(
            centered_i * centered_k,
            axis=[0, 1, 2]
        )

        Vjj = kr.backend.mean(
            centered_j ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vjk = kr.backend.mean(
            centered_j * centered_k,
            axis=[0, 1, 2]
        )

        Vkk = kr.backend.mean(
            centered_k ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        pars_shape = [input_dim, 1]
        Vrr = tf.reshape(Vrr, pars_shape)
        Vri = tf.reshape(Vri, pars_shape)
        Vrj = tf.reshape(Vrj, pars_shape)
        Vrk = tf.reshape(Vrk, pars_shape)
        Vii = tf.reshape(Vii, pars_shape)
        Vij = tf.reshape(Vij, pars_shape)
        Vik = tf.reshape(Vik, pars_shape)
        Vjj = tf.reshape(Vjj, pars_shape)
        Vjk = tf.reshape(Vjk, pars_shape)
        Vkk = tf.reshape(Vkk, pars_shape)

        return Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk
    
    def _moving_exponential_update(self, var, value):
        decay = 1 - self.momentum
        var.assign_sub(var * decay)
        var.assign_add(value * decay)

    def _update_moving_parameters(self, mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk):
        if self.center:
            self._moving_exponential_update(self.mov_mean, mean)

        if self.scale:
            self._moving_exponential_update(self.mov_Vrr, Vrr)
            self._moving_exponential_update(self.mov_Vri, Vri)
            self._moving_exponential_update(self.mov_Vrj, Vrj)
            self._moving_exponential_update(self.mov_Vrk, Vrk)
            self._moving_exponential_update(self.mov_Vii, Vii)
            self._moving_exponential_update(self.mov_Vij, Vij)
            self._moving_exponential_update(self.mov_Vik, Vik)
            self._moving_exponential_update(self.mov_Vjj, Vjj)
            self._moving_exponential_update(self.mov_Vjk, Vjk)
            self._moving_exponential_update(self.mov_Vkk, Vkk)

    def call(self, inputs, training=None):
        if (not self.center) or (not self.scale):
            raise ValueError("Batch Normalization should scale or center.")

        input_shape = kr.backend.int_shape(inputs)
        input_dim = input_shape[-1] // 4

        # Activation before
        if self.activation_position == "before":
            output = self.activation(inputs)
        else:
            output = inputs

        if training in {0, False}:
            mean = self.mov_mean
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr = self.mov_Vrr
                Vri = self.mov_Vri
                Vrj = self.mov_Vrj
                Vrk = self.mov_Vrk
                Vii = self.mov_Vii
                Vij = self.mov_Vij
                Vik = self.mov_Vik
                Vjj = self.mov_Vjj
                Vjk = self.mov_Vjk
                Vkk = self.mov_Vkk
        else:
            # mean and centering
            mean = kr.backend.mean(output, axis=[0, 1, 2])
            mean = kr.backend.reshape(mean, [1, 1, 1, input_dim * 4])
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = self._compute_variances(centered_r, centered_i, centered_j, centered_k, input_dim)
            else:
                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = [None for i in range(10)]  

            self._update_moving_parameters(mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk)

        if self.scale:
            var_reshape = [input_dim, 1, 4]
            # covariance matrix
            V = tf.concat([[tf.reshape(tf.concat([Vrr, Vri, Vrj, Vrk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vri, Vii, Vij, Vik], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrj, Vij, Vjj, Vjk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrk, Vik, Vjk, Vkk], axis=1), var_reshape)]], axis=2)

            # Whitening
            R = tf.reshape(tf.linalg.cholesky(V), [input_dim, 4, 4])
            W = tf.linalg.inv(tf.transpose(R, perm=[0,2,1]))

            Wrr = W[:,0,0]
            Wri = W[:,0,1]
            Wrj = W[:,0,2]
            Wrk = W[:,0,3]
            Wii = W[:,1,1]
            Wij = W[:,1,2]
            Wik = W[:,1,3]
            Wjj = W[:,2,2]
            Wjk = W[:,2,3]
            Wkk = W[:,3,3]

            output_r = centered_r * Wrr
            output_i = centered_r * Wri + centered_i * Wii
            output_j = centered_r * Wrj + centered_i * Wij + centered_j * Wjj
            output_k = centered_r * Wrk + centered_i * Wik + centered_j * Wjk + centered_k * Wkk

            if self.activation_position == "middle":
                output_r = self.activation(output_r)
                output_i = self.activation(output_i)
                output_j = self.activation(output_j)
                output_k = self.activation(output_k)

            out_r = output_r * self.gam_rr
            out_i = output_r * self.gam_ri + output_i * self.gam_ii
            out_j = output_r * self.gam_rj + output_i * self.gam_ij + output_j * self.gam_jj
            out_k = output_r * self.gam_rk + output_i * self.gam_ik + output_j * self.gam_jk + output_k * self.gam_kk
            output = tf.concat([out_r, out_i, out_j, out_k], axis=-1)
        else:
            output = centered
            if self.activation_position == "middle":
                output = self.activation(output)

        if self.center:
            output = output + self.beta

        if self.activation_position == "after":
            output = self.activation(output)

        return output

# %%
class TessResidualUnit(layers.Layer):
    """ 
    Tessarine valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recog-nition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual net-works.
    """
    def __init__(self, filters, strides=1, activation="elu", activation_position='after', **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvTess(filters, strides=strides),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position),
            DefaultConvTess(filters),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position)]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvTess(filters, kernel_size=(1,1), strides=strides),
                Hypercomplex4DBNActivation(activation=None, activation_position='no_activation')]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

tess_resnet = kr.models.Sequential()
tess_resnet.add(DefaultConvTess(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    tess_resnet.add(TessResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
tess_resnet.add(kr.layers.GlobalAvgPool2D())
tess_resnet.add(kr.layers.Flatten())
tess_resnet.add(kr.layers.Dense(10, activation="softmax"))
tess_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

tess_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 166s 292ms/step - loss: 2.2919 - accuracy: 0.3286 - val_loss: 2.4584 - val_accuracy: 0.2336
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 2.0524 - accuracy: 0.4114 - val_loss: 2.4884 - val_accuracy: 0.2329
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 287ms/step - loss: 1.9456 - accuracy: 0.4542 - val_loss: 2.4493 - val_accuracy: 0.2060
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 1.8729 - accuracy: 0.4785 - val_loss: 2.7365 - val_accuracy: 0.2117
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 1.8223 - accuracy: 0.4950 - val_loss: 2.4773 - val_accuracy: 0.2311
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 1.7762 - accuracy: 0.5098 - val_loss: 2.4751 - val_accuracy: 0.2532
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 1.7302 - accuracy: 0.5229 - val_loss: 2.2599 - val_accuracy: 0.3377
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 284ms/step - loss: 1.6954 - accuracy: 0.5358 - val_loss: 2.9582 - val_accuracy: 0.2009
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 1.6519 - accuracy: 0.5516 - val_loss: 2.3180 - val_accuracy: 0.3105
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 284ms/step - loss: 1.6178 - accuracy: 0.5611 - val_loss: 2.0665 - val_accuracy: 0.4008
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 1.7737 - accuracy: 0.4958 - val_loss: 2.6575 - val_accuracy: 0.2673
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 1.5266 - accuracy: 0.5726 - val_loss: 2.3626 - val_accuracy: 0.3062
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 1.4071 - accuracy: 0.6047 - val_loss: 2.0564 - val_accuracy: 0.4211
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 1.3153 - accuracy: 0.6290 - val_loss: 1.9308 - val_accuracy: 0.4375
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 1.2445 - accuracy: 0.6437 - val_loss: 1.7753 - val_accuracy: 0.5004
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 1.1770 - accuracy: 0.6642 - val_loss: 1.9859 - val_accuracy: 0.4271
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 1.1241 - accuracy: 0.6797 - val_loss: 1.7479 - val_accuracy: 0.5244
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 1.0712 - accuracy: 0.6954 - val_loss: 1.4615 - val_accuracy: 0.5591
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 1.0313 - accuracy: 0.7065 - val_loss: 1.3921 - val_accuracy: 0.5836
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.9912 - accuracy: 0.7180 - val_loss: 1.6174 - val_accuracy: 0.5234
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.9568 - accuracy: 0.7269 - val_loss: 1.4938 - val_accuracy: 0.5585
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.9282 - accuracy: 0.7346 - val_loss: 1.1846 - val_accuracy: 0.6516
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.8977 - accuracy: 0.7436 - val_loss: 1.1892 - val_accuracy: 0.6495
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.8732 - accuracy: 0.7523 - val_loss: 1.1807 - val_accuracy: 0.6585
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.8493 - accuracy: 0.7606 - val_loss: 1.2486 - val_accuracy: 0.6261
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.8357 - accuracy: 0.7641 - val_loss: 1.1859 - val_accuracy: 0.6491
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.8209 - accuracy: 0.7704 - val_loss: 0.9850 - val_accuracy: 0.7075
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.7973 - accuracy: 0.7776 - val_loss: 1.0984 - val_accuracy: 0.6872
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.7846 - accuracy: 0.7828 - val_loss: 1.1791 - val_accuracy: 0.6601
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.7719 - accuracy: 0.7854 - val_loss: 1.2420 - val_accuracy: 0.6503
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7636 - accuracy: 0.7888 - val_loss: 1.1001 - val_accuracy: 0.6832
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.7534 - accuracy: 0.7923 - val_loss: 0.9328 - val_accuracy: 0.7359
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.7364 - accuracy: 0.7953 - val_loss: 0.8822 - val_accuracy: 0.7467
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7319 - accuracy: 0.7998 - val_loss: 0.9817 - val_accuracy: 0.7212
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.7240 - accuracy: 0.8001 - val_loss: 1.0050 - val_accuracy: 0.7182
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.7133 - accuracy: 0.8051 - val_loss: 1.1119 - val_accuracy: 0.6659
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.7072 - accuracy: 0.8072 - val_loss: 1.0301 - val_accuracy: 0.7092
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.7000 - accuracy: 0.8104 - val_loss: 0.9806 - val_accuracy: 0.7223
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6942 - accuracy: 0.8128 - val_loss: 0.9805 - val_accuracy: 0.7326
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6874 - accuracy: 0.8149 - val_loss: 1.0105 - val_accuracy: 0.7158
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.6803 - accuracy: 0.8184 - val_loss: 0.9739 - val_accuracy: 0.7248
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6717 - accuracy: 0.8189 - val_loss: 1.1322 - val_accuracy: 0.6770
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.6672 - accuracy: 0.8229 - val_loss: 1.0251 - val_accuracy: 0.7178
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.6631 - accuracy: 0.8223 - val_loss: 0.9300 - val_accuracy: 0.7320
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.6641 - accuracy: 0.8218 - val_loss: 1.0011 - val_accuracy: 0.7211
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.6547 - accuracy: 0.8267 - val_loss: 0.7412 - val_accuracy: 0.7961
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.6494 - accuracy: 0.8273 - val_loss: 1.4096 - val_accuracy: 0.6350
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.6446 - accuracy: 0.8300 - val_loss: 1.2023 - val_accuracy: 0.6602
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.6406 - accuracy: 0.8310 - val_loss: 1.0952 - val_accuracy: 0.7066
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.6391 - accuracy: 0.8313 - val_loss: 0.9107 - val_accuracy: 0.7569
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.6392 - accuracy: 0.8339 - val_loss: 1.2273 - val_accuracy: 0.6665
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.6365 - accuracy: 0.8343 - val_loss: 1.0083 - val_accuracy: 0.7229
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.6288 - accuracy: 0.8348 - val_loss: 0.8076 - val_accuracy: 0.7796
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.6238 - accuracy: 0.8390 - val_loss: 1.3233 - val_accuracy: 0.6664
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.6241 - accuracy: 0.8392 - val_loss: 0.8079 - val_accuracy: 0.7807
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.6210 - accuracy: 0.8399 - val_loss: 0.9136 - val_accuracy: 0.7403
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.6173 - accuracy: 0.8409 - val_loss: 0.8422 - val_accuracy: 0.7663
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6122 - accuracy: 0.8435 - val_loss: 1.1265 - val_accuracy: 0.7090
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.6146 - accuracy: 0.8404 - val_loss: 0.7635 - val_accuracy: 0.7929
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.6092 - accuracy: 0.8441 - val_loss: 0.8571 - val_accuracy: 0.7667
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.6069 - accuracy: 0.8435 - val_loss: 0.8418 - val_accuracy: 0.7696
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.6036 - accuracy: 0.8449 - val_loss: 0.7824 - val_accuracy: 0.7911
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.6017 - accuracy: 0.8475 - val_loss: 0.8385 - val_accuracy: 0.7731
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.6018 - accuracy: 0.8469 - val_loss: 0.8534 - val_accuracy: 0.7696
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.6017 - accuracy: 0.8466 - val_loss: 0.9049 - val_accuracy: 0.7439
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5967 - accuracy: 0.8483 - val_loss: 0.9880 - val_accuracy: 0.7333
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5960 - accuracy: 0.8493 - val_loss: 0.9173 - val_accuracy: 0.7466
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5892 - accuracy: 0.8505 - val_loss: 0.8998 - val_accuracy: 0.7542
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5845 - accuracy: 0.8539 - val_loss: 1.0557 - val_accuracy: 0.7021
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5861 - accuracy: 0.8537 - val_loss: 0.7348 - val_accuracy: 0.8037
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5863 - accuracy: 0.8520 - val_loss: 0.8508 - val_accuracy: 0.7707
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5821 - accuracy: 0.8532 - val_loss: 1.1392 - val_accuracy: 0.6973
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5791 - accuracy: 0.8540 - val_loss: 1.1875 - val_accuracy: 0.6909
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5833 - accuracy: 0.8530 - val_loss: 1.0197 - val_accuracy: 0.7369
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5822 - accuracy: 0.8545 - val_loss: 0.8828 - val_accuracy: 0.7643
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5799 - accuracy: 0.8545 - val_loss: 0.9609 - val_accuracy: 0.7364
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5764 - accuracy: 0.8555 - val_loss: 0.9259 - val_accuracy: 0.7453
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5732 - accuracy: 0.8568 - val_loss: 0.9697 - val_accuracy: 0.7347
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5722 - accuracy: 0.8586 - val_loss: 0.7616 - val_accuracy: 0.7962
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5712 - accuracy: 0.8588 - val_loss: 1.0607 - val_accuracy: 0.6988
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5667 - accuracy: 0.8595 - val_loss: 0.7426 - val_accuracy: 0.8052
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5662 - accuracy: 0.8591 - val_loss: 0.7398 - val_accuracy: 0.8006
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5663 - accuracy: 0.8606 - val_loss: 0.9121 - val_accuracy: 0.7461
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5625 - accuracy: 0.8622 - val_loss: 0.8463 - val_accuracy: 0.7707
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5624 - accuracy: 0.8613 - val_loss: 1.0558 - val_accuracy: 0.6980
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5619 - accuracy: 0.8611 - val_loss: 0.8103 - val_accuracy: 0.7799
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5630 - accuracy: 0.8617 - val_loss: 0.9377 - val_accuracy: 0.7405
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5605 - accuracy: 0.8624 - val_loss: 1.0578 - val_accuracy: 0.7096
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5591 - accuracy: 0.8620 - val_loss: 0.9672 - val_accuracy: 0.7293
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5597 - accuracy: 0.8603 - val_loss: 0.8480 - val_accuracy: 0.7785
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5534 - accuracy: 0.8647 - val_loss: 1.0161 - val_accuracy: 0.7327
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5560 - accuracy: 0.8643 - val_loss: 1.0292 - val_accuracy: 0.7118
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5584 - accuracy: 0.8618 - val_loss: 0.7036 - val_accuracy: 0.8137
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5511 - accuracy: 0.8645 - val_loss: 0.8119 - val_accuracy: 0.7836
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5516 - accuracy: 0.8650 - val_loss: 0.7356 - val_accuracy: 0.8043
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5491 - accuracy: 0.8652 - val_loss: 0.9348 - val_accuracy: 0.7578
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5499 - accuracy: 0.8664 - val_loss: 1.0026 - val_accuracy: 0.7409
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5489 - accuracy: 0.8666 - val_loss: 0.7506 - val_accuracy: 0.8068
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5479 - accuracy: 0.8667 - val_loss: 0.8498 - val_accuracy: 0.7683
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5478 - accuracy: 0.8670 - val_loss: 1.5522 - val_accuracy: 0.6180
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5443 - accuracy: 0.8680 - val_loss: 0.7742 - val_accuracy: 0.7964
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5462 - accuracy: 0.8675 - val_loss: 0.7908 - val_accuracy: 0.7956
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5423 - accuracy: 0.8675 - val_loss: 1.2254 - val_accuracy: 0.6858
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5450 - accuracy: 0.8675 - val_loss: 0.8017 - val_accuracy: 0.7961
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5423 - accuracy: 0.8682 - val_loss: 1.2775 - val_accuracy: 0.6959
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.5432 - accuracy: 0.8674 - val_loss: 1.0945 - val_accuracy: 0.7202
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5452 - accuracy: 0.8694 - val_loss: 0.8558 - val_accuracy: 0.7791
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5407 - accuracy: 0.8689 - val_loss: 0.8087 - val_accuracy: 0.7856
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5379 - accuracy: 0.8723 - val_loss: 1.2122 - val_accuracy: 0.6974
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5388 - accuracy: 0.8694 - val_loss: 0.7949 - val_accuracy: 0.7909
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5363 - accuracy: 0.8722 - val_loss: 0.9857 - val_accuracy: 0.7444
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5361 - accuracy: 0.8725 - val_loss: 1.1759 - val_accuracy: 0.7006
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5311 - accuracy: 0.8728 - val_loss: 0.6991 - val_accuracy: 0.8276
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5329 - accuracy: 0.8731 - val_loss: 0.7495 - val_accuracy: 0.8148
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5333 - accuracy: 0.8720 - val_loss: 1.0206 - val_accuracy: 0.7297
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5353 - accuracy: 0.8727 - val_loss: 1.0886 - val_accuracy: 0.6988
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5333 - accuracy: 0.8730 - val_loss: 1.1342 - val_accuracy: 0.6821
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5343 - accuracy: 0.8723 - val_loss: 0.6930 - val_accuracy: 0.8219
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5316 - accuracy: 0.8741 - val_loss: 0.8433 - val_accuracy: 0.7716
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5316 - accuracy: 0.8740 - val_loss: 1.2900 - val_accuracy: 0.6542
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5315 - accuracy: 0.8733 - val_loss: 0.7798 - val_accuracy: 0.7917
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5291 - accuracy: 0.8740 - val_loss: 0.9301 - val_accuracy: 0.7600
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5242 - accuracy: 0.8738 - val_loss: 0.7513 - val_accuracy: 0.8043
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5294 - accuracy: 0.8729 - val_loss: 0.9595 - val_accuracy: 0.7384
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5343 - accuracy: 0.8713 - val_loss: 0.9818 - val_accuracy: 0.7528
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5256 - accuracy: 0.8759 - val_loss: 1.1286 - val_accuracy: 0.7167
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5275 - accuracy: 0.8746 - val_loss: 0.7898 - val_accuracy: 0.7940
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5250 - accuracy: 0.8751 - val_loss: 0.8304 - val_accuracy: 0.7894
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5301 - accuracy: 0.8741 - val_loss: 1.0664 - val_accuracy: 0.7176
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5217 - accuracy: 0.8767 - val_loss: 1.3479 - val_accuracy: 0.6557
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5292 - accuracy: 0.8740 - val_loss: 0.9404 - val_accuracy: 0.7533
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.5274 - accuracy: 0.8756 - val_loss: 0.9717 - val_accuracy: 0.7522
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5198 - accuracy: 0.8789 - val_loss: 0.9612 - val_accuracy: 0.7556
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5208 - accuracy: 0.8758 - val_loss: 1.0276 - val_accuracy: 0.7249
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5206 - accuracy: 0.8790 - val_loss: 0.7950 - val_accuracy: 0.8013
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5156 - accuracy: 0.8803 - val_loss: 0.9890 - val_accuracy: 0.7503
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5231 - accuracy: 0.8769 - val_loss: 0.8600 - val_accuracy: 0.7757
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5243 - accuracy: 0.8767 - val_loss: 1.6395 - val_accuracy: 0.5789
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5173 - accuracy: 0.8787 - val_loss: 0.8530 - val_accuracy: 0.7765
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5192 - accuracy: 0.8766 - val_loss: 0.7754 - val_accuracy: 0.8109
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5218 - accuracy: 0.8785 - val_loss: 0.9731 - val_accuracy: 0.7395
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 0.5179 - accuracy: 0.8779 - val_loss: 0.9185 - val_accuracy: 0.7732
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5165 - accuracy: 0.8789 - val_loss: 0.9856 - val_accuracy: 0.7336
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 287ms/step - loss: 0.5112 - accuracy: 0.8810 - val_loss: 0.8146 - val_accuracy: 0.7902
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.5163 - accuracy: 0.8786 - val_loss: 0.7575 - val_accuracy: 0.8072
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5156 - accuracy: 0.8787 - val_loss: 0.9545 - val_accuracy: 0.7501
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 0.5203 - accuracy: 0.8776 - val_loss: 0.9415 - val_accuracy: 0.7662
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 291ms/step - loss: 0.5153 - accuracy: 0.8798 - val_loss: 0.9640 - val_accuracy: 0.7560
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 290ms/step - loss: 0.5154 - accuracy: 0.8790 - val_loss: 1.0131 - val_accuracy: 0.7357
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 289ms/step - loss: 0.5185 - accuracy: 0.8784 - val_loss: 0.7999 - val_accuracy: 0.7879
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5171 - accuracy: 0.8797 - val_loss: 0.9137 - val_accuracy: 0.7638
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.4230 - accuracy: 0.9125 - val_loss: 0.6293 - val_accuracy: 0.8443
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 289ms/step - loss: 0.3928 - accuracy: 0.9230 - val_loss: 0.6036 - val_accuracy: 0.8528
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.3804 - accuracy: 0.9258 - val_loss: 0.6034 - val_accuracy: 0.8516
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.3725 - accuracy: 0.9276 - val_loss: 0.6018 - val_accuracy: 0.8541
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 114s 291ms/step - loss: 0.3681 - accuracy: 0.9272 - val_loss: 0.5978 - val_accuracy: 0.8494
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.3588 - accuracy: 0.9298 - val_loss: 0.5987 - val_accuracy: 0.8517
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 289ms/step - loss: 0.3522 - accuracy: 0.9317 - val_loss: 0.6234 - val_accuracy: 0.8456
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 289ms/step - loss: 0.3476 - accuracy: 0.9332 - val_loss: 0.5978 - val_accuracy: 0.8543
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.3441 - accuracy: 0.9333 - val_loss: 0.6549 - val_accuracy: 0.8333
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 289ms/step - loss: 0.3376 - accuracy: 0.9344 - val_loss: 0.5927 - val_accuracy: 0.8545
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 114s 293ms/step - loss: 0.3376 - accuracy: 0.9343 - val_loss: 0.5965 - val_accuracy: 0.8507
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 287ms/step - loss: 0.3320 - accuracy: 0.9358 - val_loss: 0.5907 - val_accuracy: 0.8539
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 285ms/step - loss: 0.3265 - accuracy: 0.9363 - val_loss: 0.5931 - val_accuracy: 0.8507
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.3212 - accuracy: 0.9366 - val_loss: 0.6214 - val_accuracy: 0.8473
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 289ms/step - loss: 0.3184 - accuracy: 0.9376 - val_loss: 0.6059 - val_accuracy: 0.8466
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 285ms/step - loss: 0.3191 - accuracy: 0.9382 - val_loss: 0.5683 - val_accuracy: 0.8622
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 0.3144 - accuracy: 0.9389 - val_loss: 0.5857 - val_accuracy: 0.8557
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.3112 - accuracy: 0.9377 - val_loss: 0.6169 - val_accuracy: 0.8416
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 284ms/step - loss: 0.3092 - accuracy: 0.9389 - val_loss: 0.5843 - val_accuracy: 0.8538
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.3045 - accuracy: 0.9389 - val_loss: 0.6072 - val_accuracy: 0.8473
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.3025 - accuracy: 0.9398 - val_loss: 0.5846 - val_accuracy: 0.8490
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.3017 - accuracy: 0.9388 - val_loss: 0.6088 - val_accuracy: 0.8450
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2976 - accuracy: 0.9400 - val_loss: 0.5800 - val_accuracy: 0.8516
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 285ms/step - loss: 0.2919 - accuracy: 0.9415 - val_loss: 0.5706 - val_accuracy: 0.8562
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.2902 - accuracy: 0.9407 - val_loss: 0.6124 - val_accuracy: 0.8427
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2889 - accuracy: 0.9404 - val_loss: 0.6252 - val_accuracy: 0.8402
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 0.2919 - accuracy: 0.9382 - val_loss: 0.5918 - val_accuracy: 0.8447
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 285ms/step - loss: 0.2871 - accuracy: 0.9393 - val_loss: 0.6071 - val_accuracy: 0.8448
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2842 - accuracy: 0.9412 - val_loss: 0.6056 - val_accuracy: 0.8459
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.2849 - accuracy: 0.9405 - val_loss: 0.5470 - val_accuracy: 0.8580
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2808 - accuracy: 0.9421 - val_loss: 0.5507 - val_accuracy: 0.8578
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2798 - accuracy: 0.9410 - val_loss: 0.6617 - val_accuracy: 0.8293
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2741 - accuracy: 0.9432 - val_loss: 0.5944 - val_accuracy: 0.8463
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2754 - accuracy: 0.9422 - val_loss: 0.5870 - val_accuracy: 0.8492
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2729 - accuracy: 0.9426 - val_loss: 0.6052 - val_accuracy: 0.8438
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 288ms/step - loss: 0.2722 - accuracy: 0.9430 - val_loss: 0.5922 - val_accuracy: 0.8406
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2698 - accuracy: 0.9426 - val_loss: 0.6903 - val_accuracy: 0.8222
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2677 - accuracy: 0.9420 - val_loss: 0.6555 - val_accuracy: 0.8272
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2634 - accuracy: 0.9427 - val_loss: 0.5815 - val_accuracy: 0.8500
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2664 - accuracy: 0.9421 - val_loss: 0.5817 - val_accuracy: 0.8472
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2653 - accuracy: 0.9421 - val_loss: 0.5422 - val_accuracy: 0.8631
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 0.2647 - accuracy: 0.9424 - val_loss: 0.5919 - val_accuracy: 0.8489
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2585 - accuracy: 0.9440 - val_loss: 0.6458 - val_accuracy: 0.8289
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 0.2611 - accuracy: 0.9426 - val_loss: 0.6584 - val_accuracy: 0.8239
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2599 - accuracy: 0.9438 - val_loss: 0.5704 - val_accuracy: 0.8471
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2572 - accuracy: 0.9439 - val_loss: 0.5613 - val_accuracy: 0.8539
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2581 - accuracy: 0.9436 - val_loss: 0.7044 - val_accuracy: 0.8199
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 112s 286ms/step - loss: 0.2555 - accuracy: 0.9438 - val_loss: 0.5703 - val_accuracy: 0.8484
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 113s 289ms/step - loss: 0.2552 - accuracy: 0.9425 - val_loss: 0.5756 - val_accuracy: 0.8540
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 113s 289ms/step - loss: 0.2374 - accuracy: 0.9503 - val_loss: 0.5343 - val_accuracy: 0.8575
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 112s 287ms/step - loss: 0.2261 - accuracy: 0.9549 - val_loss: 0.5385 - val_accuracy: 0.8601
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 112s 287ms/step - loss: 0.2252 - accuracy: 0.9548 - val_loss: 0.5436 - val_accuracy: 0.8578
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2237 - accuracy: 0.9563 - val_loss: 0.5378 - val_accuracy: 0.8591
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 275ms/step - loss: 0.2215 - accuracy: 0.9557 - val_loss: 0.5389 - val_accuracy: 0.8607
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2215 - accuracy: 0.9563 - val_loss: 0.5462 - val_accuracy: 0.8572
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2180 - accuracy: 0.9570 - val_loss: 0.5445 - val_accuracy: 0.8588
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 280ms/step - loss: 0.2174 - accuracy: 0.9575 - val_loss: 0.5493 - val_accuracy: 0.8571
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2154 - accuracy: 0.9592 - val_loss: 0.5504 - val_accuracy: 0.8559
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2175 - accuracy: 0.9571 - val_loss: 0.5441 - val_accuracy: 0.8581
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2158 - accuracy: 0.9585 - val_loss: 0.5733 - val_accuracy: 0.8501
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2153 - accuracy: 0.9588 - val_loss: 0.5507 - val_accuracy: 0.8575
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2182 - accuracy: 0.9568 - val_loss: 0.5497 - val_accuracy: 0.8595
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2179 - accuracy: 0.9574 - val_loss: 0.5604 - val_accuracy: 0.8548
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2168 - accuracy: 0.9574 - val_loss: 0.5591 - val_accuracy: 0.8541
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2131 - accuracy: 0.9595 - val_loss: 0.5677 - val_accuracy: 0.8521
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2141 - accuracy: 0.9579 - val_loss: 0.5564 - val_accuracy: 0.8568
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2139 - accuracy: 0.9576 - val_loss: 0.5473 - val_accuracy: 0.8599
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2124 - accuracy: 0.9594 - val_loss: 0.5537 - val_accuracy: 0.8569
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2122 - accuracy: 0.9584 - val_loss: 0.5689 - val_accuracy: 0.8533
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2138 - accuracy: 0.9577 - val_loss: 0.5635 - val_accuracy: 0.8545
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 110s 280ms/step - loss: 0.2125 - accuracy: 0.9588 - val_loss: 0.5497 - val_accuracy: 0.8572
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 113s 289ms/step - loss: 0.2128 - accuracy: 0.9582 - val_loss: 0.5589 - val_accuracy: 0.8545
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 113s 290ms/step - loss: 0.2110 - accuracy: 0.9593 - val_loss: 0.5677 - val_accuracy: 0.8517
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 115s 293ms/step - loss: 0.2097 - accuracy: 0.9593 - val_loss: 0.5440 - val_accuracy: 0.8591
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 114s 291ms/step - loss: 0.2080 - accuracy: 0.9604 - val_loss: 0.5499 - val_accuracy: 0.8579
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 114s 292ms/step - loss: 0.2106 - accuracy: 0.9587 - val_loss: 0.5494 - val_accuracy: 0.8564
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2125 - accuracy: 0.9583 - val_loss: 0.5579 - val_accuracy: 0.8568
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2096 - accuracy: 0.9592 - val_loss: 0.5710 - val_accuracy: 0.8519
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2085 - accuracy: 0.9594 - val_loss: 0.5512 - val_accuracy: 0.8565
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2096 - accuracy: 0.9595 - val_loss: 0.5400 - val_accuracy: 0.8619
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2068 - accuracy: 0.9606 - val_loss: 0.5686 - val_accuracy: 0.8530
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2069 - accuracy: 0.9604 - val_loss: 0.5556 - val_accuracy: 0.8556
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 277ms/step - loss: 0.2075 - accuracy: 0.9598 - val_loss: 0.5473 - val_accuracy: 0.8596
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2093 - accuracy: 0.9586 - val_loss: 0.5578 - val_accuracy: 0.8553
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2083 - accuracy: 0.9592 - val_loss: 0.5526 - val_accuracy: 0.8578
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2076 - accuracy: 0.9604 - val_loss: 0.5618 - val_accuracy: 0.8563
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 112s 285ms/step - loss: 0.2067 - accuracy: 0.9599 - val_loss: 0.5561 - val_accuracy: 0.8565
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2057 - accuracy: 0.9593 - val_loss: 0.5491 - val_accuracy: 0.8583
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 280ms/step - loss: 0.2045 - accuracy: 0.9615 - val_loss: 0.5599 - val_accuracy: 0.8576
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2052 - accuracy: 0.9607 - val_loss: 0.5591 - val_accuracy: 0.8561
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2047 - accuracy: 0.9602 - val_loss: 0.5669 - val_accuracy: 0.8540
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 110s 282ms/step - loss: 0.2037 - accuracy: 0.9609 - val_loss: 0.5661 - val_accuracy: 0.8543
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 112s 286ms/step - loss: 0.2040 - accuracy: 0.9601 - val_loss: 0.5720 - val_accuracy: 0.8550
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2056 - accuracy: 0.9604 - val_loss: 0.5641 - val_accuracy: 0.8549
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 112s 285ms/step - loss: 0.2033 - accuracy: 0.9612 - val_loss: 0.5751 - val_accuracy: 0.8510
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2055 - accuracy: 0.9598 - val_loss: 0.5590 - val_accuracy: 0.8559
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2019 - accuracy: 0.9622 - val_loss: 0.5422 - val_accuracy: 0.8604
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2042 - accuracy: 0.9610 - val_loss: 0.5579 - val_accuracy: 0.8549
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 113s 288ms/step - loss: 0.2030 - accuracy: 0.9619 - val_loss: 0.5553 - val_accuracy: 0.8569

# %%
tess_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tess_conv2d (TessConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# tess_residual_unit (TessResi (None, None, None, 24)    2928
# _________________________________________________________________
# tess_residual_unit_1 (TessRe (None, None, None, 24)    2928
# _________________________________________________________________
# tess_residual_unit_2 (TessRe (None, None, None, 24)    2928
# _________________________________________________________________
# tess_residual_unit_3 (TessRe (None, None, None, 48)    9072
# _________________________________________________________________
# tess_residual_unit_4 (TessRe (None, None, None, 48)    11040
# _________________________________________________________________
# tess_residual_unit_5 (TessRe (None, None, None, 96)    34272
# _________________________________________________________________
# tess_residual_unit_6 (TessRe (None, None, None, 96)    42816
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 107,170
# Trainable params: 104,146
# Non-trainable params: 3,024
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(tess_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96462

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(tess_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8569
