# %% [markdown]
# # Tessarine Valued CNN with Hypercomplex Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class TessConv2D(layers.Layer):
    """
    Tessarine valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """

    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer,
                 data_format=None,
                 kernel_regularizer=1e-3):
        super(TessConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        if kernel_regularizer is not None:
            self.kernel_regularizer = kr.regularizers.l2(kernel_regularizer)
        else:
            self.kernel_regularizer = kernel_regularizer

    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('TessConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        F_r = tf.concat([ self.f0,-self.f1, self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3, self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0,-self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2, self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvTess = partial(TessConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
def diag_init(shape, dtype=None):
    return tf.ones(shape) / 2.

class Hypercomplex4DBNActivation(layers.Layer):
    """
    Batch Normalization for tessarines and quaternions.
    Based on matrix whitening. Decorrelates each component of tessarine/quaternion.
    Includes activation: can be placed before, after or in the middle of BN.
    References:
    [1] Ioffe, S. and Szegedy, C. (2015). Batch normalization: Accelerating deep network training by reducing internal covariate shift.
    [2] Kessy, A., Lewin, A., and Strimmer, K. (2018). Optimal whitening and decorrelation. The American Statistician, 72(4):309–314.
    [3] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Ros-tamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [4] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """
    def __init__(self,
                 center=True,
                 scale=True,
                 momentum=0.9,
                 beta_init='zeros',
                 gam_diag_init='diag_init',
                 gam_off_init='zeros',
                 mov_mean_init='zeros',
                 mov_var_init='diag_init',
                 mov_cov_init='zeros',
                 beta_reg=None,
                 gam_diag_reg=None,
                 gam_off_reg=None,
                 activation="elu",
                 activation_position="after",
                 epsilon=1e-6,
                 **kwargs):
        super(Hypercomplex4DBNActivation, self).__init__(**kwargs)
        self.center = center
        self.scale = scale
        self.momentum = momentum
        self.beta_init = initializers.get(beta_init)

        if gam_diag_init == 'diag_init':
            self.gam_diag_init = diag_init
        else:
            self.gam_diag_init = initializers.get(gam_diag_init)

        self.gam_off_init = initializers.get(gam_off_init)
        self.mov_mean_init = initializers.get(mov_mean_init)

        if mov_var_init == 'diag_init':
            self.mov_var_init = diag_init
        else:    
            self.mov_var_init = initializers.get(mov_var_init)
            
        self.mov_cov_init = initializers.get(mov_cov_init)
        self.beta_reg = regularizers.get(beta_reg)
        self.gam_diag_reg = regularizers.get(gam_diag_reg)
        self.gam_off_reg = regularizers.get(gam_off_reg)
        self.activation = activations.get(activation)
        self.activation_position = activation_position
        self.epsilon = epsilon

    def build(self, input_shape):
        input_dim = input_shape[-1] // 4
        vars_shape = [input_dim, 1]
        gamma_shape = (input_dim,)

        if self.scale:
            self.mov_Vrr = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vrr")
            self.mov_Vri = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vri")
            self.mov_Vrj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrj")
            self.mov_Vrk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vrk")
            self.mov_Vii = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vii")
            self.mov_Vij = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vij")
            self.mov_Vik = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vik")
            self.mov_Vjj = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vjj")
            self.mov_Vjk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_cov_init,
                                           trainable=False,
                                           name="mov_Vjk")
            self.mov_Vkk = self.add_weight(shape=vars_shape,
                                           initializer=self.mov_var_init,
                                           trainable=False,
                                           name="mov_Vkk")

            self.gam_rr = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_rr")
            self.gam_ri = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ri")
            self.gam_rj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rj")
            self.gam_rk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_rk")
            self.gam_ii = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_ii")
            self.gam_ij = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ij")
            self.gam_ik = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_ik")
            self.gam_jj = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_jj")
            self.gam_jk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_off_init,
                                          regularizer=self.gam_off_reg,
                                          name="gam_jk")
            self.gam_kk = self.add_weight(shape=gamma_shape,
                                          initializer=self.gam_diag_init,
                                          regularizer=self.gam_diag_reg,
                                          name="gam_kk")
        else:
            self.mov_Vrr = None
            self.mov_Vri = None
            self.mov_Vrj = None
            self.mov_Vrk = None
            self.mov_Vii = None
            self.mov_Vij = None
            self.mov_Vik = None
            self.mov_Vjj = None
            self.mov_Vjk = None
            self.mov_Vkk = None
            self.gam_rr = None
            self.gam_ri = None
            self.gam_rj = None
            self.gam_rk = None
            self.gam_ii = None
            self.gam_ij = None
            self.gam_ik = None
            self.gam_jj = None
            self.gam_jk = None
            self.gam_kk = None

        if self.center:
            self.beta = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                        initializer=self.beta_init,
                                        regularizer=self.beta_reg,
                                        name="beta")
            self.mov_mean = self.add_weight(shape=(1, 1, 1, input_shape[-1]),
                                            initializer=self.mov_mean_init,
                                            trainable=False,
                                            name="mov_mean")
        else:
            self.beta = None
            self.mov_mean = None

    def _compute_variances(self, centered_r, centered_i, centered_j, centered_k, input_dim):
        Vrr = kr.backend.mean(
            centered_r ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vri = kr.backend.mean(
            centered_r * centered_i,
            axis=[0, 1, 2]
        )

        Vrj = kr.backend.mean(
            centered_r * centered_j,
            axis=[0, 1, 2]
        )

        Vrk = kr.backend.mean(
            centered_r * centered_k,
            axis=[0, 1, 2]
        )

        Vii = kr.backend.mean(
            centered_i ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vij = kr.backend.mean(
            centered_i * centered_j,
            axis=[0, 1, 2]
        )

        Vik = kr.backend.mean(
            centered_i * centered_k,
            axis=[0, 1, 2]
        )

        Vjj = kr.backend.mean(
            centered_j ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        Vjk = kr.backend.mean(
            centered_j * centered_k,
            axis=[0, 1, 2]
        )

        Vkk = kr.backend.mean(
            centered_k ** 2,
            axis=[0, 1, 2]
        ) + self.epsilon

        pars_shape = [input_dim, 1]
        Vrr = tf.reshape(Vrr, pars_shape)
        Vri = tf.reshape(Vri, pars_shape)
        Vrj = tf.reshape(Vrj, pars_shape)
        Vrk = tf.reshape(Vrk, pars_shape)
        Vii = tf.reshape(Vii, pars_shape)
        Vij = tf.reshape(Vij, pars_shape)
        Vik = tf.reshape(Vik, pars_shape)
        Vjj = tf.reshape(Vjj, pars_shape)
        Vjk = tf.reshape(Vjk, pars_shape)
        Vkk = tf.reshape(Vkk, pars_shape)

        return Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk
    
    def _moving_exponential_update(self, var, value):
        decay = 1 - self.momentum
        var.assign_sub(var * decay)
        var.assign_add(value * decay)

    def _update_moving_parameters(self, mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk):
        if self.center:
            self._moving_exponential_update(self.mov_mean, mean)

        if self.scale:
            self._moving_exponential_update(self.mov_Vrr, Vrr)
            self._moving_exponential_update(self.mov_Vri, Vri)
            self._moving_exponential_update(self.mov_Vrj, Vrj)
            self._moving_exponential_update(self.mov_Vrk, Vrk)
            self._moving_exponential_update(self.mov_Vii, Vii)
            self._moving_exponential_update(self.mov_Vij, Vij)
            self._moving_exponential_update(self.mov_Vik, Vik)
            self._moving_exponential_update(self.mov_Vjj, Vjj)
            self._moving_exponential_update(self.mov_Vjk, Vjk)
            self._moving_exponential_update(self.mov_Vkk, Vkk)

    def call(self, inputs, training=None):
        if (not self.center) or (not self.scale):
            raise ValueError("Batch Normalization should scale or center.")

        input_shape = kr.backend.int_shape(inputs)
        input_dim = input_shape[-1] // 4

        # Activation before
        if self.activation_position == "before":
            output = self.activation(inputs)
        else:
            output = inputs

        if training in {0, False}:
            mean = self.mov_mean
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr = self.mov_Vrr
                Vri = self.mov_Vri
                Vrj = self.mov_Vrj
                Vrk = self.mov_Vrk
                Vii = self.mov_Vii
                Vij = self.mov_Vij
                Vik = self.mov_Vik
                Vjj = self.mov_Vjj
                Vjk = self.mov_Vjk
                Vkk = self.mov_Vkk
        else:
            # mean and centering
            mean = kr.backend.mean(output, axis=[0, 1, 2])
            mean = kr.backend.reshape(mean, [1, 1, 1, input_dim * 4])
            centered = output - mean

            if self.scale:
                centered_r = centered[:, :, :, :input_dim]
                centered_i = centered[:, :, :, input_dim:input_dim * 2]
                centered_j = centered[:, :, :, input_dim * 2:input_dim * 3]
                centered_k = centered[:, :, :, input_dim * 3:]

                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = self._compute_variances(centered_r, centered_i, centered_j, centered_k, input_dim)
            else:
                Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk = [None for i in range(10)]  

            self._update_moving_parameters(mean, Vrr, Vri, Vrj, Vrk, Vii, Vij, Vik, Vjj, Vjk, Vkk)

        if self.scale:
            var_reshape = [input_dim, 1, 4]
            # covariance matrix
            V = tf.concat([[tf.reshape(tf.concat([Vrr, Vri, Vrj, Vrk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vri, Vii, Vij, Vik], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrj, Vij, Vjj, Vjk], axis=1), var_reshape)],
                           [tf.reshape(tf.concat([Vrk, Vik, Vjk, Vkk], axis=1), var_reshape)]], axis=2)

            # Whitening
            R = tf.reshape(tf.linalg.cholesky(V), [input_dim, 4, 4])
            W = tf.linalg.inv(tf.transpose(R, perm=[0,2,1]))

            Wrr = W[:,0,0]
            Wri = W[:,0,1]
            Wrj = W[:,0,2]
            Wrk = W[:,0,3]
            Wii = W[:,1,1]
            Wij = W[:,1,2]
            Wik = W[:,1,3]
            Wjj = W[:,2,2]
            Wjk = W[:,2,3]
            Wkk = W[:,3,3]

            output_r = centered_r * Wrr
            output_i = centered_r * Wri + centered_i * Wii
            output_j = centered_r * Wrj + centered_i * Wij + centered_j * Wjj
            output_k = centered_r * Wrk + centered_i * Wik + centered_j * Wjk + centered_k * Wkk

            if self.activation_position == "middle":
                output_r = self.activation(output_r)
                output_i = self.activation(output_i)
                output_j = self.activation(output_j)
                output_k = self.activation(output_k)

            out_r = output_r * self.gam_rr
            out_i = output_r * self.gam_ri + output_i * self.gam_ii
            out_j = output_r * self.gam_rj + output_i * self.gam_ij + output_j * self.gam_jj
            out_k = output_r * self.gam_rk + output_i * self.gam_ik + output_j * self.gam_jk + output_k * self.gam_kk
            output = tf.concat([out_r, out_i, out_j, out_k], axis=-1)
        else:
            output = centered
            if self.activation_position == "middle":
                output = self.activation(output)

        if self.center:
            output = output + self.beta

        if self.activation_position == "after":
            output = self.activation(output)

        return output

# %%
class TessResidualUnit(layers.Layer):
    """ 
    Tessarine valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recog-nition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual net-works.
    """
    def __init__(self, filters, strides=1, activation="elu", activation_position='after', **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvTess(filters, strides=strides),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position),
            DefaultConvTess(filters),
            Hypercomplex4DBNActivation(activation=activation, activation_position=activation_position)]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvTess(filters, kernel_size=(1,1), strides=strides),
                Hypercomplex4DBNActivation(activation=None, activation_position='no_activation')]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

tess_resnet = kr.models.Sequential()
tess_resnet.add(DefaultConvTess(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    tess_resnet.add(TessResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
tess_resnet.add(kr.layers.GlobalAvgPool2D())
tess_resnet.add(kr.layers.Flatten())
tess_resnet.add(kr.layers.Dense(10, activation="softmax"))
tess_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

tess_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 165s 293ms/step - loss: 2.3587 - accuracy: 0.2996 - val_loss: 2.6785 - val_accuracy: 0.1679
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 2.0930 - accuracy: 0.3966 - val_loss: 3.0618 - val_accuracy: 0.1396
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 282ms/step - loss: 1.9762 - accuracy: 0.4381 - val_loss: 2.6105 - val_accuracy: 0.2410
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 280ms/step - loss: 1.8965 - accuracy: 0.4679 - val_loss: 2.4555 - val_accuracy: 0.2998
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 280ms/step - loss: 1.8396 - accuracy: 0.4834 - val_loss: 2.6987 - val_accuracy: 0.2643
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 1.7870 - accuracy: 0.4999 - val_loss: 2.9367 - val_accuracy: 0.2561
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 1.7414 - accuracy: 0.5160 - val_loss: 2.9384 - val_accuracy: 0.2662
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 277ms/step - loss: 1.7019 - accuracy: 0.5316 - val_loss: 2.8342 - val_accuracy: 0.2713
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 280ms/step - loss: 1.6610 - accuracy: 0.5442 - val_loss: 2.2271 - val_accuracy: 0.3454
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 110s 281ms/step - loss: 1.6299 - accuracy: 0.5553 - val_loss: 2.4342 - val_accuracy: 0.2987
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 1.7621 - accuracy: 0.4995 - val_loss: 2.5244 - val_accuracy: 0.2889
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 1.5355 - accuracy: 0.5667 - val_loss: 2.3030 - val_accuracy: 0.3816
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 1.4161 - accuracy: 0.5974 - val_loss: 1.8967 - val_accuracy: 0.4508
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 1.3286 - accuracy: 0.6229 - val_loss: 1.9101 - val_accuracy: 0.4611
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 1.2531 - accuracy: 0.6389 - val_loss: 2.3636 - val_accuracy: 0.4344
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 1.1952 - accuracy: 0.6558 - val_loss: 1.9751 - val_accuracy: 0.4300
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 1.1433 - accuracy: 0.6691 - val_loss: 1.7225 - val_accuracy: 0.4999
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 1.1002 - accuracy: 0.6807 - val_loss: 1.4693 - val_accuracy: 0.5896
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 1.0518 - accuracy: 0.6941 - val_loss: 1.5278 - val_accuracy: 0.5803
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 1.0111 - accuracy: 0.7073 - val_loss: 2.0131 - val_accuracy: 0.4706
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.9772 - accuracy: 0.7170 - val_loss: 1.1727 - val_accuracy: 0.6465
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.9453 - accuracy: 0.7267 - val_loss: 1.1066 - val_accuracy: 0.6743
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.9112 - accuracy: 0.7365 - val_loss: 1.0920 - val_accuracy: 0.6799
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.8908 - accuracy: 0.7437 - val_loss: 1.3167 - val_accuracy: 0.6237
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.8702 - accuracy: 0.7515 - val_loss: 1.3258 - val_accuracy: 0.6071
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.8445 - accuracy: 0.7586 - val_loss: 1.1157 - val_accuracy: 0.6700
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.8267 - accuracy: 0.7645 - val_loss: 1.1742 - val_accuracy: 0.6471
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.8143 - accuracy: 0.7701 - val_loss: 1.6594 - val_accuracy: 0.5367
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.7958 - accuracy: 0.7749 - val_loss: 1.0339 - val_accuracy: 0.7008
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.7799 - accuracy: 0.7822 - val_loss: 2.7488 - val_accuracy: 0.4755
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.7737 - accuracy: 0.7820 - val_loss: 0.9537 - val_accuracy: 0.7247
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.7670 - accuracy: 0.7864 - val_loss: 1.0397 - val_accuracy: 0.7014
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.7542 - accuracy: 0.7886 - val_loss: 0.9876 - val_accuracy: 0.7170
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.7397 - accuracy: 0.7961 - val_loss: 1.0442 - val_accuracy: 0.6945
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.7330 - accuracy: 0.7982 - val_loss: 0.8680 - val_accuracy: 0.7522
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.7244 - accuracy: 0.8020 - val_loss: 1.3692 - val_accuracy: 0.6069
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.7169 - accuracy: 0.8039 - val_loss: 1.3403 - val_accuracy: 0.6392
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.7073 - accuracy: 0.8065 - val_loss: 1.0090 - val_accuracy: 0.7121
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.7026 - accuracy: 0.8096 - val_loss: 0.9129 - val_accuracy: 0.7441
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.6952 - accuracy: 0.8116 - val_loss: 0.8891 - val_accuracy: 0.7527
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6844 - accuracy: 0.8145 - val_loss: 1.5055 - val_accuracy: 0.5627
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6794 - accuracy: 0.8171 - val_loss: 1.1056 - val_accuracy: 0.6916
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6768 - accuracy: 0.8176 - val_loss: 1.0513 - val_accuracy: 0.6961
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 280ms/step - loss: 0.6685 - accuracy: 0.8199 - val_loss: 0.8297 - val_accuracy: 0.7722
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6689 - accuracy: 0.8214 - val_loss: 0.8903 - val_accuracy: 0.7441
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6632 - accuracy: 0.8236 - val_loss: 1.1664 - val_accuracy: 0.6651
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6616 - accuracy: 0.8227 - val_loss: 1.0205 - val_accuracy: 0.7170
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6567 - accuracy: 0.8263 - val_loss: 0.8643 - val_accuracy: 0.7580
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6483 - accuracy: 0.8281 - val_loss: 1.0285 - val_accuracy: 0.7097
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6489 - accuracy: 0.8279 - val_loss: 1.0298 - val_accuracy: 0.7020
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6421 - accuracy: 0.8300 - val_loss: 1.0893 - val_accuracy: 0.6821
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6412 - accuracy: 0.8308 - val_loss: 0.8800 - val_accuracy: 0.7606
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6386 - accuracy: 0.8332 - val_loss: 0.8248 - val_accuracy: 0.7739
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6307 - accuracy: 0.8336 - val_loss: 1.0189 - val_accuracy: 0.7187
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6325 - accuracy: 0.8351 - val_loss: 0.9529 - val_accuracy: 0.7406
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6272 - accuracy: 0.8372 - val_loss: 0.8197 - val_accuracy: 0.7778
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6253 - accuracy: 0.8388 - val_loss: 0.8912 - val_accuracy: 0.7590
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.6246 - accuracy: 0.8385 - val_loss: 0.8402 - val_accuracy: 0.7726
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6197 - accuracy: 0.8391 - val_loss: 0.8855 - val_accuracy: 0.7561
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6174 - accuracy: 0.8398 - val_loss: 0.9235 - val_accuracy: 0.7403
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6147 - accuracy: 0.8409 - val_loss: 0.8771 - val_accuracy: 0.7642
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.6117 - accuracy: 0.8427 - val_loss: 0.7371 - val_accuracy: 0.8016
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6059 - accuracy: 0.8465 - val_loss: 0.8634 - val_accuracy: 0.7613
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.6072 - accuracy: 0.8454 - val_loss: 0.8371 - val_accuracy: 0.7719
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6023 - accuracy: 0.8469 - val_loss: 0.9551 - val_accuracy: 0.7334
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.6036 - accuracy: 0.8466 - val_loss: 1.2412 - val_accuracy: 0.6740
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5976 - accuracy: 0.8485 - val_loss: 0.8342 - val_accuracy: 0.7769
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5992 - accuracy: 0.8464 - val_loss: 0.8989 - val_accuracy: 0.7442
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.6015 - accuracy: 0.8473 - val_loss: 1.1084 - val_accuracy: 0.6850
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5908 - accuracy: 0.8504 - val_loss: 0.9818 - val_accuracy: 0.7398
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5959 - accuracy: 0.8488 - val_loss: 0.7523 - val_accuracy: 0.8008
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5888 - accuracy: 0.8501 - val_loss: 0.9605 - val_accuracy: 0.7365
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5882 - accuracy: 0.8514 - val_loss: 0.7701 - val_accuracy: 0.7947
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5864 - accuracy: 0.8506 - val_loss: 0.9439 - val_accuracy: 0.7428
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5887 - accuracy: 0.8519 - val_loss: 0.8401 - val_accuracy: 0.7652
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5823 - accuracy: 0.8520 - val_loss: 0.9655 - val_accuracy: 0.7374
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5772 - accuracy: 0.8552 - val_loss: 0.7598 - val_accuracy: 0.8038
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5830 - accuracy: 0.8535 - val_loss: 1.0423 - val_accuracy: 0.7130
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5811 - accuracy: 0.8534 - val_loss: 0.8484 - val_accuracy: 0.7737
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5752 - accuracy: 0.8560 - val_loss: 0.7800 - val_accuracy: 0.7960
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5770 - accuracy: 0.8553 - val_loss: 0.9991 - val_accuracy: 0.7433
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5724 - accuracy: 0.8582 - val_loss: 0.8598 - val_accuracy: 0.7708
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5728 - accuracy: 0.8567 - val_loss: 0.9132 - val_accuracy: 0.7560
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5702 - accuracy: 0.8574 - val_loss: 0.8594 - val_accuracy: 0.7701
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5711 - accuracy: 0.8582 - val_loss: 0.8023 - val_accuracy: 0.7864
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5695 - accuracy: 0.8570 - val_loss: 1.2250 - val_accuracy: 0.6675
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5676 - accuracy: 0.8607 - val_loss: 0.8220 - val_accuracy: 0.7851
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5673 - accuracy: 0.8610 - val_loss: 0.9010 - val_accuracy: 0.7556
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5638 - accuracy: 0.8606 - val_loss: 0.7684 - val_accuracy: 0.7952
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5658 - accuracy: 0.8596 - val_loss: 0.8481 - val_accuracy: 0.7704
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5597 - accuracy: 0.8610 - val_loss: 0.7599 - val_accuracy: 0.7990
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 282ms/step - loss: 0.5637 - accuracy: 0.8617 - val_loss: 1.2334 - val_accuracy: 0.6675
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5580 - accuracy: 0.8621 - val_loss: 0.7331 - val_accuracy: 0.8025
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5630 - accuracy: 0.8600 - val_loss: 1.0650 - val_accuracy: 0.7052
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 284ms/step - loss: 0.5553 - accuracy: 0.8630 - val_loss: 0.7965 - val_accuracy: 0.7914
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 113s 288ms/step - loss: 0.5568 - accuracy: 0.8652 - val_loss: 0.8244 - val_accuracy: 0.7885
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5603 - accuracy: 0.8631 - val_loss: 0.9433 - val_accuracy: 0.7470
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 285ms/step - loss: 0.5583 - accuracy: 0.8632 - val_loss: 0.8789 - val_accuracy: 0.7673
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 286ms/step - loss: 0.5507 - accuracy: 0.8664 - val_loss: 0.8496 - val_accuracy: 0.7761
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 112s 285ms/step - loss: 0.5519 - accuracy: 0.8651 - val_loss: 0.9721 - val_accuracy: 0.7259
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5509 - accuracy: 0.8646 - val_loss: 0.8862 - val_accuracy: 0.7656
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 114s 290ms/step - loss: 0.5514 - accuracy: 0.8662 - val_loss: 0.8697 - val_accuracy: 0.7753
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 111s 283ms/step - loss: 0.5486 - accuracy: 0.8665 - val_loss: 0.8013 - val_accuracy: 0.7865
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 281ms/step - loss: 0.5507 - accuracy: 0.8673 - val_loss: 0.9962 - val_accuracy: 0.7222
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5508 - accuracy: 0.8651 - val_loss: 0.8091 - val_accuracy: 0.7894
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5487 - accuracy: 0.8668 - val_loss: 0.8787 - val_accuracy: 0.7689
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5452 - accuracy: 0.8671 - val_loss: 0.9046 - val_accuracy: 0.7519
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5488 - accuracy: 0.8670 - val_loss: 0.8638 - val_accuracy: 0.7711
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5464 - accuracy: 0.8658 - val_loss: 0.7675 - val_accuracy: 0.7973
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5456 - accuracy: 0.8681 - val_loss: 1.0910 - val_accuracy: 0.6970
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5419 - accuracy: 0.8684 - val_loss: 1.1117 - val_accuracy: 0.6886
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5454 - accuracy: 0.8663 - val_loss: 0.8492 - val_accuracy: 0.7759
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 110s 280ms/step - loss: 0.5423 - accuracy: 0.8693 - val_loss: 0.7063 - val_accuracy: 0.8203
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5373 - accuracy: 0.8716 - val_loss: 0.7634 - val_accuracy: 0.8066
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 279ms/step - loss: 0.5381 - accuracy: 0.8700 - val_loss: 0.8012 - val_accuracy: 0.7910
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5406 - accuracy: 0.8682 - val_loss: 1.0868 - val_accuracy: 0.6951
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5400 - accuracy: 0.8710 - val_loss: 0.9236 - val_accuracy: 0.7582
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5316 - accuracy: 0.8722 - val_loss: 1.2237 - val_accuracy: 0.6817
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5366 - accuracy: 0.8699 - val_loss: 1.0060 - val_accuracy: 0.7356
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5379 - accuracy: 0.8685 - val_loss: 0.7503 - val_accuracy: 0.8024
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5340 - accuracy: 0.8729 - val_loss: 1.2912 - val_accuracy: 0.6561
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5353 - accuracy: 0.8716 - val_loss: 0.9146 - val_accuracy: 0.7689
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5314 - accuracy: 0.8718 - val_loss: 0.8191 - val_accuracy: 0.7860
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5354 - accuracy: 0.8725 - val_loss: 0.8226 - val_accuracy: 0.7870
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5310 - accuracy: 0.8736 - val_loss: 0.8648 - val_accuracy: 0.7673
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5347 - accuracy: 0.8723 - val_loss: 0.8073 - val_accuracy: 0.7801
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 273ms/step - loss: 0.5317 - accuracy: 0.8734 - val_loss: 0.7222 - val_accuracy: 0.8173
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5330 - accuracy: 0.8720 - val_loss: 1.1530 - val_accuracy: 0.7156
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5252 - accuracy: 0.8769 - val_loss: 0.8475 - val_accuracy: 0.7729
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5320 - accuracy: 0.8729 - val_loss: 0.7443 - val_accuracy: 0.8096
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5295 - accuracy: 0.8735 - val_loss: 0.9357 - val_accuracy: 0.7599
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5270 - accuracy: 0.8755 - val_loss: 0.9635 - val_accuracy: 0.7417
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 273ms/step - loss: 0.5286 - accuracy: 0.8738 - val_loss: 0.7553 - val_accuracy: 0.8075
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5323 - accuracy: 0.8736 - val_loss: 0.9013 - val_accuracy: 0.7718
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5263 - accuracy: 0.8769 - val_loss: 0.8344 - val_accuracy: 0.7842
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5229 - accuracy: 0.8776 - val_loss: 0.8444 - val_accuracy: 0.7759
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5207 - accuracy: 0.8778 - val_loss: 0.7705 - val_accuracy: 0.7968
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5215 - accuracy: 0.8766 - val_loss: 0.7985 - val_accuracy: 0.8016
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5244 - accuracy: 0.8771 - val_loss: 1.0103 - val_accuracy: 0.7250
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5231 - accuracy: 0.8763 - val_loss: 0.8011 - val_accuracy: 0.8000
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 277ms/step - loss: 0.5207 - accuracy: 0.8774 - val_loss: 1.0035 - val_accuracy: 0.7431
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5242 - accuracy: 0.8768 - val_loss: 0.7995 - val_accuracy: 0.7934
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 275ms/step - loss: 0.5203 - accuracy: 0.8774 - val_loss: 0.8658 - val_accuracy: 0.7708
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5231 - accuracy: 0.8772 - val_loss: 0.9342 - val_accuracy: 0.7523
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5228 - accuracy: 0.8760 - val_loss: 0.8339 - val_accuracy: 0.7881
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5205 - accuracy: 0.8775 - val_loss: 0.8826 - val_accuracy: 0.7715
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 108s 276ms/step - loss: 0.5204 - accuracy: 0.8782 - val_loss: 0.8590 - val_accuracy: 0.7815
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 273ms/step - loss: 0.5146 - accuracy: 0.8806 - val_loss: 0.9075 - val_accuracy: 0.7624
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 274ms/step - loss: 0.5168 - accuracy: 0.8783 - val_loss: 0.8571 - val_accuracy: 0.7902
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 107s 273ms/step - loss: 0.5225 - accuracy: 0.8764 - val_loss: 0.7632 - val_accuracy: 0.8117
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 109s 278ms/step - loss: 0.5192 - accuracy: 0.8771 - val_loss: 0.8194 - val_accuracy: 0.7875
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.4239 - accuracy: 0.9108 - val_loss: 0.6323 - val_accuracy: 0.8450
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 273ms/step - loss: 0.3930 - accuracy: 0.9221 - val_loss: 0.6071 - val_accuracy: 0.8519
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.3825 - accuracy: 0.9248 - val_loss: 0.6179 - val_accuracy: 0.8483
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.3718 - accuracy: 0.9276 - val_loss: 0.5918 - val_accuracy: 0.8568
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3644 - accuracy: 0.9291 - val_loss: 0.6101 - val_accuracy: 0.8520
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.3590 - accuracy: 0.9302 - val_loss: 0.6126 - val_accuracy: 0.8538
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3546 - accuracy: 0.9315 - val_loss: 0.6130 - val_accuracy: 0.8511
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3482 - accuracy: 0.9316 - val_loss: 0.6033 - val_accuracy: 0.8527
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3447 - accuracy: 0.9328 - val_loss: 0.6125 - val_accuracy: 0.8510
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.3403 - accuracy: 0.9337 - val_loss: 0.6033 - val_accuracy: 0.8525
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 277ms/step - loss: 0.3368 - accuracy: 0.9338 - val_loss: 0.5789 - val_accuracy: 0.8578
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3347 - accuracy: 0.9334 - val_loss: 0.6130 - val_accuracy: 0.8484
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3282 - accuracy: 0.9344 - val_loss: 0.5809 - val_accuracy: 0.8570
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3256 - accuracy: 0.9357 - val_loss: 0.6351 - val_accuracy: 0.8393
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3211 - accuracy: 0.9364 - val_loss: 0.5891 - val_accuracy: 0.8551
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.3185 - accuracy: 0.9377 - val_loss: 0.6050 - val_accuracy: 0.8499
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.3144 - accuracy: 0.9380 - val_loss: 0.5939 - val_accuracy: 0.8542
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.3137 - accuracy: 0.9368 - val_loss: 0.6041 - val_accuracy: 0.8512
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 111s 283ms/step - loss: 0.3125 - accuracy: 0.9362 - val_loss: 0.6219 - val_accuracy: 0.8460
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 277ms/step - loss: 0.3032 - accuracy: 0.9398 - val_loss: 0.6562 - val_accuracy: 0.8373
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.3050 - accuracy: 0.9373 - val_loss: 0.6013 - val_accuracy: 0.8480
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 277ms/step - loss: 0.3004 - accuracy: 0.9408 - val_loss: 0.6064 - val_accuracy: 0.8459
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2992 - accuracy: 0.9388 - val_loss: 0.6045 - val_accuracy: 0.8476
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2992 - accuracy: 0.9378 - val_loss: 0.6099 - val_accuracy: 0.8497
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2931 - accuracy: 0.9404 - val_loss: 0.5987 - val_accuracy: 0.8490
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2895 - accuracy: 0.9412 - val_loss: 0.5956 - val_accuracy: 0.8508
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2909 - accuracy: 0.9408 - val_loss: 0.6418 - val_accuracy: 0.8392
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2883 - accuracy: 0.9397 - val_loss: 0.6154 - val_accuracy: 0.8455
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2855 - accuracy: 0.9408 - val_loss: 0.6137 - val_accuracy: 0.8421
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2801 - accuracy: 0.9427 - val_loss: 0.6066 - val_accuracy: 0.8454
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2818 - accuracy: 0.9418 - val_loss: 0.5895 - val_accuracy: 0.8485
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2751 - accuracy: 0.9430 - val_loss: 0.5854 - val_accuracy: 0.8537
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2783 - accuracy: 0.9416 - val_loss: 0.6543 - val_accuracy: 0.8350
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2757 - accuracy: 0.9413 - val_loss: 0.5554 - val_accuracy: 0.8597
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2755 - accuracy: 0.9412 - val_loss: 0.5875 - val_accuracy: 0.8499
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 275ms/step - loss: 0.2714 - accuracy: 0.9427 - val_loss: 0.6300 - val_accuracy: 0.8392
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2712 - accuracy: 0.9418 - val_loss: 0.5357 - val_accuracy: 0.8661
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2694 - accuracy: 0.9423 - val_loss: 0.5881 - val_accuracy: 0.8482
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2697 - accuracy: 0.9422 - val_loss: 0.6241 - val_accuracy: 0.8411
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2667 - accuracy: 0.9429 - val_loss: 0.6207 - val_accuracy: 0.8397
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2628 - accuracy: 0.9429 - val_loss: 0.6976 - val_accuracy: 0.8253
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2626 - accuracy: 0.9433 - val_loss: 0.6507 - val_accuracy: 0.8296
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2620 - accuracy: 0.9432 - val_loss: 0.6366 - val_accuracy: 0.8358
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2608 - accuracy: 0.9433 - val_loss: 0.6630 - val_accuracy: 0.8300
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2595 - accuracy: 0.9432 - val_loss: 0.6387 - val_accuracy: 0.8363
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2579 - accuracy: 0.9430 - val_loss: 0.6191 - val_accuracy: 0.8393
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2581 - accuracy: 0.9440 - val_loss: 0.5868 - val_accuracy: 0.8449
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2584 - accuracy: 0.9429 - val_loss: 0.6014 - val_accuracy: 0.8408
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2557 - accuracy: 0.9428 - val_loss: 0.5694 - val_accuracy: 0.8496
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2376 - accuracy: 0.9510 - val_loss: 0.5634 - val_accuracy: 0.8537
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2316 - accuracy: 0.9528 - val_loss: 0.5667 - val_accuracy: 0.8517
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 106s 271ms/step - loss: 0.2267 - accuracy: 0.9550 - val_loss: 0.5647 - val_accuracy: 0.8548
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2248 - accuracy: 0.9559 - val_loss: 0.5638 - val_accuracy: 0.8537
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 106s 272ms/step - loss: 0.2189 - accuracy: 0.9583 - val_loss: 0.5666 - val_accuracy: 0.8505
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 106s 271ms/step - loss: 0.2224 - accuracy: 0.9550 - val_loss: 0.5624 - val_accuracy: 0.8551
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2194 - accuracy: 0.9572 - val_loss: 0.5583 - val_accuracy: 0.8532
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 106s 271ms/step - loss: 0.2189 - accuracy: 0.9570 - val_loss: 0.5653 - val_accuracy: 0.8520
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2182 - accuracy: 0.9579 - val_loss: 0.5553 - val_accuracy: 0.8555
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2187 - accuracy: 0.9575 - val_loss: 0.5543 - val_accuracy: 0.8575
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 106s 272ms/step - loss: 0.2178 - accuracy: 0.9572 - val_loss: 0.5714 - val_accuracy: 0.8542
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 272ms/step - loss: 0.2163 - accuracy: 0.9576 - val_loss: 0.5845 - val_accuracy: 0.8511
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2168 - accuracy: 0.9582 - val_loss: 0.5743 - val_accuracy: 0.8547
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2151 - accuracy: 0.9577 - val_loss: 0.5634 - val_accuracy: 0.8544
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2166 - accuracy: 0.9575 - val_loss: 0.5707 - val_accuracy: 0.8537
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2156 - accuracy: 0.9579 - val_loss: 0.5722 - val_accuracy: 0.8532
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 272ms/step - loss: 0.2137 - accuracy: 0.9586 - val_loss: 0.5795 - val_accuracy: 0.8516
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 273ms/step - loss: 0.2142 - accuracy: 0.9574 - val_loss: 0.5640 - val_accuracy: 0.8556
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2124 - accuracy: 0.9593 - val_loss: 0.5645 - val_accuracy: 0.8538
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2136 - accuracy: 0.9590 - val_loss: 0.5726 - val_accuracy: 0.8522
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2146 - accuracy: 0.9576 - val_loss: 0.5720 - val_accuracy: 0.8538
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2138 - accuracy: 0.9580 - val_loss: 0.5703 - val_accuracy: 0.8541
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2112 - accuracy: 0.9591 - val_loss: 0.5679 - val_accuracy: 0.8543
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2123 - accuracy: 0.9597 - val_loss: 0.5585 - val_accuracy: 0.8570
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 275ms/step - loss: 0.2107 - accuracy: 0.9602 - val_loss: 0.5648 - val_accuracy: 0.8554
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2103 - accuracy: 0.9586 - val_loss: 0.5626 - val_accuracy: 0.8553
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2095 - accuracy: 0.9603 - val_loss: 0.5789 - val_accuracy: 0.8513
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 280ms/step - loss: 0.2095 - accuracy: 0.9592 - val_loss: 0.5651 - val_accuracy: 0.8539
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2089 - accuracy: 0.9607 - val_loss: 0.5556 - val_accuracy: 0.8570
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2092 - accuracy: 0.9596 - val_loss: 0.5637 - val_accuracy: 0.8553
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2070 - accuracy: 0.9607 - val_loss: 0.5609 - val_accuracy: 0.8565
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2070 - accuracy: 0.9601 - val_loss: 0.5645 - val_accuracy: 0.8539
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2101 - accuracy: 0.9592 - val_loss: 0.5631 - val_accuracy: 0.8550
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2051 - accuracy: 0.9610 - val_loss: 0.5667 - val_accuracy: 0.8559
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 107s 274ms/step - loss: 0.2079 - accuracy: 0.9597 - val_loss: 0.5604 - val_accuracy: 0.8555
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2073 - accuracy: 0.9597 - val_loss: 0.5723 - val_accuracy: 0.8539
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2061 - accuracy: 0.9605 - val_loss: 0.5833 - val_accuracy: 0.8504
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2055 - accuracy: 0.9610 - val_loss: 0.5683 - val_accuracy: 0.8536
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 276ms/step - loss: 0.2060 - accuracy: 0.9603 - val_loss: 0.5671 - val_accuracy: 0.8544
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2075 - accuracy: 0.9586 - val_loss: 0.5709 - val_accuracy: 0.8525
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 108s 277ms/step - loss: 0.2068 - accuracy: 0.9590 - val_loss: 0.5853 - val_accuracy: 0.8520
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2084 - accuracy: 0.9585 - val_loss: 0.5627 - val_accuracy: 0.8551
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2055 - accuracy: 0.9605 - val_loss: 0.5765 - val_accuracy: 0.8527
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 278ms/step - loss: 0.2057 - accuracy: 0.9598 - val_loss: 0.5701 - val_accuracy: 0.8547
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 110s 280ms/step - loss: 0.2053 - accuracy: 0.9602 - val_loss: 0.5765 - val_accuracy: 0.8534
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 109s 279ms/step - loss: 0.2049 - accuracy: 0.9604 - val_loss: 0.5691 - val_accuracy: 0.8541
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 110s 281ms/step - loss: 0.2056 - accuracy: 0.9595 - val_loss: 0.5900 - val_accuracy: 0.8487
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 285ms/step - loss: 0.2045 - accuracy: 0.9609 - val_loss: 0.5813 - val_accuracy: 0.8518
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 285ms/step - loss: 0.2034 - accuracy: 0.9595 - val_loss: 0.5810 - val_accuracy: 0.8521
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 111s 284ms/step - loss: 0.2030 - accuracy: 0.9605 - val_loss: 0.5890 - val_accuracy: 0.8494

# %%
tess_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tess_conv2d (TessConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# tess_residual_unit (TessResi (None, None, None, 24)    2928
# _________________________________________________________________
# tess_residual_unit_1 (TessRe (None, None, None, 24)    2928
# _________________________________________________________________
# tess_residual_unit_2 (TessRe (None, None, None, 24)    2928
# _________________________________________________________________
# tess_residual_unit_3 (TessRe (None, None, None, 48)    9072
# _________________________________________________________________
# tess_residual_unit_4 (TessRe (None, None, None, 48)    11040
# _________________________________________________________________
# tess_residual_unit_5 (TessRe (None, None, None, 96)    34272
# _________________________________________________________________
# tess_residual_unit_6 (TessRe (None, None, None, 96)    42816
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 107,170
# Trainable params: 104,146
# Non-trainable params: 3,024
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(tess_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96352

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(tess_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8494
