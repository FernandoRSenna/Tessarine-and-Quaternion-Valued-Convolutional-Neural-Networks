# %% [markdown]
# # Tessarine valued CNN with Real Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class TessConv2D(layers.Layer):
    """
    Tessarine valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """

    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer,
                 data_format=None,
                 kernel_regularizer=1e-3):
        super(TessConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        if kernel_regularizer is not None:
            self.kernel_regularizer = kr.regularizers.l2(kernel_regularizer)
        else:
            self.kernel_regularizer = kernel_regularizer

    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('TessConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        F_r = tf.concat([ self.f0,-self.f1, self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3, self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0,-self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2, self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvTess = partial(TessConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class TessResidualUnit(layers.Layer):
    """ 
    Tessarine valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recog-nition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual net-works.
    """
    def __init__(self, filters, strides=1, activation="elu", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvTess(filters, strides=strides),
            kr.layers.BatchNormalization(),
            self.activation,
            DefaultConvTess(filters),
            kr.layers.BatchNormalization(),
            self.activation]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvTess(filters, kernel_size=(1,1), strides=strides),
                kr.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

tess_resnet = kr.models.Sequential()
tess_resnet.add(DefaultConvTess(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    tess_resnet.add(TessResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
tess_resnet.add(kr.layers.GlobalAvgPool2D())
tess_resnet.add(kr.layers.Flatten())
tess_resnet.add(kr.layers.Dense(10, activation="softmax"))
tess_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

tess_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 100ms/step - loss: 2.2629 - accuracy: 0.3371 - val_loss: 2.8337 - val_accuracy: 0.1746
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 2.0215 - accuracy: 0.4225 - val_loss: 2.5145 - val_accuracy: 0.2311
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 1.9119 - accuracy: 0.4619 - val_loss: 2.6633 - val_accuracy: 0.2300
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 1.8260 - accuracy: 0.4937 - val_loss: 2.7877 - val_accuracy: 0.2141
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 1.7628 - accuracy: 0.5151 - val_loss: 2.5296 - val_accuracy: 0.2430
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 1.7127 - accuracy: 0.5335 - val_loss: 2.3063 - val_accuracy: 0.2969
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 1.6657 - accuracy: 0.5506 - val_loss: 2.9695 - val_accuracy: 0.1886
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 1.6212 - accuracy: 0.5616 - val_loss: 2.5774 - val_accuracy: 0.2313
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 98ms/step - loss: 1.5849 - accuracy: 0.5740 - val_loss: 2.0368 - val_accuracy: 0.4015
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 1.5537 - accuracy: 0.5838 - val_loss: 2.2477 - val_accuracy: 0.3261
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 1.8694 - accuracy: 0.4615 - val_loss: 1.9334 - val_accuracy: 0.4257
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 1.5280 - accuracy: 0.5714 - val_loss: 1.6744 - val_accuracy: 0.5125
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.3804 - accuracy: 0.6141 - val_loss: 1.8472 - val_accuracy: 0.4607
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 1.2776 - accuracy: 0.6437 - val_loss: 1.5063 - val_accuracy: 0.5625
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 1.1941 - accuracy: 0.6688 - val_loss: 1.5037 - val_accuracy: 0.5459
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 1.1294 - accuracy: 0.6860 - val_loss: 1.6965 - val_accuracy: 0.4973
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 1.0732 - accuracy: 0.7005 - val_loss: 1.3328 - val_accuracy: 0.6146
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 1.0305 - accuracy: 0.7114 - val_loss: 1.2978 - val_accuracy: 0.6317
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.9883 - accuracy: 0.7231 - val_loss: 1.4541 - val_accuracy: 0.5920
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.9525 - accuracy: 0.7315 - val_loss: 1.2143 - val_accuracy: 0.6441
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.9285 - accuracy: 0.7408 - val_loss: 1.3833 - val_accuracy: 0.6120
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.9001 - accuracy: 0.7464 - val_loss: 1.4920 - val_accuracy: 0.6039
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.8728 - accuracy: 0.7548 - val_loss: 1.3577 - val_accuracy: 0.6108
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.8567 - accuracy: 0.7596 - val_loss: 1.2196 - val_accuracy: 0.6535
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.8412 - accuracy: 0.7662 - val_loss: 1.2337 - val_accuracy: 0.6555
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.8269 - accuracy: 0.7712 - val_loss: 1.0694 - val_accuracy: 0.6901
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 96ms/step - loss: 0.8118 - accuracy: 0.7735 - val_loss: 1.2306 - val_accuracy: 0.6388
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.7958 - accuracy: 0.7797 - val_loss: 0.9628 - val_accuracy: 0.7261
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.7853 - accuracy: 0.7834 - val_loss: 1.0818 - val_accuracy: 0.6847
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.7794 - accuracy: 0.7859 - val_loss: 1.0063 - val_accuracy: 0.7093
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.7638 - accuracy: 0.7897 - val_loss: 1.0617 - val_accuracy: 0.6843
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.7551 - accuracy: 0.7927 - val_loss: 0.8759 - val_accuracy: 0.7564
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7438 - accuracy: 0.7962 - val_loss: 0.9830 - val_accuracy: 0.7183
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.7351 - accuracy: 0.8004 - val_loss: 1.0711 - val_accuracy: 0.6797
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.7272 - accuracy: 0.8020 - val_loss: 0.9541 - val_accuracy: 0.7351
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.7235 - accuracy: 0.8042 - val_loss: 0.9390 - val_accuracy: 0.7401
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.7150 - accuracy: 0.8097 - val_loss: 0.9106 - val_accuracy: 0.7419
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 96ms/step - loss: 0.7119 - accuracy: 0.8086 - val_loss: 1.6846 - val_accuracy: 0.5273
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.7071 - accuracy: 0.8107 - val_loss: 0.8675 - val_accuracy: 0.7527
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6967 - accuracy: 0.8113 - val_loss: 0.8984 - val_accuracy: 0.7448
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6925 - accuracy: 0.8168 - val_loss: 1.0400 - val_accuracy: 0.7087
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6892 - accuracy: 0.8146 - val_loss: 0.9784 - val_accuracy: 0.7277
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6893 - accuracy: 0.8169 - val_loss: 0.9551 - val_accuracy: 0.7364
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6803 - accuracy: 0.8184 - val_loss: 1.0862 - val_accuracy: 0.7130
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.6742 - accuracy: 0.8228 - val_loss: 0.8652 - val_accuracy: 0.7637
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6691 - accuracy: 0.8248 - val_loss: 1.0330 - val_accuracy: 0.7146
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6660 - accuracy: 0.8269 - val_loss: 0.8293 - val_accuracy: 0.7764
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6606 - accuracy: 0.8269 - val_loss: 0.8521 - val_accuracy: 0.7676
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6621 - accuracy: 0.8277 - val_loss: 0.9866 - val_accuracy: 0.7270
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6550 - accuracy: 0.8305 - val_loss: 0.9358 - val_accuracy: 0.7431
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6519 - accuracy: 0.8314 - val_loss: 0.9340 - val_accuracy: 0.7427
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6505 - accuracy: 0.8332 - val_loss: 1.0042 - val_accuracy: 0.7286
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6472 - accuracy: 0.8318 - val_loss: 0.8107 - val_accuracy: 0.7840
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6435 - accuracy: 0.8352 - val_loss: 1.2631 - val_accuracy: 0.6619
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6399 - accuracy: 0.8360 - val_loss: 0.9113 - val_accuracy: 0.7454
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.6373 - accuracy: 0.8362 - val_loss: 1.1471 - val_accuracy: 0.7089
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6351 - accuracy: 0.8376 - val_loss: 1.0585 - val_accuracy: 0.7111
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6334 - accuracy: 0.8371 - val_loss: 0.8852 - val_accuracy: 0.7631
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 96ms/step - loss: 0.6326 - accuracy: 0.8377 - val_loss: 1.0785 - val_accuracy: 0.7206
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6267 - accuracy: 0.8423 - val_loss: 1.1097 - val_accuracy: 0.7072
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6247 - accuracy: 0.8420 - val_loss: 0.8961 - val_accuracy: 0.7587
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.6276 - accuracy: 0.8427 - val_loss: 0.9149 - val_accuracy: 0.7498
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6180 - accuracy: 0.8429 - val_loss: 1.0057 - val_accuracy: 0.7266
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6178 - accuracy: 0.8464 - val_loss: 1.3107 - val_accuracy: 0.6761
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6165 - accuracy: 0.8440 - val_loss: 1.2240 - val_accuracy: 0.6682
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.6139 - accuracy: 0.8459 - val_loss: 1.1872 - val_accuracy: 0.6724
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6091 - accuracy: 0.8469 - val_loss: 0.7783 - val_accuracy: 0.7944
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6098 - accuracy: 0.8483 - val_loss: 1.0866 - val_accuracy: 0.7172
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.6054 - accuracy: 0.8469 - val_loss: 0.8228 - val_accuracy: 0.7788
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6061 - accuracy: 0.8495 - val_loss: 0.9567 - val_accuracy: 0.7434
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.6032 - accuracy: 0.8494 - val_loss: 0.8749 - val_accuracy: 0.7540
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 98ms/step - loss: 0.6026 - accuracy: 0.8502 - val_loss: 0.9305 - val_accuracy: 0.7547
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6023 - accuracy: 0.8500 - val_loss: 1.1338 - val_accuracy: 0.6916
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5951 - accuracy: 0.8531 - val_loss: 0.9089 - val_accuracy: 0.7572
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6014 - accuracy: 0.8501 - val_loss: 0.8835 - val_accuracy: 0.7585
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5974 - accuracy: 0.8514 - val_loss: 0.9192 - val_accuracy: 0.7511
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5899 - accuracy: 0.8546 - val_loss: 1.0643 - val_accuracy: 0.7191
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5932 - accuracy: 0.8531 - val_loss: 0.9880 - val_accuracy: 0.7271
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5962 - accuracy: 0.8528 - val_loss: 0.9222 - val_accuracy: 0.7522
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5896 - accuracy: 0.8555 - val_loss: 0.8448 - val_accuracy: 0.7689
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5923 - accuracy: 0.8527 - val_loss: 0.9846 - val_accuracy: 0.7365
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5872 - accuracy: 0.8577 - val_loss: 1.3069 - val_accuracy: 0.6626
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5856 - accuracy: 0.8570 - val_loss: 0.8856 - val_accuracy: 0.7662
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5874 - accuracy: 0.8551 - val_loss: 0.7851 - val_accuracy: 0.7897
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5874 - accuracy: 0.8565 - val_loss: 1.0302 - val_accuracy: 0.7432
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5803 - accuracy: 0.8591 - val_loss: 1.0318 - val_accuracy: 0.7208
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5812 - accuracy: 0.8574 - val_loss: 0.7845 - val_accuracy: 0.7977
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5814 - accuracy: 0.8585 - val_loss: 0.7733 - val_accuracy: 0.7924
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5792 - accuracy: 0.8607 - val_loss: 0.8407 - val_accuracy: 0.7770
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5835 - accuracy: 0.8569 - val_loss: 0.7352 - val_accuracy: 0.8119
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5737 - accuracy: 0.8608 - val_loss: 0.9464 - val_accuracy: 0.7364
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5812 - accuracy: 0.8595 - val_loss: 0.8643 - val_accuracy: 0.7787
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5754 - accuracy: 0.8599 - val_loss: 0.9758 - val_accuracy: 0.7359
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5706 - accuracy: 0.8617 - val_loss: 1.0335 - val_accuracy: 0.7316
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5698 - accuracy: 0.8606 - val_loss: 0.8425 - val_accuracy: 0.7768
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5714 - accuracy: 0.8630 - val_loss: 0.9165 - val_accuracy: 0.7600
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5683 - accuracy: 0.8632 - val_loss: 1.0020 - val_accuracy: 0.7234
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 104ms/step - loss: 0.5708 - accuracy: 0.8623 - val_loss: 0.9442 - val_accuracy: 0.7447
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5680 - accuracy: 0.8625 - val_loss: 0.9579 - val_accuracy: 0.7359
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5668 - accuracy: 0.8644 - val_loss: 0.9081 - val_accuracy: 0.7605
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5659 - accuracy: 0.8646 - val_loss: 0.8601 - val_accuracy: 0.7714
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5668 - accuracy: 0.8639 - val_loss: 0.9222 - val_accuracy: 0.7428
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5642 - accuracy: 0.8643 - val_loss: 1.1036 - val_accuracy: 0.7164
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5665 - accuracy: 0.8638 - val_loss: 0.7865 - val_accuracy: 0.7982
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5637 - accuracy: 0.8637 - val_loss: 1.2425 - val_accuracy: 0.6735
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5632 - accuracy: 0.8648 - val_loss: 0.9648 - val_accuracy: 0.7501
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5609 - accuracy: 0.8668 - val_loss: 0.9840 - val_accuracy: 0.7605
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5593 - accuracy: 0.8659 - val_loss: 0.9935 - val_accuracy: 0.7203
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5584 - accuracy: 0.8669 - val_loss: 1.0371 - val_accuracy: 0.7176
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5606 - accuracy: 0.8670 - val_loss: 1.0280 - val_accuracy: 0.7210
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5560 - accuracy: 0.8671 - val_loss: 1.1413 - val_accuracy: 0.6897
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.5595 - accuracy: 0.8659 - val_loss: 0.7957 - val_accuracy: 0.7931
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5581 - accuracy: 0.8667 - val_loss: 0.8107 - val_accuracy: 0.7817
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5538 - accuracy: 0.8681 - val_loss: 0.8548 - val_accuracy: 0.7705
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5570 - accuracy: 0.8666 - val_loss: 0.8790 - val_accuracy: 0.7716
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5546 - accuracy: 0.8676 - val_loss: 1.1283 - val_accuracy: 0.6998
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5525 - accuracy: 0.8692 - val_loss: 0.8746 - val_accuracy: 0.7680
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5543 - accuracy: 0.8685 - val_loss: 0.8313 - val_accuracy: 0.7885
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5546 - accuracy: 0.8695 - val_loss: 0.8248 - val_accuracy: 0.7834
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5556 - accuracy: 0.8680 - val_loss: 1.1115 - val_accuracy: 0.7229
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5491 - accuracy: 0.8707 - val_loss: 0.9011 - val_accuracy: 0.7642
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.5487 - accuracy: 0.8700 - val_loss: 0.8852 - val_accuracy: 0.7759
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5456 - accuracy: 0.8712 - val_loss: 0.9988 - val_accuracy: 0.7405
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5490 - accuracy: 0.8706 - val_loss: 0.8543 - val_accuracy: 0.7758
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5492 - accuracy: 0.8693 - val_loss: 0.8271 - val_accuracy: 0.7936
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5458 - accuracy: 0.8714 - val_loss: 0.7700 - val_accuracy: 0.8000
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5425 - accuracy: 0.8735 - val_loss: 1.0303 - val_accuracy: 0.7384
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5443 - accuracy: 0.8714 - val_loss: 0.9493 - val_accuracy: 0.7501
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5429 - accuracy: 0.8718 - val_loss: 1.0420 - val_accuracy: 0.7444
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5428 - accuracy: 0.8717 - val_loss: 0.8779 - val_accuracy: 0.7723
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5452 - accuracy: 0.8717 - val_loss: 0.8965 - val_accuracy: 0.7557
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5437 - accuracy: 0.8717 - val_loss: 0.8957 - val_accuracy: 0.7692
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5443 - accuracy: 0.8715 - val_loss: 0.8982 - val_accuracy: 0.7658
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5414 - accuracy: 0.8733 - val_loss: 0.8764 - val_accuracy: 0.7700
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5384 - accuracy: 0.8747 - val_loss: 1.0448 - val_accuracy: 0.7299
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5411 - accuracy: 0.8727 - val_loss: 0.8547 - val_accuracy: 0.7768
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5436 - accuracy: 0.8735 - val_loss: 0.8120 - val_accuracy: 0.7874
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5380 - accuracy: 0.8741 - val_loss: 1.2078 - val_accuracy: 0.6742
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5388 - accuracy: 0.8722 - val_loss: 0.7506 - val_accuracy: 0.8011
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5387 - accuracy: 0.8734 - val_loss: 1.0027 - val_accuracy: 0.7451
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5360 - accuracy: 0.8741 - val_loss: 0.7148 - val_accuracy: 0.8251
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5339 - accuracy: 0.8746 - val_loss: 1.0748 - val_accuracy: 0.7278
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5368 - accuracy: 0.8744 - val_loss: 0.9351 - val_accuracy: 0.7592
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5335 - accuracy: 0.8753 - val_loss: 0.8811 - val_accuracy: 0.7629
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5364 - accuracy: 0.8735 - val_loss: 0.7780 - val_accuracy: 0.8039
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5307 - accuracy: 0.8753 - val_loss: 0.8776 - val_accuracy: 0.7715
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5352 - accuracy: 0.8750 - val_loss: 0.8527 - val_accuracy: 0.7801
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5346 - accuracy: 0.8764 - val_loss: 0.8493 - val_accuracy: 0.7863
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5327 - accuracy: 0.8760 - val_loss: 0.8178 - val_accuracy: 0.7891
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5343 - accuracy: 0.8750 - val_loss: 0.9332 - val_accuracy: 0.7610
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5294 - accuracy: 0.8767 - val_loss: 0.9696 - val_accuracy: 0.7545
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.4382 - accuracy: 0.9100 - val_loss: 0.6468 - val_accuracy: 0.8399
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.4096 - accuracy: 0.9192 - val_loss: 0.6246 - val_accuracy: 0.8483
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 0.3929 - accuracy: 0.9229 - val_loss: 0.6548 - val_accuracy: 0.8412
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3830 - accuracy: 0.9265 - val_loss: 0.6531 - val_accuracy: 0.8392
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3752 - accuracy: 0.9275 - val_loss: 0.6693 - val_accuracy: 0.8363
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 106ms/step - loss: 0.3692 - accuracy: 0.9285 - val_loss: 0.6710 - val_accuracy: 0.8328
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 101ms/step - loss: 0.3655 - accuracy: 0.9291 - val_loss: 0.6338 - val_accuracy: 0.8460
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3589 - accuracy: 0.9308 - val_loss: 0.6409 - val_accuracy: 0.8429
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.3552 - accuracy: 0.9317 - val_loss: 0.6286 - val_accuracy: 0.8458
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3479 - accuracy: 0.9340 - val_loss: 0.6679 - val_accuracy: 0.8345
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3468 - accuracy: 0.9321 - val_loss: 0.6460 - val_accuracy: 0.8385
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.3427 - accuracy: 0.9331 - val_loss: 0.6543 - val_accuracy: 0.8416
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3396 - accuracy: 0.9343 - val_loss: 0.6366 - val_accuracy: 0.8438
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 0.3353 - accuracy: 0.9347 - val_loss: 0.6161 - val_accuracy: 0.8452
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3295 - accuracy: 0.9371 - val_loss: 0.6602 - val_accuracy: 0.8329
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3299 - accuracy: 0.9355 - val_loss: 0.6180 - val_accuracy: 0.8460
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.3241 - accuracy: 0.9355 - val_loss: 0.6573 - val_accuracy: 0.8381
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 101ms/step - loss: 0.3191 - accuracy: 0.9372 - val_loss: 0.6596 - val_accuracy: 0.8354
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.3194 - accuracy: 0.9369 - val_loss: 0.6256 - val_accuracy: 0.8421
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3124 - accuracy: 0.9384 - val_loss: 0.6201 - val_accuracy: 0.8429
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.3106 - accuracy: 0.9381 - val_loss: 0.6556 - val_accuracy: 0.8344
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 106ms/step - loss: 0.3099 - accuracy: 0.9370 - val_loss: 0.6414 - val_accuracy: 0.8393
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3081 - accuracy: 0.9386 - val_loss: 0.6169 - val_accuracy: 0.8441
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3058 - accuracy: 0.9378 - val_loss: 0.6764 - val_accuracy: 0.8290
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.3032 - accuracy: 0.9381 - val_loss: 0.6551 - val_accuracy: 0.8363
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2932 - accuracy: 0.9408 - val_loss: 0.6510 - val_accuracy: 0.8355
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2993 - accuracy: 0.9395 - val_loss: 0.5904 - val_accuracy: 0.8519
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2948 - accuracy: 0.9401 - val_loss: 0.6462 - val_accuracy: 0.8320
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2931 - accuracy: 0.9399 - val_loss: 0.5965 - val_accuracy: 0.8481
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2929 - accuracy: 0.9386 - val_loss: 0.6481 - val_accuracy: 0.8362
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.2883 - accuracy: 0.9412 - val_loss: 0.6430 - val_accuracy: 0.8404
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2882 - accuracy: 0.9402 - val_loss: 0.7390 - val_accuracy: 0.8190
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2825 - accuracy: 0.9416 - val_loss: 0.6709 - val_accuracy: 0.8223
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2839 - accuracy: 0.9408 - val_loss: 0.6839 - val_accuracy: 0.8264
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2832 - accuracy: 0.9397 - val_loss: 0.6474 - val_accuracy: 0.8337
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2801 - accuracy: 0.9410 - val_loss: 0.6335 - val_accuracy: 0.8365
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2795 - accuracy: 0.9405 - val_loss: 0.6420 - val_accuracy: 0.8432
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2736 - accuracy: 0.9423 - val_loss: 0.6770 - val_accuracy: 0.8296
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.2741 - accuracy: 0.9408 - val_loss: 0.6434 - val_accuracy: 0.8328
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2757 - accuracy: 0.9398 - val_loss: 0.6107 - val_accuracy: 0.8401
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2721 - accuracy: 0.9430 - val_loss: 0.5887 - val_accuracy: 0.8489
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2725 - accuracy: 0.9403 - val_loss: 0.6359 - val_accuracy: 0.8363
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2698 - accuracy: 0.9427 - val_loss: 0.6317 - val_accuracy: 0.8320
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2668 - accuracy: 0.9427 - val_loss: 0.6481 - val_accuracy: 0.8348
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2670 - accuracy: 0.9421 - val_loss: 0.6011 - val_accuracy: 0.8479
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2690 - accuracy: 0.9420 - val_loss: 0.5682 - val_accuracy: 0.8557
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 98ms/step - loss: 0.2652 - accuracy: 0.9417 - val_loss: 0.5967 - val_accuracy: 0.8395
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2623 - accuracy: 0.9424 - val_loss: 0.7228 - val_accuracy: 0.8181
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2654 - accuracy: 0.9414 - val_loss: 0.5985 - val_accuracy: 0.8470
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2429 - accuracy: 0.9491 - val_loss: 0.5919 - val_accuracy: 0.8501
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2343 - accuracy: 0.9535 - val_loss: 0.5845 - val_accuracy: 0.8527
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2322 - accuracy: 0.9539 - val_loss: 0.5961 - val_accuracy: 0.8503
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2275 - accuracy: 0.9559 - val_loss: 0.5795 - val_accuracy: 0.8556
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 101ms/step - loss: 0.2289 - accuracy: 0.9556 - val_loss: 0.5915 - val_accuracy: 0.8517
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2275 - accuracy: 0.9550 - val_loss: 0.5814 - val_accuracy: 0.8553
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2267 - accuracy: 0.9562 - val_loss: 0.5983 - val_accuracy: 0.8487
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2250 - accuracy: 0.9573 - val_loss: 0.5709 - val_accuracy: 0.8581
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2256 - accuracy: 0.9572 - val_loss: 0.5777 - val_accuracy: 0.8568
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2236 - accuracy: 0.9571 - val_loss: 0.5815 - val_accuracy: 0.8535
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2256 - accuracy: 0.9554 - val_loss: 0.5947 - val_accuracy: 0.8531
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2228 - accuracy: 0.9574 - val_loss: 0.5798 - val_accuracy: 0.8541
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2216 - accuracy: 0.9572 - val_loss: 0.5939 - val_accuracy: 0.8527
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 106ms/step - loss: 0.2216 - accuracy: 0.9579 - val_loss: 0.5909 - val_accuracy: 0.8523
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2205 - accuracy: 0.9575 - val_loss: 0.5830 - val_accuracy: 0.8546
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2214 - accuracy: 0.9573 - val_loss: 0.6015 - val_accuracy: 0.8492
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2207 - accuracy: 0.9574 - val_loss: 0.5960 - val_accuracy: 0.8519
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2196 - accuracy: 0.9573 - val_loss: 0.5967 - val_accuracy: 0.8517
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2189 - accuracy: 0.9586 - val_loss: 0.6052 - val_accuracy: 0.8496
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2170 - accuracy: 0.9582 - val_loss: 0.6024 - val_accuracy: 0.8493
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2171 - accuracy: 0.9575 - val_loss: 0.6029 - val_accuracy: 0.8517
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2195 - accuracy: 0.9577 - val_loss: 0.6031 - val_accuracy: 0.8506
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2192 - accuracy: 0.9569 - val_loss: 0.5859 - val_accuracy: 0.8558
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2146 - accuracy: 0.9585 - val_loss: 0.6001 - val_accuracy: 0.8502
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2156 - accuracy: 0.9580 - val_loss: 0.5992 - val_accuracy: 0.8503
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2176 - accuracy: 0.9580 - val_loss: 0.6014 - val_accuracy: 0.8507
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2143 - accuracy: 0.9602 - val_loss: 0.6106 - val_accuracy: 0.8485
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2156 - accuracy: 0.9589 - val_loss: 0.6062 - val_accuracy: 0.8478
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2149 - accuracy: 0.9586 - val_loss: 0.5920 - val_accuracy: 0.8520
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2138 - accuracy: 0.9581 - val_loss: 0.5979 - val_accuracy: 0.8505
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2143 - accuracy: 0.9582 - val_loss: 0.5959 - val_accuracy: 0.8505
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2136 - accuracy: 0.9593 - val_loss: 0.5968 - val_accuracy: 0.8506
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2146 - accuracy: 0.9595 - val_loss: 0.6050 - val_accuracy: 0.8484
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2150 - accuracy: 0.9579 - val_loss: 0.6052 - val_accuracy: 0.8506
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2112 - accuracy: 0.9589 - val_loss: 0.5966 - val_accuracy: 0.8519
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2117 - accuracy: 0.9598 - val_loss: 0.5940 - val_accuracy: 0.8507
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2136 - accuracy: 0.9587 - val_loss: 0.5974 - val_accuracy: 0.8527
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 106ms/step - loss: 0.2103 - accuracy: 0.9613 - val_loss: 0.6069 - val_accuracy: 0.8491
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2131 - accuracy: 0.9585 - val_loss: 0.6048 - val_accuracy: 0.8490
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 39s 101ms/step - loss: 0.2111 - accuracy: 0.9587 - val_loss: 0.6250 - val_accuracy: 0.8429
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2123 - accuracy: 0.9585 - val_loss: 0.6040 - val_accuracy: 0.8499
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2116 - accuracy: 0.9587 - val_loss: 0.6048 - val_accuracy: 0.8483
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2103 - accuracy: 0.9604 - val_loss: 0.6053 - val_accuracy: 0.8511
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2098 - accuracy: 0.9597 - val_loss: 0.6266 - val_accuracy: 0.8475
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2114 - accuracy: 0.9590 - val_loss: 0.6175 - val_accuracy: 0.8492
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2109 - accuracy: 0.9592 - val_loss: 0.6242 - val_accuracy: 0.8452
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2072 - accuracy: 0.9606 - val_loss: 0.6083 - val_accuracy: 0.8507
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2092 - accuracy: 0.9595 - val_loss: 0.6211 - val_accuracy: 0.8484
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 101ms/step - loss: 0.2063 - accuracy: 0.9610 - val_loss: 0.6115 - val_accuracy: 0.8484
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2083 - accuracy: 0.9607 - val_loss: 0.6200 - val_accuracy: 0.8463

# %%
tess_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tess_conv2d (TessConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# tess_residual_unit (TessResi (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_1 (TessRe (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_2 (TessRe (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_3 (TessRe (None, None, None, 48)    8640
# _________________________________________________________________
# tess_residual_unit_4 (TessRe (None, None, None, 48)    10752
# _________________________________________________________________
# tess_residual_unit_5 (TessRe (None, None, None, 96)    33408
# _________________________________________________________________
# tess_residual_unit_6 (TessRe (None, None, None, 96)    42240
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 104,578
# Trainable params: 102,850
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(tess_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.9646

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(tess_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8463
