# %% [markdown]
# # Tessarine valued CNN with Real Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 9s 0us/step
# 170508288/170498071 [==============================] - 9s 0us/step

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class TessConv2D(layers.Layer):
    """
    Tessarine valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """

    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer,
                 data_format=None,
                 kernel_regularizer=1e-3):
        super(TessConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        if kernel_regularizer is not None:
            self.kernel_regularizer = kr.regularizers.l2(kernel_regularizer)
        else:
            self.kernel_regularizer = kernel_regularizer

    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('TessConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        F_r = tf.concat([ self.f0,-self.f1, self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3, self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0,-self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2, self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvTess = partial(TessConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class TessResidualUnit(layers.Layer):
    """ 
    Tessarine valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recog-nition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual net-works.
    """
    def __init__(self, filters, strides=1, activation="elu", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvTess(filters, strides=strides),
            kr.layers.BatchNormalization(),
            self.activation,
            DefaultConvTess(filters),
            kr.layers.BatchNormalization(),
            self.activation]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvTess(filters, kernel_size=(1,1), strides=strides),
                kr.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

tess_resnet = kr.models.Sequential()
tess_resnet.add(DefaultConvTess(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    tess_resnet.add(TessResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
tess_resnet.add(kr.layers.GlobalAvgPool2D())
tess_resnet.add(kr.layers.Flatten())
tess_resnet.add(kr.layers.Dense(10, activation="softmax"))
tess_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

tess_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 55s 122ms/step - loss: 2.2592 - accuracy: 0.3356 - val_loss: 2.6009 - val_accuracy: 0.1816
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 49s 126ms/step - loss: 2.0019 - accuracy: 0.4291 - val_loss: 2.4122 - val_accuracy: 0.2494
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 121ms/step - loss: 1.8909 - accuracy: 0.4707 - val_loss: 2.5132 - val_accuracy: 0.2796
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 49s 124ms/step - loss: 1.8101 - accuracy: 0.5013 - val_loss: 2.3568 - val_accuracy: 0.3068
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 48s 122ms/step - loss: 1.7547 - accuracy: 0.5184 - val_loss: 2.2049 - val_accuracy: 0.3436
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 48s 123ms/step - loss: 1.6977 - accuracy: 0.5403 - val_loss: 2.2898 - val_accuracy: 0.3217
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 1.6542 - accuracy: 0.5532 - val_loss: 2.2298 - val_accuracy: 0.3233
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 50s 127ms/step - loss: 1.6103 - accuracy: 0.5684 - val_loss: 2.0733 - val_accuracy: 0.3991
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 49s 126ms/step - loss: 1.5733 - accuracy: 0.5796 - val_loss: 2.2414 - val_accuracy: 0.3456
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 1.5395 - accuracy: 0.5878 - val_loss: 2.1861 - val_accuracy: 0.3511
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 119ms/step - loss: 1.8483 - accuracy: 0.4678 - val_loss: 2.2160 - val_accuracy: 0.3444
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 120ms/step - loss: 1.5072 - accuracy: 0.5796 - val_loss: 2.0549 - val_accuracy: 0.4041
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 119ms/step - loss: 1.3677 - accuracy: 0.6184 - val_loss: 1.6151 - val_accuracy: 0.5190
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 48s 122ms/step - loss: 1.2715 - accuracy: 0.6454 - val_loss: 1.8184 - val_accuracy: 0.5089
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 1.1890 - accuracy: 0.6702 - val_loss: 1.5613 - val_accuracy: 0.5394
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 118ms/step - loss: 1.1204 - accuracy: 0.6883 - val_loss: 1.5372 - val_accuracy: 0.5396
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 119ms/step - loss: 1.0696 - accuracy: 0.7029 - val_loss: 1.3410 - val_accuracy: 0.6138
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 48s 122ms/step - loss: 1.0245 - accuracy: 0.7161 - val_loss: 1.4136 - val_accuracy: 0.5797
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.9796 - accuracy: 0.7276 - val_loss: 1.4980 - val_accuracy: 0.5461
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 49s 125ms/step - loss: 0.9480 - accuracy: 0.7359 - val_loss: 1.2902 - val_accuracy: 0.6132
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 115ms/step - loss: 0.9162 - accuracy: 0.7440 - val_loss: 1.5524 - val_accuracy: 0.5484
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 118ms/step - loss: 0.8929 - accuracy: 0.7530 - val_loss: 1.0703 - val_accuracy: 0.6923
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 121ms/step - loss: 0.8674 - accuracy: 0.7590 - val_loss: 1.1561 - val_accuracy: 0.6617
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 44s 113ms/step - loss: 0.8439 - accuracy: 0.7655 - val_loss: 1.3537 - val_accuracy: 0.5985
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.8313 - accuracy: 0.7705 - val_loss: 1.1232 - val_accuracy: 0.6828
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.8167 - accuracy: 0.7745 - val_loss: 1.0877 - val_accuracy: 0.6800
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 44s 112ms/step - loss: 0.8048 - accuracy: 0.7773 - val_loss: 1.1251 - val_accuracy: 0.6690
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 120ms/step - loss: 0.7886 - accuracy: 0.7834 - val_loss: 1.0942 - val_accuracy: 0.6791
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 114ms/step - loss: 0.7788 - accuracy: 0.7860 - val_loss: 1.0566 - val_accuracy: 0.6941
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7660 - accuracy: 0.7905 - val_loss: 1.0759 - val_accuracy: 0.6913
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7541 - accuracy: 0.7949 - val_loss: 1.1634 - val_accuracy: 0.6599
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 44s 112ms/step - loss: 0.7497 - accuracy: 0.7966 - val_loss: 1.0413 - val_accuracy: 0.7098
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 117ms/step - loss: 0.7396 - accuracy: 0.7996 - val_loss: 0.9873 - val_accuracy: 0.7221
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 46s 116ms/step - loss: 0.7337 - accuracy: 0.8016 - val_loss: 0.9787 - val_accuracy: 0.7140
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 47s 119ms/step - loss: 0.7285 - accuracy: 0.8043 - val_loss: 1.2378 - val_accuracy: 0.6312
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 45s 116ms/step - loss: 0.
250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 120ms/step - loss: 0.3007 - accuracy: 0.9384 - val_loss: 0.6752 - val_accuracy: 0.8267
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.3003 - accuracy: 0.9394 - val_loss: 0.6401 - val_accuracy: 0.8377
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 116ms/step - loss: 0.2973 - accuracy: 0.9387 - val_loss: 0.6582 - val_accuracy: 0.8295
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2993 - accuracy: 0.9376 - val_loss: 0.6369 - val_accuracy: 0.8369
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2941 - accuracy: 0.9389 - val_loss: 0.6853 - val_accuracy: 0.8186
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2920 - accuracy: 0.9397 - val_loss: 0.6673 - val_accuracy: 0.8279
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2879 - accuracy: 0.9400 - val_loss: 0.6159 - val_accuracy: 0.8457
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2866 - accuracy: 0.9416 - val_loss: 0.6814 - val_accuracy: 0.8230
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2879 - accuracy: 0.9391 - val_loss: 0.6579 - val_accuracy: 0.8286
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2854 - accuracy: 0.9405 - val_loss: 0.6127 - val_accuracy: 0.8446
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 115ms/step - loss: 0.2836 - accuracy: 0.9408 - val_loss: 0.6572 - val_accuracy: 0.8315
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2812 - accuracy: 0.9397 - val_loss: 0.6500 - val_accuracy: 0.8341
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2806 - accuracy: 0.9408 - val_loss: 0.7020 - val_accuracy: 0.8172
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2810 - accuracy: 0.9396 - val_loss: 0.7027 - val_accuracy: 0.8135
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2780 - accuracy: 0.9406 - val_loss: 0.7201 - val_accuracy: 0.8110
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 115ms/step - loss: 0.2742 - accuracy: 0.9416 - val_loss: 0.7111 - val_accuracy: 0.8123
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2739 - accuracy: 0.9412 - val_loss: 0.6808 - val_accuracy: 0.8222
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2734 - accuracy: 0.9414 - val_loss: 0.7752 - val_accuracy: 0.7959
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2746 - accuracy: 0.9403 - val_loss: 0.6349 - val_accuracy: 0.8363
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2707 - accuracy: 0.9403 - val_loss: 0.7285 - val_accuracy: 0.8151
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2719 - accuracy: 0.9398 - val_loss: 0.6490 - val_accuracy: 0.8321
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2665 - accuracy: 0.9427 - val_loss: 0.6432 - val_accuracy: 0.8345
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2694 - accuracy: 0.9409 - val_loss: 0.7018 - val_accuracy: 0.8171
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2656 - accuracy: 0.9423 - val_loss: 0.7106 - val_accuracy: 0.8138
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2477 - accuracy: 0.9493 - val_loss: 0.6624 - val_accuracy: 0.8268
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2365 - accuracy: 0.9531 - val_loss: 0.6479 - val_accuracy: 0.8319
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2364 - accuracy: 0.9525 - val_loss: 0.6375 - val_accuracy: 0.8354
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.2340 - accuracy: 0.9539 - val_loss: 0.6537 - val_accuracy: 0.8295
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 123ms/step - loss: 0.2341 - accuracy: 0.9538 - val_loss: 0.6310 - val_accuracy: 0.8396
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 114ms/step - loss: 0.2316 - accuracy: 0.9537 - val_loss: 0.6582 - val_accuracy: 0.8302
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2290 - accuracy: 0.9547 - val_loss: 0.6473 - val_accuracy: 0.8324
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 124ms/step - loss: 0.2296 - accuracy: 0.9549 - val_loss: 0.6355 - val_accuracy: 0.8356
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2291 - accuracy: 0.9550 - val_loss: 0.6459 - val_accuracy: 0.8346
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2267 - accuracy: 0.9548 - val_loss: 0.6666 - val_accuracy: 0.8283
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2281 - accuracy: 0.9553 - val_loss: 0.6424 - val_accuracy: 0.8336
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2253 - accuracy: 0.9569 - val_loss: 0.6356 - val_accuracy: 0.8368
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 124ms/step - loss: 0.2274 - accuracy: 0.9562 - val_loss: 0.6539 - val_accuracy: 0.8331
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2240 - accuracy: 0.9570 - val_loss: 0.6647 - val_accuracy: 0.8262
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2259 - accuracy: 0.9567 - val_loss: 0.6517 - val_accuracy: 0.8333
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2222 - accuracy: 0.9573 - val_loss: 0.6532 - val_accuracy: 0.8313
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2223 - accuracy: 0.9570 - val_loss: 0.6368 - val_accuracy: 0.8359
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2226 - accuracy: 0.9571 - val_loss: 0.6398 - val_accuracy: 0.8355
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 121ms/step - loss: 0.2233 - accuracy: 0.9569 - val_loss: 0.6541 - val_accuracy: 0.8310
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 121ms/step - loss: 0.2202 - accuracy: 0.9575 - val_loss: 0.6732 - val_accuracy: 0.8275
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2219 - accuracy: 0.9569 - val_loss: 0.6543 - val_accuracy: 0.8314
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2236 - accuracy: 0.9560 - val_loss: 0.6345 - val_accuracy: 0.8364
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2214 - accuracy: 0.9576 - val_loss: 0.6426 - val_accuracy: 0.8355
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2223 - accuracy: 0.9578 - val_loss: 0.6623 - val_accuracy: 0.8300
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 123ms/step - loss: 0.2190 - accuracy: 0.9574 - val_loss: 0.6420 - val_accuracy: 0.8338
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2196 - accuracy: 0.9580 - val_loss: 0.6580 - val_accuracy: 0.8305
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 123ms/step - loss: 0.2188 - accuracy: 0.9574 - val_loss: 0.6495 - val_accuracy: 0.8330
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 121ms/step - loss: 0.2198 - accuracy: 0.9571 - val_loss: 0.6489 - val_accuracy: 0.8361
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2185 - accuracy: 0.9573 - val_loss: 0.6431 - val_accuracy: 0.8348
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2176 - accuracy: 0.9580 - val_loss: 0.6644 - val_accuracy: 0.8295
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2174 - accuracy: 0.9581 - val_loss: 0.6665 - val_accuracy: 0.8286
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 50s 127ms/step - loss: 0.2170 - accuracy: 0.9588 - val_loss: 0.6748 - val_accuracy: 0.8275
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 121ms/step - loss: 0.2168 - accuracy: 0.9594 - val_loss: 0.6660 - val_accuracy: 0.8291
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2170 - accuracy: 0.9582 - val_loss: 0.6468 - val_accuracy: 0.8354
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2159 - accuracy: 0.9585 - val_loss: 0.6476 - val_accuracy: 0.8347
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 119ms/step - loss: 0.2182 - accuracy: 0.9571 - val_loss: 0.6382 - val_accuracy: 0.8379
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2135 - accuracy: 0.9594 - val_loss: 0.6826 - val_accuracy: 0.8261
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2146 - accuracy: 0.9583 - val_loss: 0.6615 - val_accuracy: 0.8314
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 122ms/step - loss: 0.2143 - accuracy: 0.9593 - val_loss: 0.6895 - val_accuracy: 0.8238
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2178 - accuracy: 0.9565 - val_loss: 0.6662 - val_accuracy: 0.8304
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 117ms/step - loss: 0.2157 - accuracy: 0.9582 - val_loss: 0.6804 - val_accuracy: 0.8266
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2170 - accuracy: 0.9573 - val_loss: 0.7088 - val_accuracy: 0.8170
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 48s 123ms/step - loss: 0.2125 - accuracy: 0.9597 - val_loss: 0.6721 - val_accuracy: 0.8300
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2146 - accuracy: 0.9585 - val_loss: 0.6648 - val_accuracy: 0.8310
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 119ms/step - loss: 0.2127 - accuracy: 0.9591 - val_loss: 0.6559 - val_accuracy: 0.8341
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2122 - accuracy: 0.9595 - val_loss: 0.6731 - val_accuracy: 0.8300
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 49s 126ms/step - loss: 0.2117 - accuracy: 0.9594 - val_loss: 0.6800 - val_accuracy: 0.8271
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 121ms/step - loss: 0.2120 - accuracy: 0.9593 - val_loss: 0.6547 - val_accuracy: 0.8348
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 46s 118ms/step - loss: 0.2112 - accuracy: 0.9593 - val_loss: 0.6572 - val_accuracy: 0.8336
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 47s 120ms/step - loss: 0.2135 - accuracy: 0.9576 - val_loss: 0.6703 - val_accuracy: 0.8309

# %%
tess_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tess_conv2d (TessConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# tess_residual_unit (TessResi (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_1 (TessRe (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_2 (TessRe (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_3 (TessRe (None, None, None, 48)    8640
# _________________________________________________________________
# tess_residual_unit_4 (TessRe (None, None, None, 48)    10752
# _________________________________________________________________
# tess_residual_unit_5 (TessRe (None, None, None, 96)    33408
# _________________________________________________________________
# tess_residual_unit_6 (TessRe (None, None, None, 96)    42240
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 104,578
# Trainable params: 102,850
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(tess_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96262

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(tess_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8309
