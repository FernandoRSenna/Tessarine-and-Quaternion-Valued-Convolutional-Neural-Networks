# %% [markdown]
# # Tessarine valued CNN with Real Batch Normalization

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as kr
import matplotlib.pyplot as plt
from tensorflow.keras import datasets, models 
from tensorflow.keras import layers, activations, initializers, regularizers
from tensorflow.python.framework import tensor_shape
from tensorflow.python.keras.engine.input_spec import InputSpec
from functools import partial
from keras.preprocessing.image import ImageDataGenerator
from keras.datasets import cifar10
from sklearn.metrics import accuracy_score
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.python.ops import variables as tf_variables

# %%
(Xtr_cifar, ytr_cifar), (Xte_cifar, yte_cifar) = cifar10.load_data()
Xtr_cifar = Xtr_cifar / 255
Xte_cifar = Xte_cifar / 255

Xtr_cifar -= np.mean(Xtr_cifar, axis=0)
Xte_cifar -= np.mean(Xtr_cifar, axis=0)

n_classes = 10
ytr_cifar = kr.utils.to_categorical(ytr_cifar, num_classes=n_classes)
yte_cifar = kr.utils.to_categorical(yte_cifar, num_classes=n_classes)

# %%
def learning_rate(epoch):
    lr = 1e-2
    if epoch < 151 and epoch > 9:
        lr *= 10.
    elif epoch > 199:
        lr /= 10.
    print('Learning rate: ', lr)
    return lr

# %%
def _compute_fans(shape):
    """Computes the number of input and output units for a weight shape.
    Args:
        shape: Integer shape tuple or TF tensor shape.
    Returns:
        A tuple of integer scalars (fan_in, fan_out).

    Extracted from tensorflow/keras/initializers. Available at
    https://github.com/tensorflow/tensorflow/blob/v2.5.0/tensorflow/python/keras/initializers/initializers_v2.py
    """

    if len(shape) < 1:  # Just to avoid errors for constants.
        fan_in = fan_out = 1
    elif len(shape) == 1:
        fan_in = fan_out = shape[0]
    elif len(shape) == 2:
        fan_in = shape[0]
        fan_out = shape[1]
    else:
        # Assuming convolution kernels (2D, 3D, or more).
        # kernel shape: (..., input_depth, depth)
        receptive_field_size = 1
        for dim in shape[:-2]:
            receptive_field_size *= dim
        fan_in = shape[-2] * receptive_field_size
        fan_out = shape[-1] * receptive_field_size
    return int(fan_in), int(fan_out)


class Hypercomplex4DInitializer(initializers.Initializer):
    """
    Computes initialization based on quaternion variance.
    Options: he uniform, he normal, glorot uniform, glorot normal.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015b).  Delving deep into rectifiers: Surpassing human-level performance on imagenet classification.
    [2] Glorot, X. and Bengio, Y. (2010).  Understanding the difficulty of training deep feedforward neural networks.  
    In Teh, Y. W. and Titterington, M., editors, Proceedings of the Thirteenth International Conference on Artificial Intelligence and Statistics,
    volume 9 of Proceedings of Machine Learning Research, pages 249–256, Chia Laguna Resort, Sardinia, Italy. PMLR.
    """
    def __init__(self, criterion='he', distribution='uniform', seed=31337):
        self.criterion = criterion
        self.distribution = distribution
        self.seed = seed

    def __call__(self, shape, dtype):
        fan_in, fan_out = _compute_fans(shape)

        if self.criterion == 'he':
            std = 1. / np.sqrt(2 * fan_in)
        elif self.criterion == 'glorot':
            std = 1. / np.sqrt(2 * (fan_in + fan_out))
        else:
            raise ValueError("Chosen criterion was not identified.")

        if self.distribution == 'normal':
            return tf.random.normal(shape, mean=0, stddev=std, dtype=dtype, seed=self.seed)
        elif self.distribution == 'uniform':
            lim = std * np.sqrt(3)
            return tf.random.uniform(shape, minval=-lim, maxval=lim, dtype=dtype, seed=self.seed)
        else:
            raise ValueError("Chosen distribution was not identified")

# %%
class TessConv2D(layers.Layer):
    """
    Tessarine valued 2D convolution layer.
    References:
    [1] Trabelsi, C., Bilaniuk, O., Serdyuk, D., Subramanian, S., Santos, J. F., Mehri, S., Rostamzadeh, N., Bengio, Y., and Pal, C. J. (2017). Deep complex networks.
    [2] Gaudet, C. and Maida, A. (2017). Deep quaternion networks.
    """

    def __init__(self, 
                 filters, 
                 kernel_size, 
                 strides=1, 
                 padding='SAME',
                 use_bias=False,
                 activation=None,
                 initializer=Hypercomplex4DInitializer,
                 data_format=None,
                 kernel_regularizer=1e-3):
        super(TessConv2D, self).__init__()
        self.filters = filters 
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.use_bias = use_bias
        self.activation = activations.get(activation)
        self.initializer = initializer
        self.data_format = data_format
        if kernel_regularizer is not None:
            self.kernel_regularizer = kr.regularizers.l2(kernel_regularizer)
        else:
            self.kernel_regularizer = kernel_regularizer

    def _get_channel_axis(self):
        if self.data_format == 'channels_first':
            raise ValueError('TessConv2d is designed only for channels_last. '
                             'The input has been changed to channels last!')
        else:
            return -1
    
    def _get_input_channel(self, input_shape):
        channel_axis = self._get_channel_axis()
        if input_shape.dims[channel_axis].value is None:
            raise ValueError('The channel dimension of the inputs '
                             'should be defined. Found `None`.')
        return int(input_shape[channel_axis])

    def build(self, input_shape):
        input_shape = tensor_shape.TensorShape(input_shape)
        input_channel = self._get_input_channel(input_shape)
        if input_channel % 4 != 0:
            raise ValueError('The number of input channels must be divisible by 4.')
    
        input_dim = input_channel // 4
        kernel_shape = self.kernel_size + (input_dim, self.filters)
        
        self.f0 = self.add_weight(
            name='real_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f1 = self.add_weight(
            name='imag_i_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f2 = self.add_weight(
            name='imag_j_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        self.f3 = self.add_weight(
            name='imag_k_kernel',
            shape=kernel_shape,
            initializer=self.initializer,
            trainable=True,
            regularizer=self.kernel_regularizer
        )
        
        if self.use_bias:
            self.bias = self.add_weight(
                name='bias',
                shape=(4*self.filters,),
                initializer="zeros",
                trainable=True,
                dtype=self.dtype)
        else:
            self.bias = None

    def call(self, inputs):
        F_r = tf.concat([ self.f0,-self.f1, self.f2,-self.f3],axis=2)
        F_i = tf.concat([ self.f1, self.f0, self.f3, self.f2],axis=2)
        F_j = tf.concat([ self.f2,-self.f3, self.f0,-self.f1],axis=2)
        F_k = tf.concat([ self.f3, self.f2, self.f1, self.f0],axis=2)
               
        y_r = tf.nn.conv2d(inputs, F_r, strides=self.strides, padding=self.padding)
        y_i = tf.nn.conv2d(inputs, F_i, strides=self.strides, padding=self.padding)
        y_j = tf.nn.conv2d(inputs, F_j, strides=self.strides, padding=self.padding)
        y_k = tf.nn.conv2d(inputs, F_k, strides=self.strides, padding=self.padding)
        
        outputs = tf.concat([y_r, y_i, y_j, y_k],axis=3)
        
        if self.use_bias:
            outputs = tf.nn.bias_add(outputs,self.bias)
            
        if self.activation is not None:
            outputs = self.activation(outputs)
        
        return outputs

# %%
DefaultConvTess = partial(TessConv2D, kernel_size=(3,3), strides=1, padding="SAME", kernel_regularizer=1e-3, use_bias=False)

# %%
class TessResidualUnit(layers.Layer):
    """ 
    Tessarine valued residual unit.
    References:
    [1] He, K., Zhang, X., Ren, S., and Sun, J. (2015).  Deep residual learning for image recog-nition.
    [2] He, K., Zhang, X., Ren, S., and Sun, J. (2016).  Identity mappings in deep residual net-works.
    """
    def __init__(self, filters, strides=1, activation="elu", **kwargs):
        super().__init__(**kwargs)
        self.activation = kr.activations.get(activation)
        self.main_layers = [
            DefaultConvTess(filters, strides=strides),
            kr.layers.BatchNormalization(),
            self.activation,
            DefaultConvTess(filters),
            kr.layers.BatchNormalization(),
            self.activation]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConvTess(filters, kernel_size=(1,1), strides=strides),
                kr.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
activation = "elu"

tess_resnet = kr.models.Sequential()
tess_resnet.add(DefaultConvTess(6, kernel_size=(3,3), strides=1))
prev_filters = 6
for filters in [6] * 3 + [12] * 2 + [24] * 2:
    strides = 1 if filters == prev_filters else 2
    tess_resnet.add(TessResidualUnit(filters, strides=strides, activation=activation))
    prev_filters = filters
tess_resnet.add(kr.layers.GlobalAvgPool2D())
tess_resnet.add(kr.layers.Flatten())
tess_resnet.add(kr.layers.Dense(10, activation="softmax"))
tess_resnet.compile(loss="categorical_crossentropy", optimizer=kr.optimizers.SGD(learning_rate=learning_rate(0)), metrics=["accuracy"])
# Out:
# Learning rate:  0.01

# %%
lr_scheduler = LearningRateScheduler(learning_rate)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=1e-4)
callbacks = [lr_reducer,lr_scheduler]

# %%
Xtr_rgb = np.append(np.zeros([Xtr_cifar.shape[0],32,32,1]),Xtr_cifar,axis=3)
Xte_rgb = np.append(np.zeros([Xte_cifar.shape[0],32,32,1]),Xte_cifar,axis=3)

# %%
datagen = ImageDataGenerator(width_shift_range=0.125, height_shift_range=0.125, horizontal_flip=True)
datagen.fit(Xtr_rgb)

# %%
batch_size = 128
epochs = 250

tess_resnet.fit(datagen.flow(Xtr_rgb, ytr_cifar, batch_size=batch_size), epochs=epochs, validation_data=(Xte_rgb,yte_cifar), callbacks=callbacks)
# Out:
# Epoch 1/250
# Learning rate:  0.01
# 391/391 [==============================] - 45s 100ms/step - loss: 2.2476 - accuracy: 0.3369 - val_loss: 2.6323 - val_accuracy: 0.2016
# Epoch 2/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 2.0268 - accuracy: 0.4144 - val_loss: 2.5388 - val_accuracy: 0.2220
# Epoch 3/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 1.9362 - accuracy: 0.4525 - val_loss: 2.4240 - val_accuracy: 0.2820
# Epoch 4/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 1.8601 - accuracy: 0.4812 - val_loss: 2.3767 - val_accuracy: 0.3033
# Epoch 5/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 1.7965 - accuracy: 0.5040 - val_loss: 2.5539 - val_accuracy: 0.2477
# Epoch 6/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 1.7428 - accuracy: 0.5204 - val_loss: 2.2388 - val_accuracy: 0.3445
# Epoch 7/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 97ms/step - loss: 1.6984 - accuracy: 0.5351 - val_loss: 2.4377 - val_accuracy: 0.2945
# Epoch 8/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 1.6553 - accuracy: 0.5492 - val_loss: 2.2023 - val_accuracy: 0.3379
# Epoch 9/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 1.6207 - accuracy: 0.5604 - val_loss: 2.0278 - val_accuracy: 0.4140
# Epoch 10/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 1.5794 - accuracy: 0.5723 - val_loss: 1.9811 - val_accuracy: 0.4339
# Epoch 11/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 1.8381 - accuracy: 0.4706 - val_loss: 2.1678 - val_accuracy: 0.3810
# Epoch 12/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.5072 - accuracy: 0.5806 - val_loss: 2.5090 - val_accuracy: 0.3302
# Epoch 13/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 1.3794 - accuracy: 0.6208 - val_loss: 1.6405 - val_accuracy: 0.5122
# Epoch 14/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 1.2812 - accuracy: 0.6442 - val_loss: 1.5944 - val_accuracy: 0.5410
# Epoch 15/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 1.2048 - accuracy: 0.6638 - val_loss: 1.4770 - val_accuracy: 0.5715
# Epoch 16/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 1.1384 - accuracy: 0.6830 - val_loss: 1.4006 - val_accuracy: 0.5977
# Epoch 17/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 1.0822 - accuracy: 0.6988 - val_loss: 1.3737 - val_accuracy: 0.6039
# Epoch 18/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 1.0412 - accuracy: 0.7076 - val_loss: 1.4761 - val_accuracy: 0.5681
# Epoch 19/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.9969 - accuracy: 0.7188 - val_loss: 1.3996 - val_accuracy: 0.5948
# Epoch 20/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.9654 - accuracy: 0.7299 - val_loss: 1.3941 - val_accuracy: 0.5881
# Epoch 21/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.9342 - accuracy: 0.7385 - val_loss: 1.3068 - val_accuracy: 0.6140
# Epoch 22/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.9034 - accuracy: 0.7491 - val_loss: 1.1974 - val_accuracy: 0.6553
# Epoch 23/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.8846 - accuracy: 0.7535 - val_loss: 1.0982 - val_accuracy: 0.6849
# Epoch 24/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.8662 - accuracy: 0.7583 - val_loss: 0.9755 - val_accuracy: 0.7170
# Epoch 25/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.8420 - accuracy: 0.7686 - val_loss: 1.1183 - val_accuracy: 0.6755
# Epoch 26/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.8274 - accuracy: 0.7734 - val_loss: 1.1011 - val_accuracy: 0.6839
# Epoch 27/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.8128 - accuracy: 0.7762 - val_loss: 1.1539 - val_accuracy: 0.6719
# Epoch 28/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.8004 - accuracy: 0.7806 - val_loss: 1.1685 - val_accuracy: 0.6653
# Epoch 29/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.7839 - accuracy: 0.7854 - val_loss: 1.2319 - val_accuracy: 0.6544
# Epoch 30/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.7742 - accuracy: 0.7879 - val_loss: 1.4150 - val_accuracy: 0.6112
# Epoch 31/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.7625 - accuracy: 0.7934 - val_loss: 1.0687 - val_accuracy: 0.6875
# Epoch 32/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.7533 - accuracy: 0.7960 - val_loss: 0.9646 - val_accuracy: 0.7295
# Epoch 33/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.7456 - accuracy: 0.7978 - val_loss: 1.0163 - val_accuracy: 0.7072
# Epoch 34/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.7436 - accuracy: 0.7989 - val_loss: 1.0423 - val_accuracy: 0.6969
# Epoch 35/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.7336 - accuracy: 0.8028 - val_loss: 1.0340 - val_accuracy: 0.7121
# Epoch 36/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.7230 - accuracy: 0.8058 - val_loss: 1.0763 - val_accuracy: 0.6927
# Epoch 37/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.7205 - accuracy: 0.8085 - val_loss: 1.1705 - val_accuracy: 0.6770
# Epoch 38/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.7095 - accuracy: 0.8124 - val_loss: 1.1179 - val_accuracy: 0.6819
# Epoch 39/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.7088 - accuracy: 0.8115 - val_loss: 1.0384 - val_accuracy: 0.6927
# Epoch 40/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6984 - accuracy: 0.8150 - val_loss: 0.9176 - val_accuracy: 0.7478
# Epoch 41/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.7010 - accuracy: 0.8146 - val_loss: 1.1956 - val_accuracy: 0.6416
# Epoch 42/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6924 - accuracy: 0.8182 - val_loss: 1.2697 - val_accuracy: 0.6628
# Epoch 43/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.6848 - accuracy: 0.8201 - val_loss: 1.2727 - val_accuracy: 0.6521
# Epoch 44/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6786 - accuracy: 0.8217 - val_loss: 0.8177 - val_accuracy: 0.7776
# Epoch 45/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6757 - accuracy: 0.8234 - val_loss: 1.1373 - val_accuracy: 0.6812
# Epoch 46/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6747 - accuracy: 0.8247 - val_loss: 0.8725 - val_accuracy: 0.7633
# Epoch 47/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6678 - accuracy: 0.8277 - val_loss: 0.8835 - val_accuracy: 0.7529
# Epoch 48/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6657 - accuracy: 0.8279 - val_loss: 1.1136 - val_accuracy: 0.6930
# Epoch 49/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6594 - accuracy: 0.8299 - val_loss: 1.1173 - val_accuracy: 0.7018
# Epoch 50/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6607 - accuracy: 0.8280 - val_loss: 1.0146 - val_accuracy: 0.7252
# Epoch 51/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6572 - accuracy: 0.8298 - val_loss: 1.3935 - val_accuracy: 0.6074
# Epoch 52/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6498 - accuracy: 0.8320 - val_loss: 1.0029 - val_accuracy: 0.7233
# Epoch 53/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6499 - accuracy: 0.8336 - val_loss: 0.9408 - val_accuracy: 0.7444
# Epoch 54/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6485 - accuracy: 0.8335 - val_loss: 0.9656 - val_accuracy: 0.7340
# Epoch 55/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6403 - accuracy: 0.8350 - val_loss: 0.8320 - val_accuracy: 0.7799
# Epoch 56/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.6398 - accuracy: 0.8356 - val_loss: 0.9682 - val_accuracy: 0.7262
# Epoch 57/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6387 - accuracy: 0.8365 - val_loss: 0.8724 - val_accuracy: 0.7586
# Epoch 58/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.6335 - accuracy: 0.8381 - val_loss: 1.0436 - val_accuracy: 0.7117
# Epoch 59/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6340 - accuracy: 0.8397 - val_loss: 1.2528 - val_accuracy: 0.6569
# Epoch 60/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6322 - accuracy: 0.8395 - val_loss: 0.9441 - val_accuracy: 0.7340
# Epoch 61/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6275 - accuracy: 0.8410 - val_loss: 0.9453 - val_accuracy: 0.7411
# Epoch 62/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.6236 - accuracy: 0.8429 - val_loss: 0.9540 - val_accuracy: 0.7429
# Epoch 63/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.6270 - accuracy: 0.8408 - val_loss: 0.7735 - val_accuracy: 0.7958
# Epoch 64/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6170 - accuracy: 0.8462 - val_loss: 1.1630 - val_accuracy: 0.6794
# Epoch 65/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6189 - accuracy: 0.8457 - val_loss: 0.9477 - val_accuracy: 0.7348
# Epoch 66/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6187 - accuracy: 0.8457 - val_loss: 0.8645 - val_accuracy: 0.7649
# Epoch 67/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6179 - accuracy: 0.8464 - val_loss: 0.8207 - val_accuracy: 0.7812
# Epoch 68/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.6139 - accuracy: 0.8457 - val_loss: 0.9469 - val_accuracy: 0.7392
# Epoch 69/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.6104 - accuracy: 0.8488 - val_loss: 0.8103 - val_accuracy: 0.7855
# Epoch 70/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6122 - accuracy: 0.8479 - val_loss: 0.7882 - val_accuracy: 0.7905
# Epoch 71/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.6088 - accuracy: 0.8473 - val_loss: 0.9550 - val_accuracy: 0.7545
# Epoch 72/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.6078 - accuracy: 0.8484 - val_loss: 0.9034 - val_accuracy: 0.7595
# Epoch 73/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.6038 - accuracy: 0.8506 - val_loss: 1.3894 - val_accuracy: 0.6339
# Epoch 74/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.6051 - accuracy: 0.8516 - val_loss: 0.7842 - val_accuracy: 0.7962
# Epoch 75/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.6000 - accuracy: 0.8522 - val_loss: 0.9327 - val_accuracy: 0.7543
# Epoch 76/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5982 - accuracy: 0.8513 - val_loss: 0.9427 - val_accuracy: 0.7480
# Epoch 77/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5956 - accuracy: 0.8538 - val_loss: 0.8775 - val_accuracy: 0.7621
# Epoch 78/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 106ms/step - loss: 0.5958 - accuracy: 0.8529 - val_loss: 0.9758 - val_accuracy: 0.7282
# Epoch 79/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5924 - accuracy: 0.8564 - val_loss: 0.8999 - val_accuracy: 0.7569
# Epoch 80/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5921 - accuracy: 0.8540 - val_loss: 0.8816 - val_accuracy: 0.7699
# Epoch 81/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5964 - accuracy: 0.8548 - val_loss: 0.8807 - val_accuracy: 0.7703
# Epoch 82/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5890 - accuracy: 0.8540 - val_loss: 0.9978 - val_accuracy: 0.7393
# Epoch 83/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5874 - accuracy: 0.8562 - val_loss: 0.8399 - val_accuracy: 0.7787
# Epoch 84/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5920 - accuracy: 0.8548 - val_loss: 0.9717 - val_accuracy: 0.7467
# Epoch 85/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5841 - accuracy: 0.8591 - val_loss: 0.9030 - val_accuracy: 0.7628
# Epoch 86/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5906 - accuracy: 0.8557 - val_loss: 0.9038 - val_accuracy: 0.7474
# Epoch 87/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5847 - accuracy: 0.8572 - val_loss: 0.9119 - val_accuracy: 0.7637
# Epoch 88/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5825 - accuracy: 0.8596 - val_loss: 0.9479 - val_accuracy: 0.7404
# Epoch 89/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5779 - accuracy: 0.8607 - val_loss: 0.8714 - val_accuracy: 0.7668
# Epoch 90/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5801 - accuracy: 0.8597 - val_loss: 0.9297 - val_accuracy: 0.7661
# Epoch 91/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5791 - accuracy: 0.8601 - val_loss: 0.8314 - val_accuracy: 0.7823
# Epoch 92/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5799 - accuracy: 0.8598 - val_loss: 0.8399 - val_accuracy: 0.7774
# Epoch 93/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5750 - accuracy: 0.8607 - val_loss: 1.0636 - val_accuracy: 0.7231
# Epoch 94/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5791 - accuracy: 0.8579 - val_loss: 0.8151 - val_accuracy: 0.7885
# Epoch 95/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5754 - accuracy: 0.8609 - val_loss: 0.8244 - val_accuracy: 0.7892
# Epoch 96/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5714 - accuracy: 0.8624 - val_loss: 1.1120 - val_accuracy: 0.6945
# Epoch 97/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5745 - accuracy: 0.8616 - val_loss: 1.1307 - val_accuracy: 0.6878
# Epoch 98/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5742 - accuracy: 0.8626 - val_loss: 1.1724 - val_accuracy: 0.7120
# Epoch 99/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5694 - accuracy: 0.8648 - val_loss: 0.9436 - val_accuracy: 0.7556
# Epoch 100/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5727 - accuracy: 0.8606 - val_loss: 1.1094 - val_accuracy: 0.7101
# Epoch 101/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5684 - accuracy: 0.8641 - val_loss: 1.1461 - val_accuracy: 0.6942
# Epoch 102/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5667 - accuracy: 0.8630 - val_loss: 0.9829 - val_accuracy: 0.7291
# Epoch 103/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5668 - accuracy: 0.8627 - val_loss: 0.9692 - val_accuracy: 0.7449
# Epoch 104/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5632 - accuracy: 0.8652 - val_loss: 0.8737 - val_accuracy: 0.7612
# Epoch 105/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5635 - accuracy: 0.8636 - val_loss: 0.8729 - val_accuracy: 0.7677
# Epoch 106/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5648 - accuracy: 0.8658 - val_loss: 0.9577 - val_accuracy: 0.7483
# Epoch 107/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5655 - accuracy: 0.8641 - val_loss: 0.9004 - val_accuracy: 0.7587
# Epoch 108/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5636 - accuracy: 0.8659 - val_loss: 0.9371 - val_accuracy: 0.7501
# Epoch 109/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5565 - accuracy: 0.8677 - val_loss: 0.8247 - val_accuracy: 0.7789
# Epoch 110/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5608 - accuracy: 0.8669 - val_loss: 0.9977 - val_accuracy: 0.7295
# Epoch 111/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5590 - accuracy: 0.8680 - val_loss: 0.8823 - val_accuracy: 0.7710
# Epoch 112/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5597 - accuracy: 0.8661 - val_loss: 0.7717 - val_accuracy: 0.7947
# Epoch 113/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5634 - accuracy: 0.8654 - val_loss: 0.9476 - val_accuracy: 0.7510
# Epoch 114/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5559 - accuracy: 0.8685 - val_loss: 0.9020 - val_accuracy: 0.7602
# Epoch 115/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5577 - accuracy: 0.8666 - val_loss: 0.9682 - val_accuracy: 0.7390
# Epoch 116/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5579 - accuracy: 0.8673 - val_loss: 0.8800 - val_accuracy: 0.7759
# Epoch 117/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5564 - accuracy: 0.8664 - val_loss: 0.8030 - val_accuracy: 0.7913
# Epoch 118/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5534 - accuracy: 0.8674 - val_loss: 1.0867 - val_accuracy: 0.7072
# Epoch 119/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5557 - accuracy: 0.8680 - val_loss: 0.7731 - val_accuracy: 0.7990
# Epoch 120/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5538 - accuracy: 0.8683 - val_loss: 0.7925 - val_accuracy: 0.7963
# Epoch 121/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5496 - accuracy: 0.8690 - val_loss: 0.8067 - val_accuracy: 0.7975
# Epoch 122/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 103ms/step - loss: 0.5530 - accuracy: 0.8680 - val_loss: 0.8113 - val_accuracy: 0.7847
# Epoch 123/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5473 - accuracy: 0.8720 - val_loss: 0.8245 - val_accuracy: 0.7886
# Epoch 124/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 98ms/step - loss: 0.5544 - accuracy: 0.8684 - val_loss: 0.9324 - val_accuracy: 0.7558
# Epoch 125/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 106ms/step - loss: 0.5458 - accuracy: 0.8722 - val_loss: 0.9164 - val_accuracy: 0.7686
# Epoch 126/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5492 - accuracy: 0.8696 - val_loss: 0.8813 - val_accuracy: 0.7604
# Epoch 127/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5443 - accuracy: 0.8723 - val_loss: 0.7750 - val_accuracy: 0.7995
# Epoch 128/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5472 - accuracy: 0.8708 - val_loss: 0.9061 - val_accuracy: 0.7601
# Epoch 129/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5470 - accuracy: 0.8715 - val_loss: 0.9623 - val_accuracy: 0.7563
# Epoch 130/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5446 - accuracy: 0.8722 - val_loss: 0.8682 - val_accuracy: 0.7813
# Epoch 131/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5452 - accuracy: 0.8736 - val_loss: 0.8040 - val_accuracy: 0.7911
# Epoch 132/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5402 - accuracy: 0.8750 - val_loss: 1.0239 - val_accuracy: 0.7384
# Epoch 133/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 100ms/step - loss: 0.5463 - accuracy: 0.8716 - val_loss: 0.7980 - val_accuracy: 0.7972
# Epoch 134/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 101ms/step - loss: 0.5396 - accuracy: 0.8748 - val_loss: 1.2344 - val_accuracy: 0.6652
# Epoch 135/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5398 - accuracy: 0.8744 - val_loss: 0.9444 - val_accuracy: 0.7542
# Epoch 136/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 108ms/step - loss: 0.5431 - accuracy: 0.8732 - val_loss: 1.3253 - val_accuracy: 0.6462
# Epoch 137/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5430 - accuracy: 0.8721 - val_loss: 0.9317 - val_accuracy: 0.7692
# Epoch 138/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5418 - accuracy: 0.8730 - val_loss: 0.8581 - val_accuracy: 0.7795
# Epoch 139/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5373 - accuracy: 0.8746 - val_loss: 0.7544 - val_accuracy: 0.8059
# Epoch 140/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5384 - accuracy: 0.8735 - val_loss: 1.0445 - val_accuracy: 0.7396
# Epoch 141/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 98ms/step - loss: 0.5411 - accuracy: 0.8724 - val_loss: 0.9172 - val_accuracy: 0.7576
# Epoch 142/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 101ms/step - loss: 0.5391 - accuracy: 0.8721 - val_loss: 0.9670 - val_accuracy: 0.7530
# Epoch 143/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5375 - accuracy: 0.8747 - val_loss: 0.7927 - val_accuracy: 0.7879
# Epoch 144/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 105ms/step - loss: 0.5375 - accuracy: 0.8751 - val_loss: 0.7668 - val_accuracy: 0.8126
# Epoch 145/250
# Learning rate:  0.1
# 391/391 [==============================] - 42s 107ms/step - loss: 0.5353 - accuracy: 0.8762 - val_loss: 0.8690 - val_accuracy: 0.7744
# Epoch 146/250
# Learning rate:  0.1
# 391/391 [==============================] - 41s 104ms/step - loss: 0.5360 - accuracy: 0.8761 - val_loss: 0.7973 - val_accuracy: 0.7903
# Epoch 147/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5346 - accuracy: 0.8758 - val_loss: 0.9726 - val_accuracy: 0.7512
# Epoch 148/250
# Learning rate:  0.1
# 391/391 [==============================] - 39s 99ms/step - loss: 0.5361 - accuracy: 0.8769 - val_loss: 0.7583 - val_accuracy: 0.8031
# Epoch 149/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5331 - accuracy: 0.8746 - val_loss: 0.9484 - val_accuracy: 0.7465
# Epoch 150/250
# Learning rate:  0.1
# 391/391 [==============================] - 38s 97ms/step - loss: 0.5353 - accuracy: 0.8755 - val_loss: 0.7842 - val_accuracy: 0.7951
# Epoch 151/250
# Learning rate:  0.1
# 391/391 [==============================] - 40s 102ms/step - loss: 0.5298 - accuracy: 0.8775 - val_loss: 0.9264 - val_accuracy: 0.7596
# Epoch 152/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.4367 - accuracy: 0.9113 - val_loss: 0.6724 - val_accuracy: 0.8344
# Epoch 153/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.4064 - accuracy: 0.9209 - val_loss: 0.6646 - val_accuracy: 0.8374
# Epoch 154/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 106ms/step - loss: 0.3975 - accuracy: 0.9229 - val_loss: 0.6539 - val_accuracy: 0.8358
# Epoch 155/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3854 - accuracy: 0.9249 - val_loss: 0.6672 - val_accuracy: 0.8330
# Epoch 156/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 104ms/step - loss: 0.3762 - accuracy: 0.9287 - val_loss: 0.6535 - val_accuracy: 0.8350
# Epoch 157/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3744 - accuracy: 0.9273 - val_loss: 0.6545 - val_accuracy: 0.8376
# Epoch 158/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3665 - accuracy: 0.9304 - val_loss: 0.6885 - val_accuracy: 0.8310
# Epoch 159/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3625 - accuracy: 0.9297 - val_loss: 0.6523 - val_accuracy: 0.8382
# Epoch 160/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.3560 - accuracy: 0.9314 - val_loss: 0.6641 - val_accuracy: 0.8307
# Epoch 161/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.3518 - accuracy: 0.9327 - val_loss: 0.6349 - val_accuracy: 0.8439
# Epoch 162/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.3446 - accuracy: 0.9338 - val_loss: 0.6017 - val_accuracy: 0.8497
# Epoch 163/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.3430 - accuracy: 0.9327 - val_loss: 0.6295 - val_accuracy: 0.8404
# Epoch 164/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3372 - accuracy: 0.9344 - val_loss: 0.6428 - val_accuracy: 0.8361
# Epoch 165/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3347 - accuracy: 0.9349 - val_loss: 0.6421 - val_accuracy: 0.8400
# Epoch 166/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.3335 - accuracy: 0.9346 - val_loss: 0.6070 - val_accuracy: 0.8503
# Epoch 167/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3276 - accuracy: 0.9358 - val_loss: 0.7257 - val_accuracy: 0.8117
# Epoch 168/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 98ms/step - loss: 0.3248 - accuracy: 0.9362 - val_loss: 0.6848 - val_accuracy: 0.8217
# Epoch 169/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.3226 - accuracy: 0.9370 - val_loss: 0.6014 - val_accuracy: 0.8488
# Epoch 170/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3183 - accuracy: 0.9374 - val_loss: 0.7367 - val_accuracy: 0.8100
# Epoch 171/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 0.3159 - accuracy: 0.9352 - val_loss: 0.6453 - val_accuracy: 0.8380
# Epoch 172/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3121 - accuracy: 0.9373 - val_loss: 0.6436 - val_accuracy: 0.8370
# Epoch 173/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3092 - accuracy: 0.9383 - val_loss: 0.6234 - val_accuracy: 0.8411
# Epoch 174/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3073 - accuracy: 0.9378 - val_loss: 0.6587 - val_accuracy: 0.8320
# Epoch 175/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.3070 - accuracy: 0.9380 - val_loss: 0.6500 - val_accuracy: 0.8323
# Epoch 176/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.3021 - accuracy: 0.9387 - val_loss: 0.6314 - val_accuracy: 0.8413
# Epoch 177/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.3027 - accuracy: 0.9378 - val_loss: 0.6726 - val_accuracy: 0.8243
# Epoch 178/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2997 - accuracy: 0.9404 - val_loss: 0.5834 - val_accuracy: 0.8514
# Epoch 179/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2984 - accuracy: 0.9386 - val_loss: 0.6826 - val_accuracy: 0.8238
# Epoch 180/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2960 - accuracy: 0.9385 - val_loss: 0.6650 - val_accuracy: 0.8341
# Epoch 181/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2951 - accuracy: 0.9386 - val_loss: 0.5872 - val_accuracy: 0.8485
# Epoch 182/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2939 - accuracy: 0.9377 - val_loss: 0.6277 - val_accuracy: 0.8378
# Epoch 183/250
# Learning rate:  0.01
# 391/391 [==============================] - 38s 98ms/step - loss: 0.2906 - accuracy: 0.9396 - val_loss: 0.6989 - val_accuracy: 0.8194
# Epoch 184/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2848 - accuracy: 0.9407 - val_loss: 0.6325 - val_accuracy: 0.8369
# Epoch 185/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2843 - accuracy: 0.9412 - val_loss: 0.6239 - val_accuracy: 0.8415
# Epoch 186/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2855 - accuracy: 0.9389 - val_loss: 0.6073 - val_accuracy: 0.8397
# Epoch 187/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2793 - accuracy: 0.9415 - val_loss: 0.5975 - val_accuracy: 0.8422
# Epoch 188/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2765 - accuracy: 0.9410 - val_loss: 0.5962 - val_accuracy: 0.8517
# Epoch 189/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2750 - accuracy: 0.9427 - val_loss: 0.6212 - val_accuracy: 0.8367
# Epoch 190/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2767 - accuracy: 0.9406 - val_loss: 0.6160 - val_accuracy: 0.8387
# Epoch 191/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2761 - accuracy: 0.9403 - val_loss: 0.6628 - val_accuracy: 0.8258
# Epoch 192/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 99ms/step - loss: 0.2722 - accuracy: 0.9409 - val_loss: 0.7137 - val_accuracy: 0.8135
# Epoch 193/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2726 - accuracy: 0.9415 - val_loss: 0.6065 - val_accuracy: 0.8419
# Epoch 194/250
# Learning rate:  0.01
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2691 - accuracy: 0.9418 - val_loss: 0.6160 - val_accuracy: 0.8423
# Epoch 195/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 101ms/step - loss: 0.2704 - accuracy: 0.9413 - val_loss: 0.6721 - val_accuracy: 0.8256
# Epoch 196/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2686 - accuracy: 0.9424 - val_loss: 0.7569 - val_accuracy: 0.8041
# Epoch 197/250
# Learning rate:  0.01
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2648 - accuracy: 0.9423 - val_loss: 0.6604 - val_accuracy: 0.8233
# Epoch 198/250
# Learning rate:  0.01
# 391/391 [==============================] - 39s 100ms/step - loss: 0.2670 - accuracy: 0.9419 - val_loss: 0.6208 - val_accuracy: 0.8380
# Epoch 199/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.2652 - accuracy: 0.9418 - val_loss: 0.6578 - val_accuracy: 0.8251
# Epoch 200/250
# Learning rate:  0.01
# 391/391 [==============================] - 40s 101ms/step - loss: 0.2654 - accuracy: 0.9413 - val_loss: 0.6331 - val_accuracy: 0.8377
# Epoch 201/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2469 - accuracy: 0.9486 - val_loss: 0.5936 - val_accuracy: 0.8462
# Epoch 202/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2365 - accuracy: 0.9531 - val_loss: 0.5860 - val_accuracy: 0.8475
# Epoch 203/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2323 - accuracy: 0.9536 - val_loss: 0.5918 - val_accuracy: 0.8433
# Epoch 204/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2334 - accuracy: 0.9544 - val_loss: 0.5891 - val_accuracy: 0.8476
# Epoch 205/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2306 - accuracy: 0.9541 - val_loss: 0.5941 - val_accuracy: 0.8442
# Epoch 206/250
# Learning rate:  0.001
# 391/391 [==============================] - 45s 115ms/step - loss: 0.2275 - accuracy: 0.9551 - val_loss: 0.5877 - val_accuracy: 0.8458
# Epoch 207/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 111ms/step - loss: 0.2277 - accuracy: 0.9560 - val_loss: 0.5921 - val_accuracy: 0.8455
# Epoch 208/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2288 - accuracy: 0.9554 - val_loss: 0.5910 - val_accuracy: 0.8460
# Epoch 209/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2250 - accuracy: 0.9571 - val_loss: 0.5992 - val_accuracy: 0.8439
# Epoch 210/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2235 - accuracy: 0.9575 - val_loss: 0.6001 - val_accuracy: 0.8437
# Epoch 211/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2233 - accuracy: 0.9575 - val_loss: 0.5774 - val_accuracy: 0.8504
# Epoch 212/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2220 - accuracy: 0.9572 - val_loss: 0.5850 - val_accuracy: 0.8457
# Epoch 213/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2222 - accuracy: 0.9574 - val_loss: 0.5986 - val_accuracy: 0.8436
# Epoch 214/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2233 - accuracy: 0.9566 - val_loss: 0.5939 - val_accuracy: 0.8464
# Epoch 215/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2236 - accuracy: 0.9578 - val_loss: 0.5885 - val_accuracy: 0.8473
# Epoch 216/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2198 - accuracy: 0.9586 - val_loss: 0.5985 - val_accuracy: 0.8435
# Epoch 217/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2193 - accuracy: 0.9568 - val_loss: 0.5792 - val_accuracy: 0.8502
# Epoch 218/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2204 - accuracy: 0.9581 - val_loss: 0.6060 - val_accuracy: 0.8438
# Epoch 219/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2187 - accuracy: 0.9580 - val_loss: 0.5864 - val_accuracy: 0.8479
# Epoch 220/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2182 - accuracy: 0.9586 - val_loss: 0.5792 - val_accuracy: 0.8514
# Epoch 221/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2204 - accuracy: 0.9581 - val_loss: 0.5983 - val_accuracy: 0.8448
# Epoch 222/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2177 - accuracy: 0.9583 - val_loss: 0.6041 - val_accuracy: 0.8443
# Epoch 223/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2186 - accuracy: 0.9584 - val_loss: 0.5825 - val_accuracy: 0.8494
# Epoch 224/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2159 - accuracy: 0.9591 - val_loss: 0.6044 - val_accuracy: 0.8416
# Epoch 225/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 105ms/step - loss: 0.2165 - accuracy: 0.9588 - val_loss: 0.6017 - val_accuracy: 0.8452
# Epoch 226/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2167 - accuracy: 0.9587 - val_loss: 0.5995 - val_accuracy: 0.8452
# Epoch 227/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2144 - accuracy: 0.9597 - val_loss: 0.5900 - val_accuracy: 0.8494
# Epoch 228/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2180 - accuracy: 0.9564 - val_loss: 0.5924 - val_accuracy: 0.8473
# Epoch 229/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 112ms/step - loss: 0.2174 - accuracy: 0.9590 - val_loss: 0.6015 - val_accuracy: 0.8446
# Epoch 230/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2157 - accuracy: 0.9582 - val_loss: 0.5980 - val_accuracy: 0.8464
# Epoch 231/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2152 - accuracy: 0.9584 - val_loss: 0.5892 - val_accuracy: 0.8478
# Epoch 232/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2148 - accuracy: 0.9586 - val_loss: 0.6049 - val_accuracy: 0.8430
# Epoch 233/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2144 - accuracy: 0.9587 - val_loss: 0.6139 - val_accuracy: 0.8401
# Epoch 234/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 111ms/step - loss: 0.2162 - accuracy: 0.9585 - val_loss: 0.6024 - val_accuracy: 0.8454
# Epoch 235/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2119 - accuracy: 0.9599 - val_loss: 0.6036 - val_accuracy: 0.8430
# Epoch 236/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 113ms/step - loss: 0.2121 - accuracy: 0.9590 - val_loss: 0.5995 - val_accuracy: 0.8437
# Epoch 237/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 109ms/step - loss: 0.2136 - accuracy: 0.9596 - val_loss: 0.6154 - val_accuracy: 0.8401
# Epoch 238/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2101 - accuracy: 0.9606 - val_loss: 0.6119 - val_accuracy: 0.8412
# Epoch 239/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2110 - accuracy: 0.9606 - val_loss: 0.5974 - val_accuracy: 0.8463
# Epoch 240/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 103ms/step - loss: 0.2146 - accuracy: 0.9581 - val_loss: 0.5978 - val_accuracy: 0.8458
# Epoch 241/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2109 - accuracy: 0.9605 - val_loss: 0.6100 - val_accuracy: 0.8423
# Epoch 242/250
# Learning rate:  0.001
# 391/391 [==============================] - 44s 111ms/step - loss: 0.2129 - accuracy: 0.9598 - val_loss: 0.6187 - val_accuracy: 0.8398
# Epoch 243/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2104 - accuracy: 0.9597 - val_loss: 0.6266 - val_accuracy: 0.8380
# Epoch 244/250
# Learning rate:  0.001
# 391/391 [==============================] - 40s 102ms/step - loss: 0.2113 - accuracy: 0.9581 - val_loss: 0.5982 - val_accuracy: 0.8457
# Epoch 245/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 107ms/step - loss: 0.2109 - accuracy: 0.9590 - val_loss: 0.5987 - val_accuracy: 0.8457
# Epoch 246/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2097 - accuracy: 0.9598 - val_loss: 0.5957 - val_accuracy: 0.8476
# Epoch 247/250
# Learning rate:  0.001
# 391/391 [==============================] - 42s 108ms/step - loss: 0.2097 - accuracy: 0.9597 - val_loss: 0.5946 - val_accuracy: 0.8497
# Epoch 248/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 106ms/step - loss: 0.2096 - accuracy: 0.9606 - val_loss: 0.5993 - val_accuracy: 0.8455
# Epoch 249/250
# Learning rate:  0.001
# 391/391 [==============================] - 41s 104ms/step - loss: 0.2064 - accuracy: 0.9616 - val_loss: 0.5906 - val_accuracy: 0.8503
# Epoch 250/250
# Learning rate:  0.001
# 391/391 [==============================] - 43s 110ms/step - loss: 0.2077 - accuracy: 0.9604 - val_loss: 0.6124 - val_accuracy: 0.8423

# %%
tess_resnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# tess_conv2d (TessConv2D)     (None, None, None, 24)    216
# _________________________________________________________________
# tess_residual_unit (TessResi (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_1 (TessRe (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_2 (TessRe (None, None, None, 24)    2784
# _________________________________________________________________
# tess_residual_unit_3 (TessRe (None, None, None, 48)    8640
# _________________________________________________________________
# tess_residual_unit_4 (TessRe (None, None, None, 48)    10752
# _________________________________________________________________
# tess_residual_unit_5 (TessRe (None, None, None, 96)    33408
# _________________________________________________________________
# tess_residual_unit_6 (TessRe (None, None, None, 96)    42240
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 96)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 96)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                970
# =================================================================
# Total params: 104,578
# Trainable params: 102,850
# Non-trainable params: 1,728
# _________________________________________________________________

# %%
accuracy_score(np.argmax(ytr_cifar, axis=1),np.argmax(tess_resnet.predict(Xtr_rgb),axis=1))
# Out:
# 0.96392

# %%
accuracy_score(np.argmax(yte_cifar, axis=1),np.argmax(tess_resnet.predict(Xte_rgb),axis=1))
# Out:
# 0.8423
